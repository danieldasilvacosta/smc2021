# %%
# Principais mudanças
    
# Baseline: 20200610-16h46--20200610-13h41
# Ver apresentação do dia 15/06/2020.

# %%
images_dimensions = 128
attribute = 'Big_Lips'
totalInputImages = 5000
BATCH_SIZE = 100
latent_dim = 100

# %%
EPOCHS = 200

# %%
from numpy import load
from numpy import zeros
from numpy import ones
from numpy.random import randn
from numpy.random import randint
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Reshape
from keras.layers import Flatten
from keras.layers import Conv2D
from keras.layers import Conv2DTranspose
from keras.layers import LeakyReLU
from keras.layers import Dropout
from matplotlib import pyplot

# Daniel
import os
import sys
import numpy as np
from PIL import Image
from tqdm import tqdm
import cv2
import time
from keras.initializers import RandomNormal
from numpy.random import random
from numpy.random import choice
import shutil
# Out:
# Using TensorFlow backend.

# %%
import warnings
warnings.filterwarnings( 'ignore' )

# %%
import tensorflow as tf
print( tf.__version__ )
print( 'Num GPUs Available: ', len( tf.config.list_physical_devices( 'GPU' ) ) )
# Out:
# 2.1.0
# Num GPUs Available:  1

# %%
lastTimeNotebook = time.time()

# %%
IMAGES_FOLDER = './images/'
folderDimensionsSufix = str( images_dimensions ) + 'x' + str( images_dimensions )

padronizedFolder = f'{IMAGES_FOLDER}padronized--{attribute}--{folderDimensionsSufix}--{totalInputImages}--bs-{BATCH_SIZE}--ls-{latent_dim}/'

# %%
trainedModelFolder = f'./trained-model--{attribute}--{folderDimensionsSufix}--{totalInputImages}--bs-{BATCH_SIZE}--ls-{latent_dim}/'
generatorFolder = trainedModelFolder + 'generator/'
generatedFolder = trainedModelFolder + 'generated/'

# %%
try:
    shutil.rmtree(trainedModelFolder)
    os.mkdir(trainedModelFolder)
except OSError as e:
    os.mkdir(trainedModelFolder)

# %%
try:
    shutil.rmtree(generatorFolder)
    os.mkdir(generatorFolder)
except OSError as e:
    os.mkdir(generatorFolder)

# %%
try:
    shutil.rmtree(generatedFolder)
    os.mkdir(generatedFolder)
except OSError as e:
    os.mkdir(generatedFolder)

# %%
def define_discriminator(in_shape=(128,128,1)):
    model = Sequential()
    # normal
    model.add(Conv2D(128, (6,6), padding='same', input_shape=in_shape))
    model.add(LeakyReLU(alpha=0.2))

    # downsample to 64x64
    model.add(Conv2D(128, (6,6), strides=(2,2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    
    # downsample to 32x32
    model.add(Conv2D(128, (6,6), strides=(2,2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    
    # downsample to 16x16
    model.add(Conv2D(128, (6,6), strides=(2,2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    
    # downsample to 8x8
    model.add(Conv2D(128, (6,6), strides=(2,2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    
    # classifier
    model.add(Flatten())
    model.add(Dropout(0.4))
    model.add(Dense(1, activation='sigmoid'))
    
    # compile model
    opt = Adam(lr=0.0002, beta_1=0.5)
    model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

    print()
    print('=================================================================')
    print('========================= Discriminator =========================')
    print('=================================================================')
    print()
    print( model.summary() )

    return model

# %%
# define the standalone generator model
def define_generator(latent_dim):
    model = Sequential()
    
    # foundation for 8x8 feature maps
    n_nodes = 128 * 8 * 8
    model.add(Dense(n_nodes, input_dim=latent_dim))
    model.add(LeakyReLU(alpha=0.2))
    
    model.add(Reshape((8, 8, 128)))
    
    # upsample to 16x16
    model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    
    # upsample to 32x32
    model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    
    # upsample to 64x64
    model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    
    # upsample to 128x128
    model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    
    # output layer 128x128x3
    model.add(Conv2D(1, (5,5), activation='tanh', padding='same'))

    print()
    print('=================================================================')
    print('=========================== Generator ===========================')
    print('=================================================================')
    print()
    print( model.summary() )
    
    return model

# %%
# define the combined generator and discriminator model, for updating the generator
def define_gan(g_model, d_model):
    # make weights in the discriminator not trainable
    d_model.trainable = False
    # connect them
    model = Sequential()
    # add generator
    model.add(g_model)
    # add the discriminator
    model.add(d_model)
    # compile model
    opt = Adam(lr=0.0002, beta_1=0.5)
    model.compile(loss='binary_crossentropy', optimizer=opt)
    return model

# %%
# load and prepare training images
def load_real_samples():
    
    _, _, files = next( os.walk( padronizedFolder ) )

    images = []
    for file in tqdm(files):

        image = cv2.imread( padronizedFolder + file, cv2.IMREAD_GRAYSCALE )
        image = image[..., np.newaxis]
        image = (image - 127.5) / 127.5
        images.append( image )

    images = np.asarray(images)
    return images

# %%
# Daniel # 5.5.3 Use Label Smoothing

# example of smoothing class=1 to [0.7, 1.2]
def smooth_positive_labels(y):
    return y - 0.3 + (random(y.shape) * 0.5)

# example of smoothing class=0 to [0.0, 0.3]
def smooth_negative_labels(y):
    return y + random(y.shape) * 0.3

# %%
# Daniel # 5.5.4 Use Noisy Labels

# randomly flip some labels
def noisy_labels(y, p_flip):
    
    # determine the number of labels to flip
    n_select = int(p_flip * y.shape[0])
    
    # choose labels to flip
    flip_ix = choice([i for i in range(y.shape[0])], size=n_select)
    
    # invert the labels in place
    y[flip_ix] = 1 - y[flip_ix]
    
    return y

# %%
# select real samples
def generate_real_samples(dataset, n_samples):
    
    # choose random instances
    ix = randint(0, dataset.shape[0], n_samples)
    
    # retrieve selected images
    X = dataset[ix]
    
    # generate 'real' class labels (1)
    y = ones((n_samples, 1))

    # Daniel # 5.5.3 Use Label Smoothing
    # smooth labels
    y = smooth_positive_labels(y)

    # Daniel # 5.5.4 Use Noisy Labels
    # flip labels with 5% probability
    y = noisy_labels(y, 0.05)

    return X, y

# %%
# generate points in latent space as input for the generator
def generate_latent_points(latent_dim, n_samples):
    
    # generate points in the latent space
    x_input = randn(latent_dim * n_samples)
    
    # reshape into a batch of inputs for the network
    x_input = x_input.reshape(n_samples, latent_dim)
    return x_input

# %%
# use the generator to generate n fake examples, with class labels
def generate_fake_samples(g_model, latent_dim, n_samples):
    
    # generate points in latent space
    x_input = generate_latent_points(latent_dim, n_samples)
    
    # predict outputs
    X = g_model.predict(x_input)
    
    # create 'fake' class labels (0)
    y = zeros((n_samples, 1))

    # Daniel # 5.5.3 Use Label Smoothing
    # smooth labels
    y = smooth_negative_labels(y)

    # Daniel # 5.5.4 Use Noisy Labels
    # flip labels with 5% probability
    y = noisy_labels(y, 0.05)

    return X, y

# %%
# create and save a plot of generated images
def save_plot(examples, epoch, n=10):
    
    # Daniel
    examples = ( examples * 127.5 ) + 127.5
    epochFolder = generatedFolder + f'epoch-{epoch + 1}/'
    
    # Daniel
    for i in range(0, 30) :
        
        cv2.imwrite( 
            epochFolder + f'epoch-{epoch + 1}--{i + 1}.png', 
            examples[i] )

# %%
# evaluate the discriminator, plot generated images, save generator model
def summarize_performance(epoch, g_model, d_model, dataset, latent_dim, n_samples=100):
    
    # prepare real samples
    X_real, y_real = generate_real_samples(dataset, n_samples)
    
    # evaluate discriminator on real examples
    _, acc_real = d_model.evaluate(X_real, y_real, verbose=0)
    
    # prepare fake examples
    x_fake, y_fake = generate_fake_samples(g_model, latent_dim, n_samples)
    
    # evaluate discriminator on fake examples
    _, acc_fake = d_model.evaluate(x_fake, y_fake, verbose=0)
    
    # save plot
    save_plot(x_fake, epoch)
    
    # save the generator model tile file
    filename = generatorFolder + 'generator_model_%03d.h5' % (epoch + 1)
    g_model.save(filename)

# %%
# train the generator and discriminator
def train(g_model, d_model, gan_model, dataset, latent_dim, n_epochs=100, n_batch=128):
    
    lastTime = time.time()
    
    bat_per_epo = int(dataset.shape[0] / n_batch)
    half_batch = int(n_batch / 2)
    
    # manually enumerate epochs
    for i in range(n_epochs):
        
        print()
        
        # enumerate batches over the training set
        for j in range(bat_per_epo):
            
            # Time
            now = time.time()
            interval = now - lastTime
            lastTime = now
            
            # get randomly selected 'real' samples
            X_real, y_real = generate_real_samples(dataset, half_batch)
            
            # update discriminator model weights
            d_loss1, _ = d_model.train_on_batch(X_real, y_real)
            
            # generate 'fake' examples
            X_fake, y_fake = generate_fake_samples(g_model, latent_dim, half_batch)
            
            # update discriminator model weights
            d_loss2, _ = d_model.train_on_batch(X_fake, y_fake)
            
            # prepare points in latent space as input for the generator
            X_gan = generate_latent_points(latent_dim, n_batch)
            
            # create inverted labels for the fake samples
            y_gan = ones((n_batch, 1))
            
            # update the generator via the discriminator's error
            g_loss = gan_model.train_on_batch(X_gan, y_gan)
            
            # summarize loss on this batch
            print('> epoch=%d, batch=%d/%d, d1=%.3f, d2=%.3f, g=%.3f, time=%.2f sec' %
                (i+1, j+1, bat_per_epo, d_loss1, d_loss2, g_loss, (interval) ))
            
        # evaluate the model performance, sometimes
        if (i + 1) % 1 == 0:

            # Daniel
            os.mkdir( generatedFolder + f'epoch-{i + 1}/' )
            
            summarize_performance(i, g_model, d_model, dataset, latent_dim)

# %%
print( 'Processing...' )
print()

# create the discriminator
d_model = define_discriminator()

# create the generator
g_model = define_generator(latent_dim)

# create the gan
gan_model = define_gan(g_model, d_model)

# load image data
dataset = load_real_samples()

# train model
train(
    g_model, 
    d_model, 
    gan_model, 
    dataset, 
    latent_dim, 
    n_epochs=EPOCHS, 
    n_batch=BATCH_SIZE)

print( '\n----------------------------------------------------' )
print( 'Finalized' )

# Time
now = time.time()
interval = now - lastTimeNotebook
print('Notebook Time: %.2f min' % (interval/60))
# Out:
# Processing...
#   0%|          | 0/5000 [00:00<?, ?it/s]
# =================================================================
# ========================= Discriminator =========================
# =================================================================
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 128, 128, 128)     4736
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 128, 128, 128)     0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 128)       589952
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 64, 64, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 128)       589952
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 128)       589952
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 128)         589952
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 8, 8, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8192)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 8193
# =================================================================
# Total params: 2,372,737
# Trainable params: 2,372,737
# Non-trainable params: 0
# _________________________________________________________________
# None
#
# =================================================================
# =========================== Generator ===========================
# =================================================================
#
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 8192)              827392
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 8192)              0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 16, 16, 128)       262272
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 32, 32, 128)       262272
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 64, 64, 128)       262272
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 64, 64, 128)       0
# _________________________________________________________________
# conv2d_transpose_4 (Conv2DTr (None, 128, 128, 128)     262272
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 128, 128, 128)     0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 128, 128, 1)       3201
# =================================================================
# Total params: 1,879,681
# Trainable params: 1,879,681
# Non-trainable params: 0
# _________________________________________________________________
# None
# 100%|██████████| 5000/5000 [00:18<00:00, 267.58it/s]
# > epoch=1, batch=1/50, d1=0.700, d2=0.695, g=0.692, time=0.00 sec
# > epoch=1, batch=2/50, d1=0.635, d2=0.697, g=0.689, time=11.41 sec
# > epoch=1, batch=3/50, d1=0.416, d2=0.717, g=0.674, time=0.85 sec
# > epoch=1, batch=4/50, d1=0.462, d2=0.696, g=0.697, time=0.85 sec
# > epoch=1, batch=5/50, d1=0.379, d2=0.691, g=0.702, time=0.85 sec
# > epoch=1, batch=6/50, d1=0.415, d2=0.694, g=0.695, time=0.85 sec
# > epoch=1, batch=7/50, d1=0.383, d2=0.701, g=0.691, time=0.85 sec
# > epoch=1, batch=8/50, d1=0.361, d2=0.700, g=0.716, time=0.85 sec
# > epoch=1, batch=9/50, d1=0.265, d2=0.685, g=0.747, time=0.85 sec
# > epoch=1, batch=10/50, d1=0.406, d2=0.670, g=0.758, time=0.85 sec
# > epoch=1, batch=11/50, d1=0.491, d2=0.681, g=0.712, time=0.85 sec
# > epoch=1, batch=12/50, d1=0.335, d2=0.681, g=0.722, time=0.85 sec
# > epoch=1, batch=13/50, d1=0.349, d2=0.674, g=0.741, time=0.85 sec
# > epoch=1, batch=14/50, d1=0.359, d2=0.656, g=0.806, time=0.85 sec
# > epoch=1, batch=15/50, d1=0.296, d2=0.602, g=1.146, time=0.85 sec
# > epoch=1, batch=16/50, d1=0.570, d2=0.504, g=1.950, time=0.85 sec
# > epoch=1, batch=17/50, d1=0.760, d2=0.510, g=1.207, time=0.85 sec
# > epoch=1, batch=18/50, d1=0.413, d2=0.522, g=1.381, time=0.86 sec
# > epoch=1, batch=19/50, d1=0.241, d2=0.537, g=1.601, time=0.86 sec
# > epoch=1, batch=20/50, d1=0.382, d2=0.475, g=1.700, time=0.86 sec
# > epoch=1, batch=21/50, d1=0.383, d2=0.473, g=2.103, time=0.86 sec
# > epoch=1, batch=22/50, d1=0.459, d2=0.707, g=0.961, time=0.89 sec
# > epoch=1, batch=23/50, d1=0.340, d2=0.774, g=1.459, time=0.89 sec
# > epoch=1, batch=24/50, d1=0.389, d2=0.457, g=6.877, time=0.87 sec
# > epoch=1, batch=25/50, d1=0.309, d2=0.710, g=0.420, time=0.88 sec
# > epoch=1, batch=26/50, d1=0.416, d2=0.869, g=0.752, time=0.86 sec
# > epoch=1, batch=27/50, d1=0.424, d2=0.648, g=0.996, time=0.87 sec
# > epoch=1, batch=28/50, d1=0.275, d2=0.567, g=1.423, time=0.87 sec
# > epoch=1, batch=29/50, d1=0.379, d2=0.527, g=1.326, time=0.86 sec
# > epoch=1, batch=30/50, d1=0.524, d2=0.600, g=0.901, time=0.89 sec
# > epoch=1, batch=31/50, d1=0.359, d2=0.647, g=0.783, time=0.86 sec
# > epoch=1, batch=32/50, d1=0.436, d2=0.658, g=0.772, time=0.87 sec
# > epoch=1, batch=33/50, d1=0.341, d2=0.646, g=0.815, time=0.88 sec
# > epoch=1, batch=34/50, d1=0.350, d2=0.633, g=0.835, time=0.86 sec
# > epoch=1, batch=35/50, d1=0.277, d2=0.637, g=0.837, time=0.89 sec
# > epoch=1, batch=36/50, d1=0.463, d2=0.644, g=0.799, time=0.87 sec
# > epoch=1, batch=37/50, d1=0.365, d2=0.636, g=0.829, time=0.86 sec
# > epoch=1, batch=38/50, d1=0.253, d2=0.619, g=0.892, time=0.86 sec
# > epoch=1, batch=39/50, d1=0.524, d2=0.675, g=0.751, time=0.86 sec
# > epoch=1, batch=40/50, d1=0.388, d2=0.652, g=0.997, time=0.88 sec
# > epoch=1, batch=41/50, d1=0.371, d2=0.586, g=1.520, time=0.87 sec
# > epoch=1, batch=42/50, d1=0.350, d2=0.499, g=2.184, time=0.88 sec
# > epoch=1, batch=43/50, d1=0.263, d2=0.428, g=2.795, time=0.86 sec
# > epoch=1, batch=44/50, d1=0.428, d2=0.508, g=4.790, time=0.86 sec
# > epoch=1, batch=45/50, d1=0.354, d2=0.573, g=0.479, time=0.86 sec
# > epoch=1, batch=46/50, d1=0.310, d2=1.372, g=0.767, time=0.86 sec
# > epoch=1, batch=47/50, d1=0.448, d2=0.612, g=1.060, time=0.86 sec
# > epoch=1, batch=48/50, d1=0.394, d2=0.517, g=1.597, time=0.86 sec
# > epoch=1, batch=49/50, d1=0.420, d2=0.482, g=1.721, time=0.86 sec
# > epoch=1, batch=50/50, d1=0.463, d2=0.490, g=1.644, time=0.86 sec
#
# > epoch=2, batch=1/50, d1=0.335, d2=0.476, g=1.747, time=2.01 sec
# > epoch=2, batch=2/50, d1=0.341, d2=0.483, g=1.651, time=0.87 sec
# > epoch=2, batch=3/50, d1=0.463, d2=0.527, g=1.289, time=0.86 sec
# > epoch=2, batch=4/50, d1=0.315, d2=0.490, g=1.674, time=0.86 sec
# > epoch=2, batch=5/50, d1=0.334, d2=0.477, g=1.662, time=0.86 sec
# > epoch=2, batch=6/50, d1=0.308, d2=0.434, g=1.836, time=0.86 sec
# > epoch=2, batch=7/50, d1=0.309, d2=0.456, g=1.833, time=0.87 sec
# > epoch=2, batch=8/50, d1=0.281, d2=0.483, g=1.620, time=0.92 sec
# > epoch=2, batch=9/50, d1=0.316, d2=0.492, g=1.803, time=0.87 sec
# > epoch=2, batch=10/50, d1=0.355, d2=0.461, g=2.050, time=0.89 sec
# > epoch=2, batch=11/50, d1=0.350, d2=0.479, g=1.495, time=0.89 sec
# > epoch=2, batch=12/50, d1=0.333, d2=0.582, g=3.556, time=0.86 sec
# > epoch=2, batch=13/50, d1=0.398, d2=0.748, g=1.192, time=0.89 sec
# > epoch=2, batch=14/50, d1=0.417, d2=0.589, g=1.078, time=0.86 sec
# > epoch=2, batch=15/50, d1=0.268, d2=0.517, g=1.602, time=0.87 sec
# > epoch=2, batch=16/50, d1=0.390, d2=0.484, g=1.650, time=0.86 sec
# > epoch=2, batch=17/50, d1=0.375, d2=0.489, g=1.422, time=0.86 sec
# > epoch=2, batch=18/50, d1=0.329, d2=0.510, g=1.390, time=0.86 sec
# > epoch=2, batch=19/50, d1=0.313, d2=0.505, g=1.363, time=0.86 sec
# > epoch=2, batch=20/50, d1=0.340, d2=0.524, g=1.208, time=0.86 sec
# > epoch=2, batch=21/50, d1=0.256, d2=0.523, g=1.331, time=0.86 sec
# > epoch=2, batch=22/50, d1=0.387, d2=0.484, g=1.453, time=0.86 sec
# > epoch=2, batch=23/50, d1=0.315, d2=0.490, g=1.659, time=0.86 sec
# > epoch=2, batch=24/50, d1=0.360, d2=0.467, g=1.585, time=0.86 sec
# > epoch=2, batch=25/50, d1=0.368, d2=0.467, g=1.676, time=0.86 sec
# > epoch=2, batch=26/50, d1=0.308, d2=0.436, g=1.878, time=0.86 sec
# > epoch=2, batch=27/50, d1=0.260, d2=0.462, g=1.756, time=0.86 sec
# > epoch=2, batch=28/50, d1=0.354, d2=0.487, g=1.635, time=0.86 sec
# > epoch=2, batch=29/50, d1=0.271, d2=0.487, g=2.093, time=0.86 sec
# > epoch=2, batch=30/50, d1=0.326, d2=0.476, g=1.734, time=0.86 sec
# > epoch=2, batch=31/50, d1=0.325, d2=0.798, g=1.397, time=0.87 sec
# > epoch=2, batch=32/50, d1=0.302, d2=0.513, g=3.483, time=0.86 sec
# > epoch=2, batch=33/50, d1=0.561, d2=0.513, g=1.183, time=0.86 sec
# > epoch=2, batch=34/50, d1=0.390, d2=0.614, g=1.337, time=0.87 sec
# > epoch=2, batch=35/50, d1=0.442, d2=0.526, g=1.682, time=0.86 sec
# > epoch=2, batch=36/50, d1=0.320, d2=0.479, g=1.953, time=0.87 sec
# > epoch=2, batch=37/50, d1=0.403, d2=0.495, g=1.648, time=0.86 sec
# > epoch=2, batch=38/50, d1=0.395, d2=0.505, g=1.675, time=0.86 sec
# > epoch=2, batch=39/50, d1=0.402, d2=0.487, g=1.709, time=0.87 sec
# > epoch=2, batch=40/50, d1=0.426, d2=0.481, g=2.051, time=0.87 sec
# > epoch=2, batch=41/50, d1=0.360, d2=0.531, g=2.648, time=0.86 sec
# > epoch=2, batch=42/50, d1=0.371, d2=0.580, g=5.779, time=0.86 sec
# > epoch=2, batch=43/50, d1=7.032, d2=0.708, g=0.862, time=0.87 sec
# > epoch=2, batch=44/50, d1=0.485, d2=0.601, g=1.424, time=0.86 sec
# > epoch=2, batch=45/50, d1=0.404, d2=0.540, g=1.409, time=0.86 sec
# > epoch=2, batch=46/50, d1=0.487, d2=0.502, g=1.521, time=0.87 sec
# > epoch=2, batch=47/50, d1=0.546, d2=0.513, g=1.378, time=0.86 sec
# > epoch=2, batch=48/50, d1=0.528, d2=0.566, g=1.378, time=0.86 sec
# > epoch=2, batch=49/50, d1=0.292, d2=0.547, g=1.440, time=0.86 sec
# > epoch=2, batch=50/50, d1=0.284, d2=0.517, g=1.550, time=0.87 sec
#
# > epoch=3, batch=1/50, d1=0.377, d2=0.467, g=1.828, time=1.25 sec
# > epoch=3, batch=2/50, d1=0.304, d2=0.522, g=1.566, time=0.87 sec
# > epoch=3, batch=3/50, d1=0.358, d2=0.488, g=2.305, time=0.87 sec
# > epoch=3, batch=4/50, d1=0.223, d2=0.469, g=1.542, time=0.87 sec
# > epoch=3, batch=5/50, d1=0.291, d2=0.743, g=2.174, time=0.87 sec
# > epoch=3, batch=6/50, d1=0.305, d2=0.608, g=1.636, time=0.87 sec
# > epoch=3, batch=7/50, d1=0.544, d2=0.701, g=1.025, time=0.86 sec
# > epoch=3, batch=8/50, d1=0.707, d2=0.821, g=0.612, time=0.86 sec
# > epoch=3, batch=9/50, d1=0.353, d2=0.751, g=0.690, time=0.86 sec
# > epoch=3, batch=10/50, d1=0.228, d2=0.666, g=0.824, time=0.86 sec
# > epoch=3, batch=11/50, d1=0.462, d2=0.590, g=1.054, time=0.87 sec
# > epoch=3, batch=12/50, d1=0.370, d2=0.530, g=1.299, time=0.86 sec
# > epoch=3, batch=13/50, d1=0.297, d2=0.492, g=1.552, time=0.86 sec
# > epoch=3, batch=14/50, d1=0.235, d2=0.472, g=1.607, time=0.86 sec
# > epoch=3, batch=15/50, d1=0.403, d2=0.481, g=1.534, time=0.87 sec
# > epoch=3, batch=16/50, d1=0.298, d2=0.505, g=1.427, time=0.87 sec
# > epoch=3, batch=17/50, d1=0.378, d2=0.489, g=1.460, time=0.86 sec
# > epoch=3, batch=18/50, d1=0.375, d2=0.481, g=1.488, time=0.87 sec
# > epoch=3, batch=19/50, d1=0.259, d2=0.503, g=1.505, time=0.87 sec
# > epoch=3, batch=20/50, d1=0.195, d2=0.518, g=1.616, time=0.86 sec
# > epoch=3, batch=21/50, d1=0.218, d2=0.475, g=1.912, time=0.87 sec
# > epoch=3, batch=22/50, d1=0.356, d2=0.480, g=1.711, time=0.86 sec
# > epoch=3, batch=23/50, d1=0.332, d2=0.500, g=2.147, time=0.87 sec
# > epoch=3, batch=24/50, d1=0.271, d2=0.450, g=1.262, time=0.87 sec
# > epoch=3, batch=25/50, d1=0.374, d2=0.576, g=1.921, time=0.86 sec
# > epoch=3, batch=26/50, d1=0.287, d2=0.531, g=1.245, time=0.86 sec
# > epoch=3, batch=27/50, d1=0.338, d2=0.595, g=1.208, time=0.86 sec
# > epoch=3, batch=28/50, d1=0.371, d2=0.504, g=1.628, time=0.87 sec
# > epoch=3, batch=29/50, d1=0.140, d2=0.469, g=1.783, time=0.87 sec
# > epoch=3, batch=30/50, d1=0.302, d2=0.479, g=1.780, time=0.86 sec
# > epoch=3, batch=31/50, d1=0.295, d2=0.448, g=2.209, time=0.87 sec
# > epoch=3, batch=32/50, d1=0.334, d2=0.494, g=1.287, time=0.87 sec
# > epoch=3, batch=33/50, d1=0.246, d2=0.714, g=1.504, time=0.87 sec
# > epoch=3, batch=34/50, d1=0.282, d2=0.494, g=2.466, time=0.87 sec
# > epoch=3, batch=35/50, d1=0.364, d2=0.546, g=0.986, time=0.87 sec
# > epoch=3, batch=36/50, d1=0.370, d2=0.759, g=0.962, time=0.87 sec
# > epoch=3, batch=37/50, d1=0.245, d2=0.541, g=1.678, time=0.87 sec
# > epoch=3, batch=38/50, d1=0.428, d2=0.491, g=1.594, time=0.87 sec
# > epoch=3, batch=39/50, d1=0.251, d2=0.478, g=1.790, time=0.87 sec
# > epoch=3, batch=40/50, d1=0.436, d2=0.498, g=1.657, time=0.87 sec
# > epoch=3, batch=41/50, d1=0.279, d2=0.472, g=1.759, time=0.87 sec
# > epoch=3, batch=42/50, d1=0.407, d2=0.448, g=1.909, time=0.87 sec
# > epoch=3, batch=43/50, d1=0.305, d2=0.510, g=1.578, time=0.86 sec
# > epoch=3, batch=44/50, d1=0.370, d2=0.494, g=1.539, time=0.87 sec
# > epoch=3, batch=45/50, d1=0.294, d2=0.478, g=1.712, time=0.87 sec
# > epoch=3, batch=46/50, d1=0.228, d2=0.470, g=1.747, time=0.87 sec
# > epoch=3, batch=47/50, d1=0.243, d2=0.472, g=1.703, time=0.87 sec
# > epoch=3, batch=48/50, d1=0.242, d2=0.488, g=1.720, time=0.87 sec
# > epoch=3, batch=49/50, d1=0.350, d2=0.456, g=1.800, time=0.87 sec
# > epoch=3, batch=50/50, d1=0.248, d2=0.452, g=1.848, time=0.87 sec
#
# > epoch=4, batch=1/50, d1=0.274, d2=0.492, g=1.641, time=2.59 sec
# > epoch=4, batch=2/50, d1=0.468, d2=0.490, g=1.702, time=0.86 sec
# > epoch=4, batch=3/50, d1=0.342, d2=0.460, g=1.857, time=0.87 sec
# > epoch=4, batch=4/50, d1=0.309, d2=0.437, g=1.932, time=0.87 sec
# > epoch=4, batch=5/50, d1=0.351, d2=0.479, g=1.827, time=0.87 sec
# > epoch=4, batch=6/50, d1=0.345, d2=0.476, g=3.126, time=0.86 sec
# > epoch=4, batch=7/50, d1=0.331, d2=0.564, g=1.420, time=0.87 sec
# > epoch=4, batch=8/50, d1=0.373, d2=0.673, g=0.930, time=0.87 sec
# > epoch=4, batch=9/50, d1=0.363, d2=0.636, g=1.194, time=0.86 sec
# > epoch=4, batch=10/50, d1=0.445, d2=0.626, g=1.090, time=0.86 sec
# > epoch=4, batch=11/50, d1=0.312, d2=0.537, g=1.797, time=0.87 sec
# > epoch=4, batch=12/50, d1=0.407, d2=0.458, g=1.779, time=0.86 sec
# > epoch=4, batch=13/50, d1=0.380, d2=0.491, g=1.692, time=0.86 sec
# > epoch=4, batch=14/50, d1=0.403, d2=0.445, g=2.101, time=0.86 sec
# > epoch=4, batch=15/50, d1=0.287, d2=0.485, g=1.387, time=0.86 sec
# > epoch=4, batch=16/50, d1=0.406, d2=0.602, g=1.935, time=0.86 sec
# > epoch=4, batch=17/50, d1=0.297, d2=0.501, g=1.512, time=0.87 sec
# > epoch=4, batch=18/50, d1=0.280, d2=0.511, g=1.564, time=0.86 sec
# > epoch=4, batch=19/50, d1=0.235, d2=0.475, g=1.772, time=0.86 sec
# > epoch=4, batch=20/50, d1=0.464, d2=0.486, g=1.656, time=0.87 sec
# > epoch=4, batch=21/50, d1=0.356, d2=0.460, g=1.690, time=0.87 sec
# > epoch=4, batch=22/50, d1=0.305, d2=0.481, g=1.702, time=0.87 sec
# > epoch=4, batch=23/50, d1=0.319, d2=0.492, g=1.598, time=0.86 sec
# > epoch=4, batch=24/50, d1=0.276, d2=0.479, g=1.700, time=0.87 sec
# > epoch=4, batch=25/50, d1=0.260, d2=0.488, g=1.711, time=0.86 sec
# > epoch=4, batch=26/50, d1=0.296, d2=0.498, g=1.708, time=0.86 sec
# > epoch=4, batch=27/50, d1=0.299, d2=0.492, g=2.037, time=0.86 sec
# > epoch=4, batch=28/50, d1=0.351, d2=0.480, g=1.619, time=0.86 sec
# > epoch=4, batch=29/50, d1=0.331, d2=0.678, g=2.802, time=0.86 sec
# > epoch=4, batch=30/50, d1=0.281, d2=0.491, g=0.972, time=0.87 sec
# > epoch=4, batch=31/50, d1=0.375, d2=0.692, g=0.997, time=0.86 sec
# > epoch=4, batch=32/50, d1=0.308, d2=0.544, g=1.699, time=0.87 sec
# > epoch=4, batch=33/50, d1=0.354, d2=0.457, g=1.933, time=0.87 sec
# > epoch=4, batch=34/50, d1=0.263, d2=0.515, g=1.553, time=0.87 sec
# > epoch=4, batch=35/50, d1=0.440, d2=0.522, g=1.715, time=0.87 sec
# > epoch=4, batch=36/50, d1=0.388, d2=0.477, g=1.829, time=0.87 sec
# > epoch=4, batch=37/50, d1=0.423, d2=0.485, g=1.707, time=0.87 sec
# > epoch=4, batch=38/50, d1=0.368, d2=0.469, g=1.700, time=0.86 sec
# > epoch=4, batch=39/50, d1=0.319, d2=0.483, g=1.922, time=0.87 sec
# > epoch=4, batch=40/50, d1=0.345, d2=0.496, g=1.703, time=0.87 sec
# > epoch=4, batch=41/50, d1=0.234, d2=0.514, g=2.704, time=0.87 sec
# > epoch=4, batch=42/50, d1=0.324, d2=0.536, g=1.102, time=0.87 sec
# > epoch=4, batch=43/50, d1=0.288, d2=0.751, g=1.001, time=0.87 sec
# > epoch=4, batch=44/50, d1=0.368, d2=0.519, g=1.723, time=0.87 sec
# > epoch=4, batch=45/50, d1=0.291, d2=0.516, g=1.658, time=0.87 sec
# > epoch=4, batch=46/50, d1=0.335, d2=0.518, g=1.483, time=0.87 sec
# > epoch=4, batch=47/50, d1=0.417, d2=0.500, g=1.529, time=0.87 sec
# > epoch=4, batch=48/50, d1=0.395, d2=0.538, g=2.149, time=0.87 sec
# > epoch=4, batch=49/50, d1=0.349, d2=0.538, g=1.590, time=0.87 sec
# > epoch=4, batch=50/50, d1=0.312, d2=0.517, g=1.515, time=0.86 sec
#
# > epoch=5, batch=1/50, d1=0.371, d2=0.502, g=1.641, time=3.56 sec
# > epoch=5, batch=2/50, d1=0.464, d2=0.479, g=1.600, time=0.89 sec
# > epoch=5, batch=3/50, d1=0.416, d2=0.460, g=1.951, time=0.87 sec
# > epoch=5, batch=4/50, d1=0.399, d2=0.537, g=1.628, time=0.87 sec
# > epoch=5, batch=5/50, d1=0.422, d2=0.608, g=1.865, time=0.86 sec
# > epoch=5, batch=6/50, d1=0.415, d2=0.609, g=1.919, time=0.86 sec
# > epoch=5, batch=7/50, d1=0.430, d2=0.460, g=1.591, time=0.87 sec
# > epoch=5, batch=8/50, d1=0.394, d2=0.477, g=1.830, time=0.86 sec
# > epoch=5, batch=9/50, d1=0.380, d2=0.475, g=1.712, time=0.86 sec
# > epoch=5, batch=10/50, d1=0.423, d2=0.534, g=1.566, time=0.87 sec
# > epoch=5, batch=11/50, d1=0.375, d2=0.583, g=1.754, time=0.86 sec
# > epoch=5, batch=12/50, d1=0.443, d2=0.619, g=1.996, time=0.86 sec
# > epoch=5, batch=13/50, d1=0.537, d2=0.532, g=1.850, time=0.87 sec
# > epoch=5, batch=14/50, d1=0.433, d2=0.572, g=2.317, time=0.86 sec
# > epoch=5, batch=15/50, d1=0.436, d2=0.512, g=1.752, time=0.86 sec
# > epoch=5, batch=16/50, d1=0.423, d2=0.598, g=1.475, time=0.86 sec
# > epoch=5, batch=17/50, d1=0.378, d2=0.664, g=1.239, time=0.86 sec
# > epoch=5, batch=18/50, d1=0.454, d2=0.525, g=1.575, time=0.86 sec
# > epoch=5, batch=19/50, d1=0.360, d2=0.510, g=1.599, time=0.87 sec
# > epoch=5, batch=20/50, d1=0.369, d2=0.485, g=2.120, time=0.87 sec
# > epoch=5, batch=21/50, d1=0.346, d2=0.533, g=1.913, time=0.86 sec
# > epoch=5, batch=22/50, d1=0.297, d2=0.740, g=2.353, time=0.87 sec
# > epoch=5, batch=23/50, d1=0.653, d2=0.659, g=1.947, time=0.87 sec
# > epoch=5, batch=24/50, d1=0.502, d2=0.572, g=1.775, time=0.87 sec
# > epoch=5, batch=25/50, d1=0.440, d2=0.617, g=2.480, time=0.87 sec
# > epoch=5, batch=26/50, d1=0.441, d2=0.585, g=1.706, time=0.87 sec
# > epoch=5, batch=27/50, d1=0.392, d2=0.509, g=2.004, time=0.87 sec
# > epoch=5, batch=28/50, d1=0.421, d2=0.451, g=1.913, time=0.87 sec
# > epoch=5, batch=29/50, d1=0.322, d2=0.604, g=2.248, time=0.87 sec
# > epoch=5, batch=30/50, d1=0.392, d2=0.604, g=2.152, time=0.87 sec
# > epoch=5, batch=31/50, d1=0.438, d2=0.553, g=1.863, time=0.87 sec
# > epoch=5, batch=32/50, d1=0.442, d2=0.575, g=1.621, time=0.87 sec
# > epoch=5, batch=33/50, d1=0.249, d2=0.601, g=1.760, time=0.87 sec
# > epoch=5, batch=34/50, d1=0.367, d2=0.569, g=1.909, time=0.87 sec
# > epoch=5, batch=35/50, d1=0.441, d2=0.699, g=1.548, time=0.87 sec
# > epoch=5, batch=36/50, d1=0.436, d2=0.563, g=1.798, time=0.87 sec
# > epoch=5, batch=37/50, d1=0.436, d2=0.605, g=1.304, time=0.87 sec
# > epoch=5, batch=38/50, d1=0.328, d2=0.546, g=1.576, time=0.87 sec
# > epoch=5, batch=39/50, d1=0.414, d2=0.577, g=1.691, time=0.87 sec
# > epoch=5, batch=40/50, d1=0.323, d2=0.597, g=1.890, time=0.87 sec
# > epoch=5, batch=41/50, d1=0.395, d2=0.499, g=1.604, time=0.87 sec
# > epoch=5, batch=42/50, d1=0.400, d2=0.618, g=1.826, time=0.87 sec
# > epoch=5, batch=43/50, d1=0.432, d2=0.558, g=1.332, time=0.87 sec
# > epoch=5, batch=44/50, d1=0.408, d2=0.540, g=2.018, time=0.87 sec
# > epoch=5, batch=45/50, d1=0.354, d2=0.526, g=2.187, time=0.87 sec
# > epoch=5, batch=46/50, d1=0.395, d2=0.489, g=1.855, time=0.87 sec
# > epoch=5, batch=47/50, d1=0.351, d2=0.557, g=1.674, time=0.87 sec
# > epoch=5, batch=48/50, d1=0.348, d2=0.479, g=1.875, time=0.87 sec
# > epoch=5, batch=49/50, d1=0.385, d2=0.488, g=1.674, time=0.87 sec
# > epoch=5, batch=50/50, d1=0.382, d2=0.519, g=1.589, time=0.87 sec
#
# > epoch=6, batch=1/50, d1=0.358, d2=0.486, g=2.006, time=1.62 sec
# > epoch=6, batch=2/50, d1=0.398, d2=0.471, g=1.851, time=0.87 sec
# > epoch=6, batch=3/50, d1=0.239, d2=0.529, g=1.615, time=0.87 sec
# > epoch=6, batch=4/50, d1=0.216, d2=0.526, g=2.024, time=0.87 sec
# > epoch=6, batch=5/50, d1=0.453, d2=0.491, g=1.664, time=0.87 sec
# > epoch=6, batch=6/50, d1=0.374, d2=0.539, g=1.799, time=0.87 sec
# > epoch=6, batch=7/50, d1=0.302, d2=0.501, g=1.857, time=0.87 sec
# > epoch=6, batch=8/50, d1=0.384, d2=0.516, g=1.800, time=0.87 sec
# > epoch=6, batch=9/50, d1=0.251, d2=0.550, g=2.027, time=0.87 sec
# > epoch=6, batch=10/50, d1=0.474, d2=0.452, g=2.126, time=0.87 sec
# > epoch=6, batch=11/50, d1=0.437, d2=0.519, g=2.159, time=0.87 sec
# > epoch=6, batch=12/50, d1=0.291, d2=0.600, g=2.140, time=0.87 sec
# > epoch=6, batch=13/50, d1=0.437, d2=0.494, g=1.676, time=0.87 sec
# > epoch=6, batch=14/50, d1=0.309, d2=0.630, g=2.835, time=0.87 sec
# > epoch=6, batch=15/50, d1=0.521, d2=0.567, g=1.789, time=0.87 sec
# > epoch=6, batch=16/50, d1=0.314, d2=0.558, g=2.288, time=0.87 sec
# > epoch=6, batch=17/50, d1=0.489, d2=0.539, g=2.609, time=0.87 sec
# > epoch=6, batch=18/50, d1=0.412, d2=0.572, g=1.968, time=0.87 sec
# > epoch=6, batch=19/50, d1=0.389, d2=0.513, g=2.633, time=0.87 sec
# > epoch=6, batch=20/50, d1=0.494, d2=0.711, g=3.099, time=0.87 sec
# > epoch=6, batch=21/50, d1=0.499, d2=0.551, g=2.068, time=0.87 sec
# > epoch=6, batch=22/50, d1=0.327, d2=0.564, g=2.165, time=0.87 sec
# > epoch=6, batch=23/50, d1=0.430, d2=0.473, g=1.993, time=0.87 sec
# > epoch=6, batch=24/50, d1=0.357, d2=0.600, g=2.321, time=0.87 sec
# > epoch=6, batch=25/50, d1=0.527, d2=0.506, g=1.944, time=0.87 sec
# > epoch=6, batch=26/50, d1=0.391, d2=0.735, g=2.117, time=0.87 sec
# > epoch=6, batch=27/50, d1=0.439, d2=0.461, g=1.799, time=0.87 sec
# > epoch=6, batch=28/50, d1=0.432, d2=0.577, g=1.933, time=0.87 sec
# > epoch=6, batch=29/50, d1=0.330, d2=0.484, g=1.913, time=0.87 sec
# > epoch=6, batch=30/50, d1=0.483, d2=0.551, g=1.543, time=0.87 sec
# > epoch=6, batch=31/50, d1=0.289, d2=0.683, g=2.105, time=0.87 sec
# > epoch=6, batch=32/50, d1=0.347, d2=0.456, g=2.183, time=0.87 sec
# > epoch=6, batch=33/50, d1=0.374, d2=1.005, g=2.234, time=0.87 sec
# > epoch=6, batch=34/50, d1=0.544, d2=1.049, g=4.919, time=0.87 sec
# > epoch=6, batch=35/50, d1=1.099, d2=0.809, g=1.109, time=0.87 sec
# > epoch=6, batch=36/50, d1=0.287, d2=0.659, g=1.521, time=0.87 sec
# > epoch=6, batch=37/50, d1=0.562, d2=0.586, g=1.432, time=0.87 sec
# > epoch=6, batch=38/50, d1=0.355, d2=0.521, g=1.568, time=0.87 sec
# > epoch=6, batch=39/50, d1=0.442, d2=0.542, g=1.584, time=0.87 sec
# > epoch=6, batch=40/50, d1=0.369, d2=0.565, g=1.571, time=0.87 sec
# > epoch=6, batch=41/50, d1=0.483, d2=0.548, g=1.772, time=0.87 sec
# > epoch=6, batch=42/50, d1=0.390, d2=0.498, g=1.757, time=0.87 sec
# > epoch=6, batch=43/50, d1=0.424, d2=0.556, g=1.581, time=0.87 sec
# > epoch=6, batch=44/50, d1=0.418, d2=0.588, g=1.719, time=0.87 sec
# > epoch=6, batch=45/50, d1=0.383, d2=0.509, g=1.929, time=0.87 sec
# > epoch=6, batch=46/50, d1=0.389, d2=0.553, g=2.003, time=0.87 sec
# > epoch=6, batch=47/50, d1=0.553, d2=0.619, g=1.667, time=0.87 sec
# > epoch=6, batch=48/50, d1=0.368, d2=0.489, g=2.039, time=0.87 sec
# > epoch=6, batch=49/50, d1=0.471, d2=0.537, g=1.656, time=0.87 sec
# > epoch=6, batch=50/50, d1=0.328, d2=0.518, g=2.031, time=0.87 sec
#
# > epoch=7, batch=1/50, d1=0.301, d2=0.454, g=1.909, time=1.69 sec
# > epoch=7, batch=2/50, d1=0.341, d2=0.565, g=2.244, time=0.88 sec
# > epoch=7, batch=3/50, d1=0.549, d2=0.492, g=1.665, time=0.89 sec
# > epoch=7, batch=4/50, d1=0.330, d2=0.589, g=2.034, time=0.88 sec
# > epoch=7, batch=5/50, d1=0.415, d2=0.512, g=1.769, time=0.87 sec
# > epoch=7, batch=6/50, d1=0.318, d2=0.552, g=1.544, time=0.89 sec
# > epoch=7, batch=7/50, d1=0.405, d2=0.510, g=1.899, time=0.87 sec
# > epoch=7, batch=8/50, d1=0.354, d2=0.566, g=1.914, time=0.87 sec
# > epoch=7, batch=9/50, d1=0.393, d2=0.538, g=1.703, time=0.87 sec
# > epoch=7, batch=10/50, d1=0.321, d2=0.578, g=2.021, time=0.87 sec
# > epoch=7, batch=11/50, d1=0.373, d2=0.518, g=1.833, time=0.87 sec
# > epoch=7, batch=12/50, d1=0.322, d2=0.663, g=2.152, time=0.87 sec
# > epoch=7, batch=13/50, d1=0.303, d2=0.471, g=1.856, time=0.87 sec
# > epoch=7, batch=14/50, d1=0.372, d2=0.499, g=2.147, time=0.87 sec
# > epoch=7, batch=15/50, d1=0.465, d2=0.504, g=1.769, time=0.87 sec
# > epoch=7, batch=16/50, d1=0.424, d2=0.679, g=2.012, time=0.87 sec
# > epoch=7, batch=17/50, d1=0.345, d2=0.501, g=1.704, time=0.87 sec
# > epoch=7, batch=18/50, d1=0.369, d2=0.486, g=1.842, time=0.87 sec
# > epoch=7, batch=19/50, d1=0.213, d2=0.475, g=1.877, time=0.87 sec
# > epoch=7, batch=20/50, d1=0.385, d2=0.509, g=2.372, time=0.87 sec
# > epoch=7, batch=21/50, d1=0.489, d2=0.737, g=2.204, time=0.87 sec
# > epoch=7, batch=22/50, d1=0.609, d2=0.589, g=2.131, time=0.87 sec
# > epoch=7, batch=23/50, d1=0.506, d2=0.608, g=1.747, time=0.87 sec
# > epoch=7, batch=24/50, d1=0.394, d2=0.574, g=2.016, time=0.87 sec
# > epoch=7, batch=25/50, d1=0.452, d2=0.720, g=1.621, time=0.87 sec
# > epoch=7, batch=26/50, d1=0.370, d2=0.592, g=1.900, time=0.87 sec
# > epoch=7, batch=27/50, d1=0.503, d2=0.602, g=2.132, time=0.87 sec
# > epoch=7, batch=28/50, d1=0.523, d2=0.638, g=1.774, time=0.87 sec
# > epoch=7, batch=29/50, d1=0.417, d2=0.576, g=2.268, time=0.87 sec
# > epoch=7, batch=30/50, d1=0.444, d2=0.552, g=1.597, time=0.87 sec
# > epoch=7, batch=31/50, d1=0.349, d2=0.596, g=1.876, time=0.87 sec
# > epoch=7, batch=32/50, d1=0.460, d2=0.528, g=1.492, time=0.87 sec
# > epoch=7, batch=33/50, d1=0.380, d2=0.618, g=2.109, time=0.87 sec
# > epoch=7, batch=34/50, d1=0.536, d2=0.559, g=1.675, time=0.87 sec
# > epoch=7, batch=35/50, d1=0.378, d2=0.683, g=2.361, time=0.87 sec
# > epoch=7, batch=36/50, d1=0.376, d2=0.491, g=2.016, time=0.87 sec
# > epoch=7, batch=37/50, d1=0.302, d2=0.518, g=1.892, time=0.87 sec
# > epoch=7, batch=38/50, d1=0.327, d2=0.472, g=1.956, time=0.87 sec
# > epoch=7, batch=39/50, d1=0.342, d2=0.583, g=2.204, time=0.87 sec
# > epoch=7, batch=40/50, d1=0.425, d2=0.482, g=1.793, time=0.87 sec
# > epoch=7, batch=41/50, d1=0.397, d2=0.465, g=1.993, time=0.87 sec
# > epoch=7, batch=42/50, d1=0.448, d2=0.544, g=1.816, time=0.86 sec
# > epoch=7, batch=43/50, d1=0.411, d2=0.493, g=2.162, time=0.87 sec
# > epoch=7, batch=44/50, d1=0.394, d2=0.541, g=1.971, time=0.87 sec
# > epoch=7, batch=45/50, d1=0.371, d2=0.488, g=2.212, time=0.87 sec
# > epoch=7, batch=46/50, d1=0.445, d2=0.632, g=2.758, time=0.87 sec
# > epoch=7, batch=47/50, d1=0.622, d2=0.717, g=1.837, time=0.87 sec
# > epoch=7, batch=48/50, d1=0.380, d2=0.625, g=2.583, time=0.87 sec
# > epoch=7, batch=49/50, d1=0.461, d2=0.474, g=1.695, time=0.87 sec
# > epoch=7, batch=50/50, d1=0.194, d2=0.626, g=2.151, time=0.87 sec
#
# > epoch=8, batch=1/50, d1=0.470, d2=0.520, g=1.857, time=1.61 sec
# > epoch=8, batch=2/50, d1=0.403, d2=0.686, g=1.749, time=0.88 sec
# > epoch=8, batch=3/50, d1=0.456, d2=0.515, g=1.952, time=0.87 sec
# > epoch=8, batch=4/50, d1=0.427, d2=0.538, g=1.622, time=0.87 sec
# > epoch=8, batch=5/50, d1=0.446, d2=0.588, g=1.842, time=0.87 sec
# > epoch=8, batch=6/50, d1=0.357, d2=0.527, g=2.171, time=0.87 sec
# > epoch=8, batch=7/50, d1=0.518, d2=0.560, g=1.958, time=0.87 sec
# > epoch=8, batch=8/50, d1=0.414, d2=0.495, g=1.839, time=0.87 sec
# > epoch=8, batch=9/50, d1=0.363, d2=0.525, g=1.656, time=0.87 sec
# > epoch=8, batch=10/50, d1=0.371, d2=0.531, g=1.876, time=0.87 sec
# > epoch=8, batch=11/50, d1=0.412, d2=0.535, g=1.983, time=0.87 sec
# > epoch=8, batch=12/50, d1=0.402, d2=0.553, g=1.936, time=0.87 sec
# > epoch=8, batch=13/50, d1=0.434, d2=0.562, g=2.286, time=0.87 sec
# > epoch=8, batch=14/50, d1=0.420, d2=0.589, g=2.016, time=0.87 sec
# > epoch=8, batch=15/50, d1=0.442, d2=0.522, g=2.422, time=0.87 sec
# > epoch=8, batch=16/50, d1=0.513, d2=0.755, g=2.530, time=0.87 sec
# > epoch=8, batch=17/50, d1=0.509, d2=0.517, g=1.658, time=0.87 sec
# > epoch=8, batch=18/50, d1=0.468, d2=0.927, g=2.026, time=0.87 sec
# > epoch=8, batch=19/50, d1=0.660, d2=0.594, g=1.356, time=0.87 sec
# > epoch=8, batch=20/50, d1=0.424, d2=0.630, g=1.512, time=0.87 sec
# > epoch=8, batch=21/50, d1=0.453, d2=0.549, g=1.552, time=0.87 sec
# > epoch=8, batch=22/50, d1=0.422, d2=0.567, g=1.790, time=0.87 sec
# > epoch=8, batch=23/50, d1=0.447, d2=0.562, g=1.610, time=0.86 sec
# > epoch=8, batch=24/50, d1=0.400, d2=0.560, g=1.996, time=0.87 sec
# > epoch=8, batch=25/50, d1=0.467, d2=0.506, g=1.642, time=0.87 sec
# > epoch=8, batch=26/50, d1=0.333, d2=0.581, g=1.988, time=0.87 sec
# > epoch=8, batch=27/50, d1=0.455, d2=0.541, g=1.925, time=0.87 sec
# > epoch=8, batch=28/50, d1=0.357, d2=0.536, g=2.073, time=0.87 sec
# > epoch=8, batch=29/50, d1=0.367, d2=0.513, g=1.866, time=0.87 sec
# > epoch=8, batch=30/50, d1=0.340, d2=0.474, g=1.930, time=0.87 sec
# > epoch=8, batch=31/50, d1=0.350, d2=0.488, g=2.005, time=0.87 sec
# > epoch=8, batch=32/50, d1=0.385, d2=0.619, g=2.303, time=0.87 sec
# > epoch=8, batch=33/50, d1=0.430, d2=0.578, g=1.821, time=0.87 sec
# > epoch=8, batch=34/50, d1=0.276, d2=0.532, g=2.264, time=0.87 sec
# > epoch=8, batch=35/50, d1=0.482, d2=0.502, g=1.940, time=0.87 sec
# > epoch=8, batch=36/50, d1=0.489, d2=0.676, g=2.216, time=0.87 sec
# > epoch=8, batch=37/50, d1=0.592, d2=0.643, g=2.163, time=0.87 sec
# > epoch=8, batch=38/50, d1=0.453, d2=0.508, g=2.217, time=0.87 sec
# > epoch=8, batch=39/50, d1=0.443, d2=0.539, g=2.357, time=0.87 sec
# > epoch=8, batch=40/50, d1=0.441, d2=0.765, g=2.783, time=0.87 sec
# > epoch=8, batch=41/50, d1=0.491, d2=0.529, g=2.595, time=0.87 sec
# > epoch=8, batch=42/50, d1=0.456, d2=0.545, g=1.633, time=0.87 sec
# > epoch=8, batch=43/50, d1=0.264, d2=0.551, g=2.005, time=0.87 sec
# > epoch=8, batch=44/50, d1=0.430, d2=0.558, g=1.920, time=0.87 sec
# > epoch=8, batch=45/50, d1=0.416, d2=0.524, g=1.646, time=0.87 sec
# > epoch=8, batch=46/50, d1=0.335, d2=0.527, g=1.880, time=0.87 sec
# > epoch=8, batch=47/50, d1=0.323, d2=0.574, g=1.773, time=0.86 sec
# > epoch=8, batch=48/50, d1=0.376, d2=0.510, g=1.847, time=0.87 sec
# > epoch=8, batch=49/50, d1=0.348, d2=0.699, g=1.730, time=0.87 sec
# > epoch=8, batch=50/50, d1=0.518, d2=1.330, g=2.854, time=0.87 sec
#
# > epoch=9, batch=1/50, d1=0.722, d2=2.461, g=2.853, time=1.59 sec
# > epoch=9, batch=2/50, d1=0.706, d2=0.484, g=1.799, time=0.87 sec
# > epoch=9, batch=3/50, d1=0.410, d2=0.717, g=1.528, time=0.87 sec
# > epoch=9, batch=4/50, d1=0.456, d2=0.556, g=1.675, time=0.87 sec
# > epoch=9, batch=5/50, d1=0.453, d2=0.622, g=1.422, time=0.87 sec
# > epoch=9, batch=6/50, d1=0.338, d2=0.551, g=1.587, time=0.87 sec
# > epoch=9, batch=7/50, d1=0.437, d2=0.588, g=1.651, time=0.87 sec
# > epoch=9, batch=8/50, d1=0.381, d2=0.599, g=1.536, time=0.87 sec
# > epoch=9, batch=9/50, d1=0.426, d2=0.552, g=1.693, time=0.87 sec
# > epoch=9, batch=10/50, d1=0.452, d2=0.595, g=1.449, time=0.87 sec
# > epoch=9, batch=11/50, d1=0.405, d2=0.484, g=1.826, time=0.87 sec
# > epoch=9, batch=12/50, d1=0.378, d2=0.593, g=1.534, time=0.87 sec
# > epoch=9, batch=13/50, d1=0.344, d2=0.536, g=1.774, time=0.87 sec
# > epoch=9, batch=14/50, d1=0.380, d2=0.508, g=1.614, time=0.87 sec
# > epoch=9, batch=15/50, d1=0.400, d2=0.486, g=1.755, time=0.87 sec
# > epoch=9, batch=16/50, d1=0.503, d2=0.658, g=2.011, time=0.87 sec
# > epoch=9, batch=17/50, d1=0.502, d2=0.455, g=2.033, time=0.87 sec
# > epoch=9, batch=18/50, d1=0.474, d2=0.586, g=1.525, time=0.87 sec
# > epoch=9, batch=19/50, d1=0.385, d2=0.623, g=2.003, time=0.87 sec
# > epoch=9, batch=20/50, d1=0.506, d2=0.527, g=1.748, time=0.87 sec
# > epoch=9, batch=21/50, d1=0.443, d2=0.560, g=1.779, time=0.87 sec
# > epoch=9, batch=22/50, d1=0.466, d2=0.675, g=2.332, time=0.87 sec
# > epoch=9, batch=23/50, d1=0.606, d2=0.641, g=1.686, time=0.87 sec
# > epoch=9, batch=24/50, d1=0.426, d2=0.486, g=1.791, time=0.87 sec
# > epoch=9, batch=25/50, d1=0.345, d2=0.576, g=1.821, time=0.87 sec
# > epoch=9, batch=26/50, d1=0.355, d2=0.601, g=1.938, time=0.87 sec
# > epoch=9, batch=27/50, d1=0.434, d2=0.553, g=1.720, time=0.87 sec
# > epoch=9, batch=28/50, d1=0.446, d2=0.581, g=1.577, time=0.87 sec
# > epoch=9, batch=29/50, d1=0.489, d2=0.581, g=1.656, time=0.87 sec
# > epoch=9, batch=30/50, d1=0.395, d2=0.606, g=1.660, time=0.87 sec
# > epoch=9, batch=31/50, d1=0.508, d2=0.543, g=1.901, time=0.87 sec
# > epoch=9, batch=32/50, d1=0.346, d2=0.512, g=1.785, time=0.87 sec
# > epoch=9, batch=33/50, d1=0.362, d2=0.575, g=1.677, time=0.87 sec
# > epoch=9, batch=34/50, d1=0.400, d2=0.606, g=1.914, time=0.87 sec
# > epoch=9, batch=35/50, d1=0.400, d2=0.514, g=1.889, time=0.87 sec
# > epoch=9, batch=36/50, d1=0.327, d2=0.512, g=1.815, time=0.87 sec
# > epoch=9, batch=37/50, d1=0.392, d2=0.567, g=2.127, time=0.87 sec
# > epoch=9, batch=38/50, d1=0.453, d2=0.569, g=1.611, time=0.87 sec
# > epoch=9, batch=39/50, d1=0.401, d2=0.610, g=2.107, time=0.87 sec
# > epoch=9, batch=40/50, d1=0.419, d2=0.640, g=1.777, time=0.87 sec
# > epoch=9, batch=41/50, d1=0.321, d2=0.563, g=1.992, time=0.87 sec
# > epoch=9, batch=42/50, d1=0.443, d2=0.497, g=2.271, time=0.87 sec
# > epoch=9, batch=43/50, d1=0.546, d2=0.602, g=1.868, time=0.87 sec
# > epoch=9, batch=44/50, d1=0.432, d2=0.745, g=2.313, time=0.87 sec
# > epoch=9, batch=45/50, d1=0.603, d2=0.653, g=1.878, time=0.87 sec
# > epoch=9, batch=46/50, d1=0.579, d2=0.545, g=1.877, time=0.87 sec
# > epoch=9, batch=47/50, d1=0.352, d2=0.534, g=1.789, time=0.87 sec
# > epoch=9, batch=48/50, d1=0.390, d2=0.628, g=1.778, time=0.87 sec
# > epoch=9, batch=49/50, d1=0.480, d2=0.577, g=1.787, time=0.87 sec
# > epoch=9, batch=50/50, d1=0.364, d2=0.496, g=1.822, time=0.87 sec
#
# > epoch=10, batch=1/50, d1=0.425, d2=0.561, g=1.830, time=1.59 sec
# > epoch=10, batch=2/50, d1=0.468, d2=0.530, g=2.390, time=0.87 sec
# > epoch=10, batch=3/50, d1=0.422, d2=0.460, g=1.850, time=0.87 sec
# > epoch=10, batch=4/50, d1=0.413, d2=0.629, g=2.465, time=0.87 sec
# > epoch=10, batch=5/50, d1=0.483, d2=0.496, g=1.672, time=0.87 sec
# > epoch=10, batch=6/50, d1=0.469, d2=0.677, g=2.287, time=0.87 sec
# > epoch=10, batch=7/50, d1=0.498, d2=0.512, g=1.740, time=0.87 sec
# > epoch=10, batch=8/50, d1=0.389, d2=0.634, g=1.909, time=0.87 sec
# > epoch=10, batch=9/50, d1=0.420, d2=0.583, g=1.822, time=0.87 sec
# > epoch=10, batch=10/50, d1=0.437, d2=0.561, g=1.637, time=0.87 sec
# > epoch=10, batch=11/50, d1=0.366, d2=0.605, g=2.055, time=0.87 sec
# > epoch=10, batch=12/50, d1=0.444, d2=0.544, g=1.814, time=0.87 sec
# > epoch=10, batch=13/50, d1=0.348, d2=0.527, g=2.155, time=0.87 sec
# > epoch=10, batch=14/50, d1=0.413, d2=0.617, g=1.796, time=0.87 sec
# > epoch=10, batch=15/50, d1=0.365, d2=0.502, g=1.877, time=0.87 sec
# > epoch=10, batch=16/50, d1=0.457, d2=0.589, g=1.679, time=0.87 sec
# > epoch=10, batch=17/50, d1=0.453, d2=0.636, g=1.780, time=0.87 sec
# > epoch=10, batch=18/50, d1=0.381, d2=0.534, g=1.592, time=0.87 sec
# > epoch=10, batch=19/50, d1=0.349, d2=0.559, g=1.992, time=0.87 sec
# > epoch=10, batch=20/50, d1=0.440, d2=0.510, g=1.766, time=0.87 sec
# > epoch=10, batch=21/50, d1=0.403, d2=0.534, g=1.555, time=0.87 sec
# > epoch=10, batch=22/50, d1=0.380, d2=0.563, g=1.814, time=0.87 sec
# > epoch=10, batch=23/50, d1=0.394, d2=0.547, g=1.788, time=0.87 sec
# > epoch=10, batch=24/50, d1=0.345, d2=0.568, g=1.922, time=0.87 sec
# > epoch=10, batch=25/50, d1=0.421, d2=0.456, g=1.934, time=0.87 sec
# > epoch=10, batch=26/50, d1=0.484, d2=0.548, g=1.842, time=0.87 sec
# > epoch=10, batch=27/50, d1=0.357, d2=0.600, g=1.720, time=0.87 sec
# > epoch=10, batch=28/50, d1=0.357, d2=0.505, g=2.147, time=0.87 sec
# > epoch=10, batch=29/50, d1=0.410, d2=0.518, g=2.030, time=0.87 sec
# > epoch=10, batch=30/50, d1=0.395, d2=0.683, g=2.033, time=0.87 sec
# > epoch=10, batch=31/50, d1=0.482, d2=0.540, g=1.745, time=0.87 sec
# > epoch=10, batch=32/50, d1=0.493, d2=0.559, g=1.666, time=0.87 sec
# > epoch=10, batch=33/50, d1=0.484, d2=0.563, g=1.781, time=0.87 sec
# > epoch=10, batch=34/50, d1=0.303, d2=0.540, g=1.976, time=0.87 sec
# > epoch=10, batch=35/50, d1=0.376, d2=0.569, g=1.552, time=0.87 sec
# > epoch=10, batch=36/50, d1=0.416, d2=0.541, g=2.377, time=0.87 sec
# > epoch=10, batch=37/50, d1=0.475, d2=0.570, g=1.890, time=0.87 sec
# > epoch=10, batch=38/50, d1=0.476, d2=0.490, g=1.977, time=0.87 sec
# > epoch=10, batch=39/50, d1=0.424, d2=0.572, g=1.976, time=0.87 sec
# > epoch=10, batch=40/50, d1=0.313, d2=0.477, g=1.673, time=0.87 sec
# > epoch=10, batch=41/50, d1=0.359, d2=0.566, g=2.188, time=0.87 sec
# > epoch=10, batch=42/50, d1=0.426, d2=0.541, g=1.815, time=0.87 sec
# > epoch=10, batch=43/50, d1=0.393, d2=0.478, g=1.881, time=0.87 sec
# > epoch=10, batch=44/50, d1=0.386, d2=0.559, g=1.981, time=0.87 sec
# > epoch=10, batch=45/50, d1=0.459, d2=0.562, g=1.791, time=0.87 sec
# > epoch=10, batch=46/50, d1=0.445, d2=0.649, g=2.373, time=0.87 sec
# > epoch=10, batch=47/50, d1=0.541, d2=0.508, g=1.807, time=0.87 sec
# > epoch=10, batch=48/50, d1=0.373, d2=0.522, g=1.849, time=0.87 sec
# > epoch=10, batch=49/50, d1=0.350, d2=0.611, g=2.308, time=0.87 sec
# > epoch=10, batch=50/50, d1=0.505, d2=0.561, g=1.863, time=0.87 sec
#
# > epoch=11, batch=1/50, d1=0.404, d2=0.543, g=1.891, time=1.25 sec
# > epoch=11, batch=2/50, d1=0.368, d2=0.616, g=1.672, time=0.87 sec
# > epoch=11, batch=3/50, d1=0.408, d2=0.509, g=1.952, time=0.88 sec
# > epoch=11, batch=4/50, d1=0.511, d2=0.666, g=1.798, time=0.87 sec
# > epoch=11, batch=5/50, d1=0.447, d2=0.560, g=1.528, time=0.87 sec
# > epoch=11, batch=6/50, d1=0.438, d2=0.543, g=1.507, time=0.87 sec
# > epoch=11, batch=7/50, d1=0.420, d2=0.565, g=1.723, time=0.87 sec
# > epoch=11, batch=8/50, d1=0.427, d2=0.575, g=1.793, time=0.87 sec
# > epoch=11, batch=9/50, d1=0.503, d2=0.632, g=1.845, time=0.87 sec
# > epoch=11, batch=10/50, d1=0.438, d2=0.548, g=2.020, time=0.87 sec
# > epoch=11, batch=11/50, d1=0.314, d2=0.535, g=2.036, time=0.87 sec
# > epoch=11, batch=12/50, d1=0.505, d2=0.524, g=1.791, time=0.87 sec
# > epoch=11, batch=13/50, d1=0.319, d2=0.536, g=1.738, time=0.87 sec
# > epoch=11, batch=14/50, d1=0.355, d2=0.543, g=2.241, time=0.87 sec
# > epoch=11, batch=15/50, d1=0.404, d2=0.500, g=2.009, time=0.87 sec
# > epoch=11, batch=16/50, d1=0.519, d2=0.534, g=1.852, time=0.87 sec
# > epoch=11, batch=17/50, d1=0.351, d2=0.722, g=2.126, time=0.87 sec
# > epoch=11, batch=18/50, d1=0.491, d2=0.482, g=1.681, time=0.87 sec
# > epoch=11, batch=19/50, d1=0.582, d2=0.726, g=1.813, time=0.87 sec
# > epoch=11, batch=20/50, d1=0.563, d2=0.604, g=1.506, time=0.87 sec
# > epoch=11, batch=21/50, d1=0.336, d2=0.536, g=1.892, time=0.87 sec
# > epoch=11, batch=22/50, d1=0.367, d2=0.560, g=1.501, time=0.87 sec
# > epoch=11, batch=23/50, d1=0.428, d2=0.579, g=1.766, time=0.87 sec
# > epoch=11, batch=24/50, d1=0.414, d2=0.573, g=1.660, time=0.87 sec
# > epoch=11, batch=25/50, d1=0.327, d2=0.520, g=1.647, time=0.86 sec
# > epoch=11, batch=26/50, d1=0.466, d2=0.565, g=1.517, time=0.87 sec
# > epoch=11, batch=27/50, d1=0.314, d2=0.646, g=1.978, time=0.87 sec
# > epoch=11, batch=28/50, d1=0.473, d2=0.505, g=1.517, time=0.87 sec
# > epoch=11, batch=29/50, d1=0.303, d2=0.554, g=1.900, time=0.87 sec
# > epoch=11, batch=30/50, d1=0.373, d2=0.528, g=1.668, time=0.87 sec
# > epoch=11, batch=31/50, d1=0.435, d2=0.537, g=1.792, time=0.87 sec
# > epoch=11, batch=32/50, d1=0.425, d2=0.518, g=1.573, time=0.87 sec
# > epoch=11, batch=33/50, d1=0.293, d2=0.548, g=1.771, time=0.87 sec
# > epoch=11, batch=34/50, d1=0.359, d2=0.451, g=2.016, time=0.87 sec
# > epoch=11, batch=35/50, d1=0.462, d2=0.564, g=1.825, time=0.87 sec
# > epoch=11, batch=36/50, d1=0.368, d2=0.532, g=1.740, time=0.87 sec
# > epoch=11, batch=37/50, d1=0.505, d2=0.532, g=1.879, time=0.87 sec
# > epoch=11, batch=38/50, d1=0.346, d2=0.639, g=1.883, time=0.87 sec
# > epoch=11, batch=39/50, d1=0.400, d2=0.566, g=1.676, time=0.87 sec
# > epoch=11, batch=40/50, d1=0.403, d2=0.604, g=1.874, time=0.87 sec
# > epoch=11, batch=41/50, d1=0.526, d2=0.502, g=1.848, time=0.86 sec
# > epoch=11, batch=42/50, d1=0.407, d2=0.574, g=1.961, time=0.87 sec
# > epoch=11, batch=43/50, d1=0.436, d2=0.521, g=1.804, time=0.87 sec
# > epoch=11, batch=44/50, d1=0.399, d2=0.509, g=1.947, time=0.87 sec
# > epoch=11, batch=45/50, d1=0.468, d2=0.501, g=1.936, time=0.87 sec
# > epoch=11, batch=46/50, d1=0.534, d2=0.546, g=1.971, time=0.87 sec
# > epoch=11, batch=47/50, d1=0.471, d2=0.635, g=1.771, time=0.87 sec
# > epoch=11, batch=48/50, d1=0.361, d2=0.509, g=2.055, time=0.87 sec
# > epoch=11, batch=49/50, d1=0.287, d2=0.546, g=1.669, time=0.87 sec
# > epoch=11, batch=50/50, d1=0.457, d2=0.508, g=2.206, time=0.87 sec
#
# > epoch=12, batch=1/50, d1=0.370, d2=0.494, g=1.788, time=1.61 sec
# > epoch=12, batch=2/50, d1=0.369, d2=0.608, g=1.765, time=0.88 sec
# > epoch=12, batch=3/50, d1=0.353, d2=0.545, g=1.799, time=0.87 sec
# > epoch=12, batch=4/50, d1=0.378, d2=0.520, g=1.800, time=0.87 sec
# > epoch=12, batch=5/50, d1=0.424, d2=0.479, g=1.985, time=0.87 sec
# > epoch=12, batch=6/50, d1=0.450, d2=0.582, g=1.756, time=0.87 sec
# > epoch=12, batch=7/50, d1=0.375, d2=0.627, g=2.139, time=0.86 sec
# > epoch=12, batch=8/50, d1=0.596, d2=0.524, g=1.731, time=0.87 sec
# > epoch=12, batch=9/50, d1=0.422, d2=0.551, g=2.108, time=0.87 sec
# > epoch=12, batch=10/50, d1=0.401, d2=0.513, g=1.773, time=0.87 sec
# > epoch=12, batch=11/50, d1=0.406, d2=0.696, g=1.824, time=0.87 sec
# > epoch=12, batch=12/50, d1=0.392, d2=0.533, g=1.880, time=0.87 sec
# > epoch=12, batch=13/50, d1=0.381, d2=0.564, g=2.160, time=0.87 sec
# > epoch=12, batch=14/50, d1=0.387, d2=0.538, g=1.786, time=0.87 sec
# > epoch=12, batch=15/50, d1=0.386, d2=0.537, g=1.780, time=0.86 sec
# > epoch=12, batch=16/50, d1=0.380, d2=0.525, g=1.801, time=0.87 sec
# > epoch=12, batch=17/50, d1=0.346, d2=0.558, g=1.799, time=0.87 sec
# > epoch=12, batch=18/50, d1=0.350, d2=0.565, g=2.189, time=0.87 sec
# > epoch=12, batch=19/50, d1=0.468, d2=0.563, g=2.011, time=0.87 sec
# > epoch=12, batch=20/50, d1=0.364, d2=0.482, g=2.322, time=0.87 sec
# > epoch=12, batch=21/50, d1=0.383, d2=0.578, g=1.972, time=0.87 sec
# > epoch=12, batch=22/50, d1=0.386, d2=0.513, g=1.893, time=0.87 sec
# > epoch=12, batch=23/50, d1=0.550, d2=0.511, g=2.000, time=0.87 sec
# > epoch=12, batch=24/50, d1=0.543, d2=0.598, g=2.085, time=0.87 sec
# > epoch=12, batch=25/50, d1=0.345, d2=0.534, g=2.091, time=0.87 sec
# > epoch=12, batch=26/50, d1=0.321, d2=0.593, g=2.372, time=0.87 sec
# > epoch=12, batch=27/50, d1=0.379, d2=0.686, g=2.677, time=0.87 sec
# > epoch=12, batch=28/50, d1=0.462, d2=0.526, g=1.905, time=0.87 sec
# > epoch=12, batch=29/50, d1=0.393, d2=0.645, g=2.018, time=0.87 sec
# > epoch=12, batch=30/50, d1=0.409, d2=0.530, g=1.648, time=0.87 sec
# > epoch=12, batch=31/50, d1=0.325, d2=0.686, g=2.122, time=0.87 sec
# > epoch=12, batch=32/50, d1=0.556, d2=0.562, g=1.654, time=0.87 sec
# > epoch=12, batch=33/50, d1=0.451, d2=0.600, g=2.043, time=0.87 sec
# > epoch=12, batch=34/50, d1=0.527, d2=0.544, g=1.784, time=0.87 sec
# > epoch=12, batch=35/50, d1=0.329, d2=0.566, g=1.673, time=0.87 sec
# > epoch=12, batch=36/50, d1=0.350, d2=0.550, g=1.956, time=0.87 sec
# > epoch=12, batch=37/50, d1=0.379, d2=0.492, g=1.653, time=0.87 sec
# > epoch=12, batch=38/50, d1=0.298, d2=0.651, g=2.323, time=0.87 sec
# > epoch=12, batch=39/50, d1=0.376, d2=0.496, g=1.773, time=0.87 sec
# > epoch=12, batch=40/50, d1=0.370, d2=0.633, g=1.980, time=0.87 sec
# > epoch=12, batch=41/50, d1=0.423, d2=0.509, g=1.575, time=0.87 sec
# > epoch=12, batch=42/50, d1=0.375, d2=0.626, g=1.773, time=0.87 sec
# > epoch=12, batch=43/50, d1=0.299, d2=0.530, g=1.859, time=0.87 sec
# > epoch=12, batch=44/50, d1=0.387, d2=0.548, g=1.845, time=0.87 sec
# > epoch=12, batch=45/50, d1=0.447, d2=0.638, g=2.067, time=0.87 sec
# > epoch=12, batch=46/50, d1=0.358, d2=0.538, g=1.766, time=0.87 sec
# > epoch=12, batch=47/50, d1=0.413, d2=0.577, g=2.142, time=0.87 sec
# > epoch=12, batch=48/50, d1=0.410, d2=0.474, g=1.819, time=0.87 sec
# > epoch=12, batch=49/50, d1=0.393, d2=0.566, g=2.154, time=0.87 sec
# > epoch=12, batch=50/50, d1=0.383, d2=0.489, g=1.766, time=0.87 sec
#
# > epoch=13, batch=1/50, d1=0.377, d2=0.652, g=2.126, time=1.62 sec
# > epoch=13, batch=2/50, d1=0.396, d2=0.514, g=2.224, time=0.88 sec
# > epoch=13, batch=3/50, d1=0.425, d2=0.619, g=2.140, time=0.87 sec
# > epoch=13, batch=4/50, d1=0.376, d2=0.496, g=1.958, time=0.87 sec
# > epoch=13, batch=5/50, d1=0.466, d2=0.581, g=1.895, time=0.87 sec
# > epoch=13, batch=6/50, d1=0.479, d2=0.709, g=2.033, time=0.87 sec
# > epoch=13, batch=7/50, d1=0.408, d2=0.542, g=1.656, time=0.87 sec
# > epoch=13, batch=8/50, d1=0.329, d2=0.606, g=1.773, time=0.87 sec
# > epoch=13, batch=9/50, d1=0.478, d2=0.552, g=1.680, time=0.87 sec
# > epoch=13, batch=10/50, d1=0.392, d2=0.581, g=1.669, time=0.87 sec
# > epoch=13, batch=11/50, d1=0.391, d2=0.530, g=1.708, time=0.87 sec
# > epoch=13, batch=12/50, d1=0.389, d2=0.534, g=1.804, time=0.87 sec
# > epoch=13, batch=13/50, d1=0.332, d2=0.530, g=1.838, time=0.87 sec
# > epoch=13, batch=14/50, d1=0.366, d2=0.607, g=2.034, time=0.87 sec
# > epoch=13, batch=15/50, d1=0.460, d2=0.546, g=1.825, time=0.87 sec
# > epoch=13, batch=16/50, d1=0.428, d2=0.538, g=1.602, time=0.87 sec
# > epoch=13, batch=17/50, d1=0.324, d2=0.586, g=2.119, time=0.87 sec
# > epoch=13, batch=18/50, d1=0.437, d2=0.469, g=1.667, time=0.87 sec
# > epoch=13, batch=19/50, d1=0.404, d2=0.629, g=2.008, time=0.87 sec
# > epoch=13, batch=20/50, d1=0.476, d2=0.443, g=1.882, time=0.87 sec
# > epoch=13, batch=21/50, d1=0.328, d2=0.536, g=1.754, time=0.87 sec
# > epoch=13, batch=22/50, d1=0.485, d2=0.587, g=1.776, time=0.87 sec
# > epoch=13, batch=23/50, d1=0.427, d2=0.537, g=1.848, time=0.87 sec
# > epoch=13, batch=24/50, d1=0.289, d2=0.533, g=1.805, time=0.87 sec
# > epoch=13, batch=25/50, d1=0.412, d2=0.574, g=2.417, time=0.87 sec
# > epoch=13, batch=26/50, d1=0.495, d2=0.527, g=1.501, time=0.87 sec
# > epoch=13, batch=27/50, d1=0.347, d2=0.596, g=2.056, time=0.87 sec
# > epoch=13, batch=28/50, d1=0.460, d2=0.561, g=1.789, time=0.87 sec
# > epoch=13, batch=29/50, d1=0.412, d2=0.627, g=1.885, time=0.87 sec
# > epoch=13, batch=30/50, d1=0.539, d2=0.540, g=2.028, time=0.87 sec
# > epoch=13, batch=31/50, d1=0.374, d2=0.493, g=2.016, time=0.87 sec
# > epoch=13, batch=32/50, d1=0.281, d2=0.532, g=2.112, time=0.87 sec
# > epoch=13, batch=33/50, d1=0.456, d2=0.589, g=1.951, time=0.87 sec
# > epoch=13, batch=34/50, d1=0.391, d2=0.647, g=2.082, time=0.87 sec
# > epoch=13, batch=35/50, d1=0.412, d2=0.748, g=3.549, time=0.87 sec
# > epoch=13, batch=36/50, d1=0.876, d2=0.593, g=1.549, time=0.87 sec
# > epoch=13, batch=37/50, d1=0.326, d2=0.590, g=1.765, time=0.87 sec
# > epoch=13, batch=38/50, d1=0.517, d2=0.600, g=1.929, time=0.87 sec
# > epoch=13, batch=39/50, d1=0.458, d2=0.516, g=1.922, time=0.87 sec
# > epoch=13, batch=40/50, d1=0.400, d2=0.492, g=1.676, time=0.87 sec
# > epoch=13, batch=41/50, d1=0.398, d2=0.572, g=1.962, time=0.87 sec
# > epoch=13, batch=42/50, d1=0.463, d2=0.758, g=1.940, time=0.87 sec
# > epoch=13, batch=43/50, d1=0.478, d2=0.513, g=1.930, time=0.87 sec
# > epoch=13, batch=44/50, d1=0.450, d2=0.534, g=1.568, time=0.87 sec
# > epoch=13, batch=45/50, d1=0.300, d2=0.578, g=2.318, time=0.87 sec
# > epoch=13, batch=46/50, d1=0.450, d2=0.633, g=2.082, time=0.87 sec
# > epoch=13, batch=47/50, d1=0.385, d2=0.562, g=2.124, time=0.87 sec
# ...
# > epoch=196, batch=20/50, d1=0.500, d2=0.590, g=1.749, time=0.87 sec
# > epoch=196, batch=21/50, d1=0.351, d2=0.597, g=1.642, time=0.87 sec
# > epoch=196, batch=22/50, d1=0.411, d2=0.515, g=1.601, time=0.86 sec
# > epoch=196, batch=23/50, d1=0.417, d2=0.546, g=1.757, time=0.86 sec
# > epoch=196, batch=24/50, d1=0.419, d2=0.581, g=1.766, time=0.87 sec
# > epoch=196, batch=25/50, d1=0.324, d2=0.581, g=2.048, time=0.86 sec
# > epoch=196, batch=26/50, d1=0.495, d2=0.549, g=1.481, time=0.87 sec
# > epoch=196, batch=27/50, d1=0.446, d2=0.525, g=1.917, time=0.86 sec
# > epoch=196, batch=28/50, d1=0.397, d2=0.528, g=1.762, time=0.87 sec
# > epoch=196, batch=29/50, d1=0.411, d2=0.601, g=1.568, time=0.87 sec
# > epoch=196, batch=30/50, d1=0.384, d2=0.556, g=1.815, time=0.86 sec
# > epoch=196, batch=31/50, d1=0.367, d2=0.612, g=1.618, time=0.87 sec
# > epoch=196, batch=32/50, d1=0.406, d2=0.589, g=1.828, time=0.87 sec
# > epoch=196, batch=33/50, d1=0.340, d2=0.591, g=2.218, time=0.87 sec
# > epoch=196, batch=34/50, d1=0.559, d2=0.484, g=1.758, time=0.87 sec
# > epoch=196, batch=35/50, d1=0.307, d2=0.611, g=1.600, time=0.87 sec
# > epoch=196, batch=36/50, d1=0.363, d2=0.527, g=1.804, time=0.87 sec
# > epoch=196, batch=37/50, d1=0.309, d2=0.546, g=1.841, time=0.87 sec
# > epoch=196, batch=38/50, d1=0.347, d2=0.541, g=2.150, time=0.87 sec
# > epoch=196, batch=39/50, d1=0.389, d2=0.530, g=1.818, time=0.87 sec
# > epoch=196, batch=40/50, d1=0.445, d2=0.563, g=1.761, time=0.87 sec
# > epoch=196, batch=41/50, d1=0.332, d2=0.552, g=1.937, time=0.87 sec
# > epoch=196, batch=42/50, d1=0.444, d2=0.549, g=1.662, time=0.87 sec
# > epoch=196, batch=43/50, d1=0.367, d2=0.604, g=1.645, time=0.87 sec
# > epoch=196, batch=44/50, d1=0.436, d2=0.541, g=2.022, time=0.87 sec
# > epoch=196, batch=45/50, d1=0.476, d2=0.589, g=1.443, time=0.87 sec
# > epoch=196, batch=46/50, d1=0.486, d2=0.653, g=1.800, time=0.87 sec
# > epoch=196, batch=47/50, d1=0.371, d2=0.570, g=1.666, time=0.87 sec
# > epoch=196, batch=48/50, d1=0.352, d2=0.557, g=1.609, time=0.86 sec
# > epoch=196, batch=49/50, d1=0.304, d2=0.580, g=1.750, time=0.87 sec
# > epoch=196, batch=50/50, d1=0.357, d2=0.538, g=1.694, time=0.87 sec
#
# > epoch=197, batch=1/50, d1=0.303, d2=0.549, g=1.607, time=2.95 sec
# > epoch=197, batch=2/50, d1=0.387, d2=0.609, g=2.231, time=0.86 sec
# > epoch=197, batch=3/50, d1=0.449, d2=0.532, g=1.941, time=0.87 sec
# > epoch=197, batch=4/50, d1=0.406, d2=0.585, g=1.673, time=0.87 sec
# > epoch=197, batch=5/50, d1=0.393, d2=0.511, g=1.926, time=0.87 sec
# > epoch=197, batch=6/50, d1=0.497, d2=0.531, g=1.740, time=0.87 sec
# > epoch=197, batch=7/50, d1=0.399, d2=0.616, g=1.933, time=0.87 sec
# > epoch=197, batch=8/50, d1=0.447, d2=0.598, g=1.582, time=0.87 sec
# > epoch=197, batch=9/50, d1=0.448, d2=0.583, g=1.536, time=0.87 sec
# > epoch=197, batch=10/50, d1=0.453, d2=0.580, g=1.761, time=0.87 sec
# > epoch=197, batch=11/50, d1=0.503, d2=0.606, g=1.610, time=0.87 sec
# > epoch=197, batch=12/50, d1=0.395, d2=0.592, g=1.626, time=0.87 sec
# > epoch=197, batch=13/50, d1=0.425, d2=0.581, g=2.003, time=0.87 sec
# > epoch=197, batch=14/50, d1=0.525, d2=0.625, g=1.696, time=0.87 sec
# > epoch=197, batch=15/50, d1=0.379, d2=0.526, g=1.637, time=0.87 sec
# > epoch=197, batch=16/50, d1=0.464, d2=0.618, g=1.726, time=0.87 sec
# > epoch=197, batch=17/50, d1=0.404, d2=0.566, g=1.522, time=0.87 sec
# > epoch=197, batch=18/50, d1=0.452, d2=0.578, g=1.568, time=0.86 sec
# > epoch=197, batch=19/50, d1=0.364, d2=0.613, g=1.840, time=0.87 sec
# > epoch=197, batch=20/50, d1=0.359, d2=0.607, g=1.724, time=0.87 sec
# > epoch=197, batch=21/50, d1=0.438, d2=0.524, g=1.944, time=0.87 sec
# > epoch=197, batch=22/50, d1=0.357, d2=0.584, g=1.514, time=0.87 sec
# > epoch=197, batch=23/50, d1=0.523, d2=0.534, g=1.917, time=0.87 sec
# > epoch=197, batch=24/50, d1=0.389, d2=0.546, g=1.694, time=0.86 sec
# > epoch=197, batch=25/50, d1=0.412, d2=0.637, g=1.970, time=0.87 sec
# > epoch=197, batch=26/50, d1=0.413, d2=0.550, g=1.940, time=0.87 sec
# > epoch=197, batch=27/50, d1=0.513, d2=0.509, g=1.767, time=0.87 sec
# > epoch=197, batch=28/50, d1=0.350, d2=0.560, g=1.705, time=0.87 sec
# > epoch=197, batch=29/50, d1=0.429, d2=0.587, g=1.741, time=0.87 sec
# > epoch=197, batch=30/50, d1=0.421, d2=0.565, g=1.679, time=0.87 sec
# > epoch=197, batch=31/50, d1=0.466, d2=0.491, g=1.602, time=0.87 sec
# > epoch=197, batch=32/50, d1=0.289, d2=0.565, g=1.869, time=0.87 sec
# > epoch=197, batch=33/50, d1=0.413, d2=0.595, g=2.032, time=0.87 sec
# > epoch=197, batch=34/50, d1=0.496, d2=0.568, g=1.787, time=0.87 sec
# > epoch=197, batch=35/50, d1=0.333, d2=0.622, g=1.863, time=0.87 sec
# > epoch=197, batch=36/50, d1=0.332, d2=0.549, g=1.787, time=0.88 sec
# > epoch=197, batch=37/50, d1=0.382, d2=0.560, g=1.850, time=0.87 sec
# > epoch=197, batch=38/50, d1=0.492, d2=0.615, g=2.027, time=0.87 sec
# > epoch=197, batch=39/50, d1=0.386, d2=0.587, g=1.651, time=0.87 sec
# > epoch=197, batch=40/50, d1=0.370, d2=0.599, g=1.730, time=0.87 sec
# > epoch=197, batch=41/50, d1=0.451, d2=0.581, g=1.811, time=0.87 sec
# > epoch=197, batch=42/50, d1=0.467, d2=0.580, g=1.638, time=0.87 sec
# > epoch=197, batch=43/50, d1=0.451, d2=0.592, g=1.611, time=0.87 sec
# > epoch=197, batch=44/50, d1=0.315, d2=0.636, g=2.247, time=0.87 sec
# > epoch=197, batch=45/50, d1=0.527, d2=0.551, g=1.704, time=0.87 sec
# > epoch=197, batch=46/50, d1=0.248, d2=0.558, g=1.709, time=0.87 sec
# > epoch=197, batch=47/50, d1=0.386, d2=0.531, g=1.811, time=0.87 sec
# > epoch=197, batch=48/50, d1=0.444, d2=0.638, g=1.473, time=0.87 sec
# > epoch=197, batch=49/50, d1=0.304, d2=0.548, g=1.778, time=0.87 sec
# > epoch=197, batch=50/50, d1=0.345, d2=0.593, g=1.878, time=0.87 sec
#
# > epoch=198, batch=1/50, d1=0.463, d2=0.527, g=1.621, time=1.25 sec
# > epoch=198, batch=2/50, d1=0.435, d2=0.650, g=2.056, time=0.87 sec
# > epoch=198, batch=3/50, d1=0.472, d2=0.557, g=1.836, time=0.87 sec
# > epoch=198, batch=4/50, d1=0.400, d2=0.532, g=1.805, time=0.87 sec
# > epoch=198, batch=5/50, d1=0.360, d2=0.573, g=1.898, time=0.87 sec
# > epoch=198, batch=6/50, d1=0.413, d2=0.562, g=2.111, time=0.87 sec
# > epoch=198, batch=7/50, d1=0.424, d2=0.622, g=1.741, time=0.87 sec
# > epoch=198, batch=8/50, d1=0.380, d2=0.633, g=1.909, time=0.87 sec
# > epoch=198, batch=9/50, d1=0.387, d2=0.600, g=1.913, time=0.87 sec
# > epoch=198, batch=10/50, d1=0.326, d2=0.556, g=1.606, time=0.87 sec
# > epoch=198, batch=11/50, d1=0.398, d2=0.775, g=1.910, time=0.87 sec
# > epoch=198, batch=12/50, d1=0.359, d2=0.531, g=1.897, time=0.87 sec
# > epoch=198, batch=13/50, d1=0.410, d2=0.610, g=1.737, time=0.87 sec
# > epoch=198, batch=14/50, d1=0.432, d2=0.570, g=1.646, time=0.87 sec
# > epoch=198, batch=15/50, d1=0.322, d2=0.599, g=1.846, time=0.87 sec
# > epoch=198, batch=16/50, d1=0.362, d2=0.570, g=1.654, time=0.87 sec
# > epoch=198, batch=17/50, d1=0.404, d2=0.530, g=1.744, time=0.87 sec
# > epoch=198, batch=18/50, d1=0.424, d2=0.567, g=1.574, time=0.87 sec
# > epoch=198, batch=19/50, d1=0.380, d2=0.628, g=2.036, time=0.87 sec
# > epoch=198, batch=20/50, d1=0.511, d2=0.515, g=1.598, time=0.87 sec
# > epoch=198, batch=21/50, d1=0.443, d2=0.589, g=1.982, time=0.87 sec
# > epoch=198, batch=22/50, d1=0.506, d2=0.521, g=1.744, time=0.87 sec
# > epoch=198, batch=23/50, d1=0.448, d2=0.554, g=1.911, time=0.87 sec
# > epoch=198, batch=24/50, d1=0.470, d2=0.581, g=1.643, time=0.87 sec
# > epoch=198, batch=25/50, d1=0.350, d2=0.564, g=1.840, time=0.87 sec
# > epoch=198, batch=26/50, d1=0.409, d2=0.544, g=1.931, time=0.87 sec
# > epoch=198, batch=27/50, d1=0.428, d2=0.613, g=1.728, time=0.87 sec
# > epoch=198, batch=28/50, d1=0.512, d2=0.599, g=1.736, time=0.87 sec
# > epoch=198, batch=29/50, d1=0.394, d2=0.577, g=1.797, time=0.87 sec
# > epoch=198, batch=30/50, d1=0.323, d2=0.598, g=2.119, time=0.87 sec
# > epoch=198, batch=31/50, d1=0.420, d2=0.528, g=1.823, time=0.87 sec
# > epoch=198, batch=32/50, d1=0.480, d2=0.638, g=2.155, time=0.87 sec
# > epoch=198, batch=33/50, d1=0.500, d2=0.463, g=2.022, time=0.87 sec
# > epoch=198, batch=34/50, d1=0.496, d2=0.573, g=1.791, time=0.87 sec
# > epoch=198, batch=35/50, d1=0.449, d2=0.554, g=1.687, time=0.87 sec
# > epoch=198, batch=36/50, d1=0.359, d2=0.574, g=1.827, time=0.86 sec
# > epoch=198, batch=37/50, d1=0.469, d2=0.569, g=2.049, time=0.87 sec
# > epoch=198, batch=38/50, d1=0.556, d2=0.492, g=1.817, time=0.87 sec
# > epoch=198, batch=39/50, d1=0.510, d2=0.642, g=1.852, time=0.87 sec
# > epoch=198, batch=40/50, d1=0.463, d2=0.560, g=1.654, time=0.87 sec
# > epoch=198, batch=41/50, d1=0.384, d2=0.548, g=1.649, time=0.87 sec
# > epoch=198, batch=42/50, d1=0.318, d2=0.649, g=1.703, time=0.87 sec
# > epoch=198, batch=43/50, d1=0.379, d2=0.577, g=1.867, time=0.87 sec
# > epoch=198, batch=44/50, d1=0.404, d2=0.607, g=1.520, time=0.87 sec
# > epoch=198, batch=45/50, d1=0.434, d2=0.556, g=1.826, time=0.87 sec
# > epoch=198, batch=46/50, d1=0.442, d2=0.709, g=1.710, time=0.87 sec
# > epoch=198, batch=47/50, d1=0.429, d2=0.593, g=1.638, time=0.87 sec
# > epoch=198, batch=48/50, d1=0.385, d2=0.596, g=1.665, time=0.87 sec
# > epoch=198, batch=49/50, d1=0.297, d2=0.544, g=1.523, time=0.87 sec
# > epoch=198, batch=50/50, d1=0.358, d2=0.523, g=1.769, time=0.87 sec
#
# > epoch=199, batch=1/50, d1=0.358, d2=0.568, g=1.976, time=1.63 sec
# > epoch=199, batch=2/50, d1=0.412, d2=0.632, g=1.920, time=0.86 sec
# > epoch=199, batch=3/50, d1=0.450, d2=0.544, g=1.893, time=0.87 sec
# > epoch=199, batch=4/50, d1=0.413, d2=0.434, g=1.754, time=0.87 sec
# > epoch=199, batch=5/50, d1=0.328, d2=0.725, g=1.824, time=0.87 sec
# > epoch=199, batch=6/50, d1=0.573, d2=0.545, g=1.793, time=0.86 sec
# > epoch=199, batch=7/50, d1=0.381, d2=0.556, g=1.587, time=0.87 sec
# > epoch=199, batch=8/50, d1=0.227, d2=0.629, g=1.618, time=0.86 sec
# > epoch=199, batch=9/50, d1=0.340, d2=0.626, g=2.011, time=0.86 sec
# > epoch=199, batch=10/50, d1=0.378, d2=0.556, g=1.724, time=0.86 sec
# > epoch=199, batch=11/50, d1=0.469, d2=0.554, g=1.897, time=0.87 sec
# > epoch=199, batch=12/50, d1=0.475, d2=0.557, g=1.771, time=0.87 sec
# > epoch=199, batch=13/50, d1=0.458, d2=0.546, g=1.684, time=0.87 sec
# > epoch=199, batch=14/50, d1=0.291, d2=0.584, g=1.584, time=0.87 sec
# > epoch=199, batch=15/50, d1=0.320, d2=0.580, g=1.851, time=0.87 sec
# > epoch=199, batch=16/50, d1=0.457, d2=0.533, g=1.816, time=0.87 sec
# > epoch=199, batch=17/50, d1=0.382, d2=0.649, g=1.763, time=0.87 sec
# > epoch=199, batch=18/50, d1=0.436, d2=0.566, g=2.039, time=0.87 sec
# > epoch=199, batch=19/50, d1=0.347, d2=0.537, g=1.731, time=0.87 sec
# > epoch=199, batch=20/50, d1=0.371, d2=0.616, g=2.197, time=0.87 sec
# > epoch=199, batch=21/50, d1=0.436, d2=0.575, g=1.640, time=0.87 sec
# > epoch=199, batch=22/50, d1=0.280, d2=0.634, g=1.832, time=0.87 sec
# > epoch=199, batch=23/50, d1=0.379, d2=0.511, g=1.931, time=0.87 sec
# > epoch=199, batch=24/50, d1=0.401, d2=0.607, g=1.555, time=0.87 sec
# > epoch=199, batch=25/50, d1=0.347, d2=0.601, g=1.652, time=0.87 sec
# > epoch=199, batch=26/50, d1=0.346, d2=0.568, g=1.744, time=0.87 sec
# > epoch=199, batch=27/50, d1=0.406, d2=0.508, g=1.791, time=0.87 sec
# > epoch=199, batch=28/50, d1=0.355, d2=0.557, g=1.563, time=0.87 sec
# > epoch=199, batch=29/50, d1=0.388, d2=0.636, g=1.984, time=0.87 sec
# > epoch=199, batch=30/50, d1=0.439, d2=0.496, g=1.803, time=0.87 sec
# > epoch=199, batch=31/50, d1=0.486, d2=0.598, g=1.490, time=0.87 sec
# > epoch=199, batch=32/50, d1=0.441, d2=0.612, g=1.518, time=0.87 sec
# > epoch=199, batch=33/50, d1=0.436, d2=0.548, g=1.824, time=0.87 sec
# > epoch=199, batch=34/50, d1=0.447, d2=0.584, g=1.770, time=0.87 sec
# > epoch=199, batch=35/50, d1=0.399, d2=0.527, g=1.481, time=0.87 sec
# > epoch=199, batch=36/50, d1=0.472, d2=0.618, g=1.960, time=0.87 sec
# > epoch=199, batch=37/50, d1=0.406, d2=0.585, g=1.760, time=0.87 sec
# > epoch=199, batch=38/50, d1=0.420, d2=0.591, g=1.961, time=0.87 sec
# > epoch=199, batch=39/50, d1=0.483, d2=0.580, g=1.876, time=0.87 sec
# > epoch=199, batch=40/50, d1=0.411, d2=0.574, g=1.537, time=0.87 sec
# > epoch=199, batch=41/50, d1=0.415, d2=0.634, g=1.852, time=0.87 sec
# > epoch=199, batch=42/50, d1=0.511, d2=0.583, g=1.417, time=0.87 sec
# > epoch=199, batch=43/50, d1=0.345, d2=0.601, g=1.458, time=0.87 sec
# > epoch=199, batch=44/50, d1=0.288, d2=0.590, g=1.662, time=0.87 sec
# > epoch=199, batch=45/50, d1=0.359, d2=0.670, g=1.937, time=0.87 sec
# > epoch=199, batch=46/50, d1=0.403, d2=0.523, g=1.733, time=0.87 sec
# > epoch=199, batch=47/50, d1=0.372, d2=0.529, g=1.526, time=0.87 sec
# > epoch=199, batch=48/50, d1=0.254, d2=0.678, g=1.950, time=0.87 sec
# > epoch=199, batch=49/50, d1=0.427, d2=0.535, g=1.698, time=0.87 sec
# > epoch=199, batch=50/50, d1=0.340, d2=0.636, g=1.787, time=0.87 sec
#
# > epoch=200, batch=1/50, d1=0.476, d2=0.559, g=1.711, time=3.50 sec
# > epoch=200, batch=2/50, d1=0.396, d2=0.657, g=1.825, time=0.86 sec
# > epoch=200, batch=3/50, d1=0.406, d2=0.588, g=1.862, time=0.87 sec
# > epoch=200, batch=4/50, d1=0.460, d2=0.508, g=1.685, time=0.87 sec
# > epoch=200, batch=5/50, d1=0.412, d2=0.591, g=1.862, time=0.87 sec
# > epoch=200, batch=6/50, d1=0.468, d2=0.558, g=1.793, time=0.87 sec
# > epoch=200, batch=7/50, d1=0.403, d2=0.501, g=1.609, time=0.87 sec
# > epoch=200, batch=8/50, d1=0.355, d2=0.530, g=1.702, time=0.87 sec
# > epoch=200, batch=9/50, d1=0.408, d2=0.649, g=1.608, time=0.87 sec
# > epoch=200, batch=10/50, d1=0.455, d2=0.508, g=1.998, time=0.87 sec
# > epoch=200, batch=11/50, d1=0.498, d2=0.645, g=1.681, time=0.87 sec
# > epoch=200, batch=12/50, d1=0.332, d2=0.556, g=1.777, time=0.87 sec
# > epoch=200, batch=13/50, d1=0.436, d2=0.595, g=1.658, time=0.87 sec
# > epoch=200, batch=14/50, d1=0.493, d2=0.554, g=1.872, time=0.87 sec
# > epoch=200, batch=15/50, d1=0.409, d2=0.521, g=1.656, time=0.87 sec
# > epoch=200, batch=16/50, d1=0.456, d2=0.565, g=1.788, time=0.87 sec
# > epoch=200, batch=17/50, d1=0.410, d2=0.494, g=1.762, time=0.87 sec
# > epoch=200, batch=18/50, d1=0.454, d2=0.769, g=1.844, time=0.87 sec
# > epoch=200, batch=19/50, d1=0.265, d2=0.543, g=1.943, time=0.87 sec
# > epoch=200, batch=20/50, d1=0.390, d2=0.476, g=1.811, time=0.87 sec
# > epoch=200, batch=21/50, d1=0.327, d2=0.594, g=2.002, time=0.87 sec
# > epoch=200, batch=22/50, d1=0.440, d2=0.504, g=1.973, time=0.87 sec
# > epoch=200, batch=23/50, d1=0.472, d2=0.574, g=1.992, time=0.87 sec
# > epoch=200, batch=24/50, d1=0.384, d2=0.548, g=1.742, time=0.87 sec
# > epoch=200, batch=25/50, d1=0.300, d2=0.567, g=1.604, time=0.87 sec
# > epoch=200, batch=26/50, d1=0.441, d2=0.584, g=1.901, time=0.87 sec
# > epoch=200, batch=27/50, d1=0.420, d2=0.544, g=1.577, time=0.87 sec
# > epoch=200, batch=28/50, d1=0.342, d2=0.587, g=1.762, time=0.87 sec
# > epoch=200, batch=29/50, d1=0.381, d2=0.514, g=1.688, time=0.87 sec
# > epoch=200, batch=30/50, d1=0.394, d2=0.638, g=1.920, time=0.87 sec
# > epoch=200, batch=31/50, d1=0.433, d2=0.561, g=1.899, time=0.87 sec
# > epoch=200, batch=32/50, d1=0.443, d2=0.568, g=1.581, time=0.87 sec
# > epoch=200, batch=33/50, d1=0.442, d2=0.611, g=1.739, time=0.87 sec
# > epoch=200, batch=34/50, d1=0.367, d2=0.571, g=1.596, time=0.87 sec
# > epoch=200, batch=35/50, d1=0.390, d2=0.608, g=1.948, time=0.87 sec
# > epoch=200, batch=36/50, d1=0.568, d2=0.506, g=1.711, time=0.87 sec
# > epoch=200, batch=37/50, d1=0.379, d2=0.593, g=1.513, time=0.87 sec
# > epoch=200, batch=38/50, d1=0.454, d2=0.556, g=2.066, time=0.87 sec
# > epoch=200, batch=39/50, d1=0.428, d2=0.520, g=1.626, time=0.87 sec
# > epoch=200, batch=40/50, d1=0.423, d2=0.574, g=1.709, time=0.87 sec
# > epoch=200, batch=41/50, d1=0.335, d2=0.716, g=2.073, time=0.87 sec
# > epoch=200, batch=42/50, d1=0.541, d2=0.540, g=1.735, time=0.87 sec
# > epoch=200, batch=43/50, d1=0.430, d2=0.598, g=1.625, time=0.87 sec
# > epoch=200, batch=44/50, d1=0.451, d2=0.506, g=1.779, time=0.87 sec
# > epoch=200, batch=45/50, d1=0.504, d2=0.616, g=1.879, time=0.87 sec
# > epoch=200, batch=46/50, d1=0.350, d2=0.555, g=1.942, time=0.87 sec
# > epoch=200, batch=47/50, d1=0.441, d2=0.516, g=1.643, time=0.87 sec
# > epoch=200, batch=48/50, d1=0.376, d2=0.501, g=1.678, time=0.87 sec
# > epoch=200, batch=49/50, d1=0.485, d2=0.602, g=1.930, time=0.87 sec
# > epoch=200, batch=50/50, d1=0.480, d2=0.571, g=1.774, time=0.87 sec
#
# ----------------------------------------------------
# Finalized
# Notebook Time: 148.63 min
