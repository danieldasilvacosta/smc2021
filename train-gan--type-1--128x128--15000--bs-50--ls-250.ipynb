# %%
# Principais mudanças
    
# Baseline: 20200610-16h46--20200610-13h41
# Ver apresentação do dia 15/06/2020.

# %%
images_dimensions = 128
attribute = 'initial-set'
totalInputImages = 15000
BATCH_SIZE = 50
latent_dim = 250

# %%
EPOCHS = 200

# %%
from numpy import load
from numpy import zeros
from numpy import ones
from numpy.random import randn
from numpy.random import randint
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Reshape
from keras.layers import Flatten
from keras.layers import Conv2D
from keras.layers import Conv2DTranspose
from keras.layers import LeakyReLU
from keras.layers import Dropout
from matplotlib import pyplot

# Daniel
import os
import sys
import numpy as np
from PIL import Image
from tqdm import tqdm
import cv2
import time
from keras.initializers import RandomNormal
from numpy.random import random
from numpy.random import choice
import shutil
# Out:
# Using TensorFlow backend.

# %%
import warnings
warnings.filterwarnings( 'ignore' )

# %%
import tensorflow as tf
print( tf.__version__ )
print( 'Num GPUs Available: ', len( tf.config.list_physical_devices( 'GPU' ) ) )
# Out:
# 2.1.0
# Num GPUs Available:  1

# %%
lastTimeNotebook = time.time()

# %%
IMAGES_FOLDER = './images/'
folderDimensionsSufix = str( images_dimensions ) + 'x' + str( images_dimensions )

padronizedFolder = f'{IMAGES_FOLDER}padronized--{attribute}--{folderDimensionsSufix}--{totalInputImages}--bs-{BATCH_SIZE}--ls-{latent_dim}/'

# %%
trainedModelFolder = f'./trained-model--{attribute}--{folderDimensionsSufix}--{totalInputImages}--bs-{BATCH_SIZE}--ls-{latent_dim}/'
generatorFolder = trainedModelFolder + 'generator/'
generatedFolder = trainedModelFolder + 'generated/'

# %%
try:
    shutil.rmtree(trainedModelFolder)
    os.mkdir(trainedModelFolder)
except OSError as e:
    os.mkdir(trainedModelFolder)

# %%
try:
    shutil.rmtree(generatorFolder)
    os.mkdir(generatorFolder)
except OSError as e:
    os.mkdir(generatorFolder)

# %%
try:
    shutil.rmtree(generatedFolder)
    os.mkdir(generatedFolder)
except OSError as e:
    os.mkdir(generatedFolder)

# %%
def define_discriminator(in_shape=(128,128,1)):
    model = Sequential()
    # normal
    model.add(Conv2D(128, (6,6), padding='same', input_shape=in_shape))
    model.add(LeakyReLU(alpha=0.2))

    # downsample to 64x64
    model.add(Conv2D(128, (6,6), strides=(2,2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    
    # downsample to 32x32
    model.add(Conv2D(128, (6,6), strides=(2,2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    
    # downsample to 16x16
    model.add(Conv2D(128, (6,6), strides=(2,2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    
    # downsample to 8x8
    model.add(Conv2D(128, (6,6), strides=(2,2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    
    # classifier
    model.add(Flatten())
    model.add(Dropout(0.4))
    model.add(Dense(1, activation='sigmoid'))
    
    # compile model
    opt = Adam(lr=0.0002, beta_1=0.5)
    model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

    print()
    print('=================================================================')
    print('========================= Discriminator =========================')
    print('=================================================================')
    print()
    print( model.summary() )

    return model

# %%
# define the standalone generator model
def define_generator(latent_dim):
    model = Sequential()
    
    # foundation for 8x8 feature maps
    n_nodes = 128 * 8 * 8
    model.add(Dense(n_nodes, input_dim=latent_dim))
    model.add(LeakyReLU(alpha=0.2))
    
    model.add(Reshape((8, 8, 128)))
    
    # upsample to 16x16
    model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    
    # upsample to 32x32
    model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    
    # upsample to 64x64
    model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    
    # upsample to 128x128
    model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    
    # output layer 128x128x3
    model.add(Conv2D(1, (5,5), activation='tanh', padding='same'))

    print()
    print('=================================================================')
    print('=========================== Generator ===========================')
    print('=================================================================')
    print()
    print( model.summary() )
    
    return model

# %%
# define the combined generator and discriminator model, for updating the generator
def define_gan(g_model, d_model):
    # make weights in the discriminator not trainable
    d_model.trainable = False
    # connect them
    model = Sequential()
    # add generator
    model.add(g_model)
    # add the discriminator
    model.add(d_model)
    # compile model
    opt = Adam(lr=0.0002, beta_1=0.5)
    model.compile(loss='binary_crossentropy', optimizer=opt)
    return model

# %%
# load and prepare training images
def load_real_samples():
    
    _, _, files = next( os.walk( padronizedFolder ) )

    images = []
    for file in tqdm(files):

        image = cv2.imread( padronizedFolder + file, cv2.IMREAD_GRAYSCALE )
        image = image[..., np.newaxis]
        image = (image - 127.5) / 127.5
        images.append( image )

    images = np.asarray(images)
    return images

# %%
# Daniel # 5.5.3 Use Label Smoothing

# example of smoothing class=1 to [0.7, 1.2]
def smooth_positive_labels(y):
    return y - 0.3 + (random(y.shape) * 0.5)

# example of smoothing class=0 to [0.0, 0.3]
def smooth_negative_labels(y):
    return y + random(y.shape) * 0.3

# %%
# Daniel # 5.5.4 Use Noisy Labels

# randomly flip some labels
def noisy_labels(y, p_flip):
    
    # determine the number of labels to flip
    n_select = int(p_flip * y.shape[0])
    
    # choose labels to flip
    flip_ix = choice([i for i in range(y.shape[0])], size=n_select)
    
    # invert the labels in place
    y[flip_ix] = 1 - y[flip_ix]
    
    return y

# %%
# select real samples
def generate_real_samples(dataset, n_samples):
    
    # choose random instances
    ix = randint(0, dataset.shape[0], n_samples)
    
    # retrieve selected images
    X = dataset[ix]
    
    # generate 'real' class labels (1)
    y = ones((n_samples, 1))

    # Daniel # 5.5.3 Use Label Smoothing
    # smooth labels
    y = smooth_positive_labels(y)

    # Daniel # 5.5.4 Use Noisy Labels
    # flip labels with 5% probability
    y = noisy_labels(y, 0.05)

    return X, y

# %%
# generate points in latent space as input for the generator
def generate_latent_points(latent_dim, n_samples):
    
    # generate points in the latent space
    x_input = randn(latent_dim * n_samples)
    
    # reshape into a batch of inputs for the network
    x_input = x_input.reshape(n_samples, latent_dim)
    return x_input

# %%
# use the generator to generate n fake examples, with class labels
def generate_fake_samples(g_model, latent_dim, n_samples):
    
    # generate points in latent space
    x_input = generate_latent_points(latent_dim, n_samples)
    
    # predict outputs
    X = g_model.predict(x_input)
    
    # create 'fake' class labels (0)
    y = zeros((n_samples, 1))

    # Daniel # 5.5.3 Use Label Smoothing
    # smooth labels
    y = smooth_negative_labels(y)

    # Daniel # 5.5.4 Use Noisy Labels
    # flip labels with 5% probability
    y = noisy_labels(y, 0.05)

    return X, y

# %%
# create and save a plot of generated images
def save_plot(examples, epoch, n=10):
    
    # Daniel
    examples = ( examples * 127.5 ) + 127.5
    epochFolder = generatedFolder + f'epoch-{epoch + 1}/'
    
    # Daniel
    for i in range(0, 30) :
        
        cv2.imwrite( 
            epochFolder + f'epoch-{epoch + 1}--{i + 1}.png', 
            examples[i] )

# %%
# evaluate the discriminator, plot generated images, save generator model
def summarize_performance(epoch, g_model, d_model, dataset, latent_dim, n_samples=100):
    
    # prepare real samples
    X_real, y_real = generate_real_samples(dataset, n_samples)
    
    # evaluate discriminator on real examples
    _, acc_real = d_model.evaluate(X_real, y_real, verbose=0)
    
    # prepare fake examples
    x_fake, y_fake = generate_fake_samples(g_model, latent_dim, n_samples)
    
    # evaluate discriminator on fake examples
    _, acc_fake = d_model.evaluate(x_fake, y_fake, verbose=0)
    
    # save plot
    save_plot(x_fake, epoch)
    
    # save the generator model tile file
    filename = generatorFolder + 'generator_model_%03d.h5' % (epoch + 1)
    g_model.save(filename)

# %%
# train the generator and discriminator
def train(g_model, d_model, gan_model, dataset, latent_dim, n_epochs=100, n_batch=128):
    
    lastTime = time.time()
    
    bat_per_epo = int(dataset.shape[0] / n_batch)
    half_batch = int(n_batch / 2)
    
    # manually enumerate epochs
    for i in range(n_epochs):
        
        print()
        
        # enumerate batches over the training set
        for j in range(bat_per_epo):
            
            # Time
            now = time.time()
            interval = now - lastTime
            lastTime = now
            
            # get randomly selected 'real' samples
            X_real, y_real = generate_real_samples(dataset, half_batch)
            
            # update discriminator model weights
            d_loss1, _ = d_model.train_on_batch(X_real, y_real)
            
            # generate 'fake' examples
            X_fake, y_fake = generate_fake_samples(g_model, latent_dim, half_batch)
            
            # update discriminator model weights
            d_loss2, _ = d_model.train_on_batch(X_fake, y_fake)
            
            # prepare points in latent space as input for the generator
            X_gan = generate_latent_points(latent_dim, n_batch)
            
            # create inverted labels for the fake samples
            y_gan = ones((n_batch, 1))
            
            # update the generator via the discriminator's error
            g_loss = gan_model.train_on_batch(X_gan, y_gan)
            
            # summarize loss on this batch
            print('> epoch=%d, batch=%d/%d, d1=%.3f, d2=%.3f, g=%.3f, time=%.2f sec' %
                (i+1, j+1, bat_per_epo, d_loss1, d_loss2, g_loss, (interval) ))
            
        # evaluate the model performance, sometimes
        if (i + 1) % 1 == 0:

            # Daniel
            os.mkdir( generatedFolder + f'epoch-{i + 1}/' )
            
            summarize_performance(i, g_model, d_model, dataset, latent_dim)

# %%
print( 'Processing...' )
print()

# create the discriminator
d_model = define_discriminator()

# create the generator
g_model = define_generator(latent_dim)

# create the gan
gan_model = define_gan(g_model, d_model)

# load image data
dataset = load_real_samples()

# train model
train(
    g_model, 
    d_model, 
    gan_model, 
    dataset, 
    latent_dim, 
    n_epochs=EPOCHS, 
    n_batch=BATCH_SIZE)

print( '\n----------------------------------------------------' )
print( 'Finalized' )

# Time
now = time.time()
interval = now - lastTimeNotebook
print('Notebook Time: %.2f min' % (interval/60))
# Out:
# Processing...
#
#
# =================================================================
# ========================= Discriminator =========================
# =================================================================
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 128, 128, 128)     4736
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 128, 128, 128)     0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 128)       589952
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 64, 64, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 128)       589952
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 128)       589952
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 128)         589952
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 8, 8, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8192)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 8193
# =================================================================
# Total params: 2,372,737
# Trainable params: 2,372,737
# Non-trainable params: 0
# _________________________________________________________________
# None
#
# =================================================================
# =========================== Generator ===========================
# =================================================================
#
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 8192)              2056192
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 8192)              0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 16, 16, 128)       262272
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 32, 32, 128)       262272
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 64, 64, 128)       262272
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 64, 64, 128)       0
# _________________________________________________________________
# conv2d_transpose_4 (Conv2DTr (None, 128, 128, 128)     262272
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 128, 128, 128)     0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 128, 128, 1)       3201
# =================================================================
# Total params: 3,108,481
# Trainable params: 3,108,481
# Non-trainable params: 0
# _________________________________________________________________
# None
# 100%|██████████| 15000/15000 [05:12<00:00, 47.92it/s]
# > epoch=1, batch=1/300, d1=0.692, d2=0.695, g=0.693, time=0.00 sec
# > epoch=1, batch=2/300, d1=0.612, d2=0.697, g=0.691, time=7.90 sec
# > epoch=1, batch=3/300, d1=0.379, d2=0.720, g=0.669, time=0.44 sec
# > epoch=1, batch=4/300, d1=0.227, d2=0.726, g=0.688, time=0.44 sec
# > epoch=1, batch=5/300, d1=0.289, d2=0.732, g=0.681, time=0.44 sec
# > epoch=1, batch=6/300, d1=0.276, d2=0.733, g=0.732, time=0.44 sec
# > epoch=1, batch=7/300, d1=0.502, d2=0.688, g=0.708, time=0.44 sec
# > epoch=1, batch=8/300, d1=0.449, d2=0.688, g=0.716, time=0.44 sec
# > epoch=1, batch=9/300, d1=0.221, d2=0.680, g=0.747, time=0.44 sec
# > epoch=1, batch=10/300, d1=0.413, d2=0.674, g=0.754, time=0.44 sec
# > epoch=1, batch=11/300, d1=0.513, d2=0.671, g=0.737, time=0.44 sec
# > epoch=1, batch=12/300, d1=0.500, d2=0.661, g=0.792, time=0.44 sec
# > epoch=1, batch=13/300, d1=0.360, d2=0.617, g=1.050, time=0.44 sec
# > epoch=1, batch=14/300, d1=0.301, d2=0.507, g=1.954, time=0.44 sec
# > epoch=1, batch=15/300, d1=0.269, d2=0.560, g=1.336, time=0.44 sec
# > epoch=1, batch=16/300, d1=0.370, d2=0.538, g=1.205, time=0.44 sec
# > epoch=1, batch=17/300, d1=0.265, d2=0.504, g=1.884, time=0.44 sec
# > epoch=1, batch=18/300, d1=0.488, d2=0.485, g=1.290, time=0.44 sec
# > epoch=1, batch=19/300, d1=0.309, d2=0.815, g=0.820, time=0.44 sec
# > epoch=1, batch=20/300, d1=0.226, d2=0.590, g=5.327, time=0.44 sec
# > epoch=1, batch=21/300, d1=0.083, d2=1.123, g=1.153, time=0.44 sec
# > epoch=1, batch=22/300, d1=0.775, d2=0.644, g=0.803, time=0.44 sec
# > epoch=1, batch=23/300, d1=0.447, d2=0.634, g=0.844, time=0.44 sec
# > epoch=1, batch=24/300, d1=0.501, d2=0.606, g=0.951, time=0.44 sec
# > epoch=1, batch=25/300, d1=0.373, d2=0.572, g=1.227, time=0.44 sec
# > epoch=1, batch=26/300, d1=0.341, d2=0.523, g=1.613, time=0.44 sec
# > epoch=1, batch=27/300, d1=0.216, d2=0.497, g=1.705, time=0.44 sec
# > epoch=1, batch=28/300, d1=0.458, d2=0.460, g=1.756, time=0.44 sec
# > epoch=1, batch=29/300, d1=0.436, d2=0.490, g=1.695, time=0.44 sec
# > epoch=1, batch=30/300, d1=0.409, d2=0.482, g=1.716, time=0.44 sec
# > epoch=1, batch=31/300, d1=0.318, d2=0.492, g=1.660, time=0.44 sec
# > epoch=1, batch=32/300, d1=0.436, d2=0.489, g=1.847, time=0.44 sec
# > epoch=1, batch=33/300, d1=0.302, d2=0.470, g=2.570, time=0.44 sec
# > epoch=1, batch=34/300, d1=0.362, d2=0.489, g=6.002, time=0.44 sec
# > epoch=1, batch=35/300, d1=0.542, d2=1.030, g=1.163, time=0.44 sec
# > epoch=1, batch=36/300, d1=0.373, d2=0.700, g=0.721, time=0.44 sec
# > epoch=1, batch=37/300, d1=0.356, d2=0.679, g=0.769, time=0.44 sec
# > epoch=1, batch=38/300, d1=0.338, d2=0.638, g=0.968, time=0.44 sec
# > epoch=1, batch=39/300, d1=0.314, d2=0.513, g=1.791, time=0.44 sec
# > epoch=1, batch=40/300, d1=0.327, d2=0.506, g=1.706, time=0.44 sec
# > epoch=1, batch=41/300, d1=0.264, d2=0.489, g=1.514, time=0.44 sec
# > epoch=1, batch=42/300, d1=0.277, d2=0.490, g=1.624, time=0.44 sec
# > epoch=1, batch=43/300, d1=0.346, d2=0.449, g=1.776, time=0.44 sec
# > epoch=1, batch=44/300, d1=0.245, d2=0.411, g=2.017, time=0.44 sec
# > epoch=1, batch=45/300, d1=0.416, d2=0.539, g=1.654, time=0.44 sec
# > epoch=1, batch=46/300, d1=0.299, d2=0.478, g=1.593, time=0.44 sec
# > epoch=1, batch=47/300, d1=0.245, d2=0.458, g=1.724, time=0.44 sec
# > epoch=1, batch=48/300, d1=0.266, d2=0.454, g=1.829, time=0.44 sec
# > epoch=1, batch=49/300, d1=0.415, d2=0.457, g=1.751, time=0.45 sec
# > epoch=1, batch=50/300, d1=0.317, d2=0.479, g=1.747, time=0.44 sec
# > epoch=1, batch=51/300, d1=0.192, d2=0.455, g=1.773, time=0.44 sec
# > epoch=1, batch=52/300, d1=0.544, d2=0.482, g=1.651, time=0.44 sec
# > epoch=1, batch=53/300, d1=0.401, d2=0.469, g=1.727, time=0.44 sec
# > epoch=1, batch=54/300, d1=0.335, d2=0.436, g=1.868, time=0.44 sec
# > epoch=1, batch=55/300, d1=0.242, d2=0.475, g=1.685, time=0.44 sec
# > epoch=1, batch=56/300, d1=0.349, d2=0.488, g=1.596, time=0.44 sec
# > epoch=1, batch=57/300, d1=0.319, d2=0.500, g=2.033, time=0.44 sec
# > epoch=1, batch=58/300, d1=0.314, d2=0.488, g=2.581, time=0.44 sec
# > epoch=1, batch=59/300, d1=0.365, d2=0.553, g=8.931, time=0.44 sec
# > epoch=1, batch=60/300, d1=2.319, d2=0.517, g=0.952, time=0.44 sec
# > epoch=1, batch=61/300, d1=0.416, d2=0.631, g=0.827, time=0.44 sec
# > epoch=1, batch=62/300, d1=0.331, d2=0.622, g=0.893, time=0.44 sec
# > epoch=1, batch=63/300, d1=0.312, d2=0.582, g=1.048, time=0.44 sec
# > epoch=1, batch=64/300, d1=0.233, d2=0.517, g=1.362, time=0.44 sec
# > epoch=1, batch=65/300, d1=0.367, d2=0.482, g=1.757, time=0.44 sec
# > epoch=1, batch=66/300, d1=0.300, d2=0.480, g=1.760, time=0.44 sec
# > epoch=1, batch=67/300, d1=0.332, d2=0.481, g=1.759, time=0.44 sec
# > epoch=1, batch=68/300, d1=0.210, d2=0.480, g=1.836, time=0.44 sec
# > epoch=1, batch=69/300, d1=0.346, d2=0.540, g=2.966, time=0.44 sec
# > epoch=1, batch=70/300, d1=0.423, d2=0.594, g=1.265, time=0.44 sec
# > epoch=1, batch=71/300, d1=0.246, d2=0.696, g=1.060, time=0.44 sec
# > epoch=1, batch=72/300, d1=0.305, d2=0.537, g=1.500, time=0.44 sec
# > epoch=1, batch=73/300, d1=0.482, d2=0.486, g=1.652, time=0.44 sec
# > epoch=1, batch=74/300, d1=0.386, d2=0.445, g=1.933, time=0.44 sec
# > epoch=1, batch=75/300, d1=0.299, d2=0.469, g=1.716, time=0.44 sec
# > epoch=1, batch=76/300, d1=0.207, d2=0.451, g=1.932, time=0.44 sec
# > epoch=1, batch=77/300, d1=0.229, d2=0.526, g=1.522, time=0.44 sec
# > epoch=1, batch=78/300, d1=0.440, d2=0.543, g=1.359, time=0.45 sec
# > epoch=1, batch=79/300, d1=0.270, d2=0.474, g=1.836, time=0.44 sec
# > epoch=1, batch=80/300, d1=0.381, d2=0.505, g=1.517, time=0.45 sec
# > epoch=1, batch=81/300, d1=0.289, d2=0.510, g=1.574, time=0.45 sec
# > epoch=1, batch=82/300, d1=0.433, d2=0.487, g=1.765, time=0.45 sec
# > epoch=1, batch=83/300, d1=0.362, d2=0.453, g=1.802, time=0.44 sec
# > epoch=1, batch=84/300, d1=0.372, d2=0.488, g=1.637, time=0.45 sec
# > epoch=1, batch=85/300, d1=0.339, d2=0.524, g=1.526, time=0.44 sec
# > epoch=1, batch=86/300, d1=0.312, d2=0.453, g=2.246, time=0.45 sec
# > epoch=1, batch=87/300, d1=0.287, d2=0.539, g=1.585, time=0.45 sec
# > epoch=1, batch=88/300, d1=0.137, d2=0.509, g=1.391, time=0.44 sec
# > epoch=1, batch=89/300, d1=0.370, d2=0.488, g=1.734, time=0.44 sec
# > epoch=1, batch=90/300, d1=0.174, d2=0.463, g=1.968, time=0.44 sec
# > epoch=1, batch=91/300, d1=0.353, d2=0.623, g=5.457, time=0.44 sec
# > epoch=1, batch=92/300, d1=2.774, d2=0.641, g=0.561, time=0.44 sec
# > epoch=1, batch=93/300, d1=0.744, d2=0.773, g=0.703, time=0.45 sec
# > epoch=1, batch=94/300, d1=0.621, d2=0.675, g=0.748, time=0.45 sec
# > epoch=1, batch=95/300, d1=0.589, d2=0.654, g=0.764, time=0.45 sec
# > epoch=1, batch=96/300, d1=0.321, d2=0.644, g=0.790, time=0.45 sec
# > epoch=1, batch=97/300, d1=0.217, d2=0.630, g=0.837, time=0.45 sec
# > epoch=1, batch=98/300, d1=0.267, d2=0.615, g=0.908, time=0.45 sec
# > epoch=1, batch=99/300, d1=0.267, d2=0.568, g=1.061, time=0.44 sec
# > epoch=1, batch=100/300, d1=0.375, d2=0.515, g=1.417, time=0.45 sec
# > epoch=1, batch=101/300, d1=0.431, d2=0.459, g=1.673, time=0.45 sec
# > epoch=1, batch=102/300, d1=0.219, d2=0.474, g=1.805, time=0.45 sec
# > epoch=1, batch=103/300, d1=0.338, d2=0.411, g=1.960, time=0.45 sec
# > epoch=1, batch=104/300, d1=0.340, d2=0.417, g=1.989, time=0.45 sec
# > epoch=1, batch=105/300, d1=0.353, d2=0.468, g=1.746, time=0.45 sec
# > epoch=1, batch=106/300, d1=0.361, d2=0.436, g=1.670, time=0.45 sec
# > epoch=1, batch=107/300, d1=0.397, d2=0.472, g=1.751, time=0.45 sec
# > epoch=1, batch=108/300, d1=0.325, d2=0.446, g=1.812, time=0.44 sec
# > epoch=1, batch=109/300, d1=0.333, d2=0.459, g=2.098, time=0.45 sec
# > epoch=1, batch=110/300, d1=0.268, d2=0.461, g=1.481, time=0.44 sec
# > epoch=1, batch=111/300, d1=0.308, d2=0.720, g=2.736, time=0.45 sec
# > epoch=1, batch=112/300, d1=0.205, d2=0.632, g=1.015, time=0.45 sec
# > epoch=1, batch=113/300, d1=0.274, d2=0.671, g=0.847, time=0.44 sec
# > epoch=1, batch=114/300, d1=0.439, d2=0.616, g=0.924, time=0.45 sec
# > epoch=1, batch=115/300, d1=0.258, d2=0.532, g=1.289, time=0.45 sec
# > epoch=1, batch=116/300, d1=0.333, d2=0.449, g=1.895, time=0.45 sec
# > epoch=1, batch=117/300, d1=0.392, d2=0.418, g=2.007, time=0.45 sec
# > epoch=1, batch=118/300, d1=0.313, d2=0.515, g=1.695, time=0.45 sec
# > epoch=1, batch=119/300, d1=0.324, d2=0.496, g=1.572, time=0.45 sec
# > epoch=1, batch=120/300, d1=0.360, d2=0.490, g=1.595, time=0.45 sec
# > epoch=1, batch=121/300, d1=0.255, d2=0.458, g=1.592, time=0.45 sec
# > epoch=1, batch=122/300, d1=0.554, d2=0.492, g=1.649, time=0.45 sec
# > epoch=1, batch=123/300, d1=0.245, d2=0.538, g=1.544, time=0.45 sec
# > epoch=1, batch=124/300, d1=0.285, d2=0.411, g=1.641, time=0.45 sec
# > epoch=1, batch=125/300, d1=0.368, d2=0.487, g=1.768, time=0.45 sec
# > epoch=1, batch=126/300, d1=0.287, d2=0.443, g=1.804, time=0.45 sec
# > epoch=1, batch=127/300, d1=0.172, d2=0.462, g=1.770, time=0.45 sec
# > epoch=1, batch=128/300, d1=0.264, d2=0.485, g=1.631, time=0.45 sec
# > epoch=1, batch=129/300, d1=0.310, d2=0.467, g=1.774, time=0.45 sec
# > epoch=1, batch=130/300, d1=-0.012, d2=0.487, g=1.683, time=0.45 sec
# > epoch=1, batch=131/300, d1=0.330, d2=0.452, g=2.058, time=0.45 sec
# > epoch=1, batch=132/300, d1=0.564, d2=0.493, g=1.562, time=0.45 sec
# > epoch=1, batch=133/300, d1=0.412, d2=0.475, g=1.617, time=0.45 sec
# > epoch=1, batch=134/300, d1=0.333, d2=0.465, g=1.795, time=0.45 sec
# > epoch=1, batch=135/300, d1=0.319, d2=0.455, g=1.895, time=0.45 sec
# > epoch=1, batch=136/300, d1=0.286, d2=0.497, g=1.584, time=0.45 sec
# > epoch=1, batch=137/300, d1=0.348, d2=0.452, g=2.316, time=0.45 sec
# > epoch=1, batch=138/300, d1=0.136, d2=0.489, g=1.937, time=0.45 sec
# > epoch=1, batch=139/300, d1=0.362, d2=0.510, g=1.470, time=0.45 sec
# > epoch=1, batch=140/300, d1=0.291, d2=0.481, g=1.664, time=0.45 sec
# > epoch=1, batch=141/300, d1=0.323, d2=0.481, g=1.884, time=0.45 sec
# > epoch=1, batch=142/300, d1=0.376, d2=0.494, g=2.653, time=0.45 sec
# > epoch=1, batch=143/300, d1=0.449, d2=0.482, g=1.813, time=0.45 sec
# > epoch=1, batch=144/300, d1=0.399, d2=0.781, g=1.013, time=0.45 sec
# > epoch=1, batch=145/300, d1=0.421, d2=0.620, g=1.827, time=0.45 sec
# > epoch=1, batch=146/300, d1=0.459, d2=0.460, g=1.703, time=0.45 sec
# > epoch=1, batch=147/300, d1=0.307, d2=0.506, g=1.751, time=0.45 sec
# > epoch=1, batch=148/300, d1=0.109, d2=0.482, g=2.068, time=0.45 sec
# > epoch=1, batch=149/300, d1=0.411, d2=0.544, g=1.588, time=0.45 sec
# > epoch=1, batch=150/300, d1=0.233, d2=0.515, g=1.926, time=0.44 sec
# > epoch=1, batch=151/300, d1=0.325, d2=0.432, g=2.310, time=0.44 sec
# > epoch=1, batch=152/300, d1=0.260, d2=0.410, g=3.130, time=0.45 sec
# > epoch=1, batch=153/300, d1=0.349, d2=0.534, g=0.526, time=0.45 sec
# > epoch=1, batch=154/300, d1=0.349, d2=0.965, g=0.670, time=0.45 sec
# > epoch=1, batch=155/300, d1=0.294, d2=0.702, g=0.784, time=0.45 sec
# > epoch=1, batch=156/300, d1=0.343, d2=0.631, g=0.984, time=0.45 sec
# > epoch=1, batch=157/300, d1=0.355, d2=0.569, g=1.445, time=0.44 sec
# > epoch=1, batch=158/300, d1=0.471, d2=0.533, g=1.362, time=0.45 sec
# > epoch=1, batch=159/300, d1=0.389, d2=0.582, g=1.279, time=0.45 sec
# > epoch=1, batch=160/300, d1=0.489, d2=0.560, g=1.320, time=0.45 sec
# > epoch=1, batch=161/300, d1=0.522, d2=0.537, g=1.310, time=0.45 sec
# > epoch=1, batch=162/300, d1=0.169, d2=0.480, g=1.652, time=0.45 sec
# > epoch=1, batch=163/300, d1=0.371, d2=0.486, g=1.751, time=0.45 sec
# > epoch=1, batch=164/300, d1=0.410, d2=0.451, g=1.769, time=0.45 sec
# > epoch=1, batch=165/300, d1=0.375, d2=0.452, g=1.818, time=0.45 sec
# > epoch=1, batch=166/300, d1=0.274, d2=0.468, g=1.709, time=0.45 sec
# > epoch=1, batch=167/300, d1=0.432, d2=0.512, g=1.623, time=0.45 sec
# > epoch=1, batch=168/300, d1=0.328, d2=0.504, g=2.064, time=0.45 sec
# > epoch=1, batch=169/300, d1=0.432, d2=0.499, g=1.291, time=0.45 sec
# > epoch=1, batch=170/300, d1=0.399, d2=0.853, g=2.433, time=0.45 sec
# > epoch=1, batch=171/300, d1=0.396, d2=0.470, g=1.284, time=0.45 sec
# > epoch=1, batch=172/300, d1=0.255, d2=0.636, g=2.064, time=0.45 sec
# > epoch=1, batch=173/300, d1=0.312, d2=0.477, g=1.730, time=0.45 sec
# > epoch=1, batch=174/300, d1=0.178, d2=0.483, g=1.555, time=0.45 sec
# > epoch=1, batch=175/300, d1=0.175, d2=0.468, g=1.864, time=0.45 sec
# > epoch=1, batch=176/300, d1=0.338, d2=0.451, g=1.916, time=0.45 sec
# > epoch=1, batch=177/300, d1=0.143, d2=0.509, g=1.553, time=0.45 sec
# > epoch=1, batch=178/300, d1=0.325, d2=0.464, g=1.972, time=0.46 sec
# > epoch=1, batch=179/300, d1=0.287, d2=0.426, g=2.016, time=0.45 sec
# > epoch=1, batch=180/300, d1=0.318, d2=0.437, g=1.951, time=0.44 sec
# > epoch=1, batch=181/300, d1=0.347, d2=0.487, g=1.686, time=0.45 sec
# > epoch=1, batch=182/300, d1=0.434, d2=0.480, g=1.749, time=0.45 sec
# > epoch=1, batch=183/300, d1=0.308, d2=0.491, g=1.787, time=0.45 sec
# > epoch=1, batch=184/300, d1=0.266, d2=0.496, g=2.636, time=0.44 sec
# > epoch=1, batch=185/300, d1=0.366, d2=0.532, g=1.639, time=0.45 sec
# > epoch=1, batch=186/300, d1=0.330, d2=0.628, g=1.757, time=0.44 sec
# > epoch=1, batch=187/300, d1=0.328, d2=0.467, g=1.822, time=0.45 sec
# > epoch=1, batch=188/300, d1=0.406, d2=0.511, g=1.561, time=0.46 sec
# > epoch=1, batch=189/300, d1=0.432, d2=0.500, g=1.584, time=0.47 sec
# > epoch=1, batch=190/300, d1=0.361, d2=0.442, g=1.964, time=0.45 sec
# > epoch=1, batch=191/300, d1=0.275, d2=0.481, g=1.754, time=0.46 sec
# > epoch=1, batch=192/300, d1=0.207, d2=0.519, g=1.997, time=0.45 sec
# > epoch=1, batch=193/300, d1=0.462, d2=0.487, g=1.759, time=0.45 sec
# > epoch=1, batch=194/300, d1=0.294, d2=0.451, g=1.727, time=0.45 sec
# > epoch=1, batch=195/300, d1=0.402, d2=0.432, g=2.146, time=0.45 sec
# > epoch=1, batch=196/300, d1=0.289, d2=0.461, g=1.908, time=0.45 sec
# > epoch=1, batch=197/300, d1=0.241, d2=0.493, g=2.186, time=0.45 sec
# > epoch=1, batch=198/300, d1=0.430, d2=0.537, g=1.493, time=0.45 sec
# > epoch=1, batch=199/300, d1=0.251, d2=0.665, g=2.517, time=0.45 sec
# > epoch=1, batch=200/300, d1=0.323, d2=0.575, g=1.804, time=0.45 sec
# > epoch=1, batch=201/300, d1=0.277, d2=0.580, g=1.638, time=0.45 sec
# > epoch=1, batch=202/300, d1=0.432, d2=0.498, g=1.935, time=0.44 sec
# > epoch=1, batch=203/300, d1=0.369, d2=0.523, g=1.547, time=0.45 sec
# > epoch=1, batch=204/300, d1=0.311, d2=0.487, g=2.341, time=0.45 sec
# > epoch=1, batch=205/300, d1=0.383, d2=0.457, g=1.748, time=0.45 sec
# > epoch=1, batch=206/300, d1=0.348, d2=0.530, g=1.875, time=0.45 sec
# > epoch=1, batch=207/300, d1=0.206, d2=0.461, g=1.912, time=0.45 sec
# > epoch=1, batch=208/300, d1=0.340, d2=0.495, g=1.759, time=0.45 sec
# > epoch=1, batch=209/300, d1=0.243, d2=0.574, g=3.780, time=0.45 sec
# > epoch=1, batch=210/300, d1=0.366, d2=0.567, g=1.122, time=0.45 sec
# > epoch=1, batch=211/300, d1=0.416, d2=0.654, g=1.104, time=0.45 sec
# > epoch=1, batch=212/300, d1=0.292, d2=0.547, g=1.809, time=0.45 sec
# > epoch=1, batch=213/300, d1=0.409, d2=0.499, g=1.895, time=0.45 sec
# > epoch=1, batch=214/300, d1=0.343, d2=0.562, g=2.027, time=0.45 sec
# > epoch=1, batch=215/300, d1=0.371, d2=0.449, g=2.003, time=0.45 sec
# > epoch=1, batch=216/300, d1=0.359, d2=0.434, g=1.938, time=0.45 sec
# > epoch=1, batch=217/300, d1=0.392, d2=0.753, g=3.518, time=0.45 sec
# > epoch=1, batch=218/300, d1=1.075, d2=1.221, g=1.052, time=0.45 sec
# > epoch=1, batch=219/300, d1=0.417, d2=0.556, g=1.415, time=0.45 sec
# > epoch=1, batch=220/300, d1=0.585, d2=0.542, g=1.324, time=0.45 sec
# > epoch=1, batch=221/300, d1=0.482, d2=0.537, g=1.348, time=0.45 sec
# > epoch=1, batch=222/300, d1=0.369, d2=0.473, g=1.779, time=0.45 sec
# > epoch=1, batch=223/300, d1=0.373, d2=0.507, g=1.933, time=0.45 sec
# > epoch=1, batch=224/300, d1=0.265, d2=0.476, g=1.568, time=0.45 sec
# > epoch=1, batch=225/300, d1=0.145, d2=0.514, g=1.486, time=0.45 sec
# > epoch=1, batch=226/300, d1=0.497, d2=0.525, g=1.582, time=0.45 sec
# > epoch=1, batch=227/300, d1=0.391, d2=0.475, g=1.441, time=0.45 sec
# > epoch=1, batch=228/300, d1=0.391, d2=0.477, g=1.611, time=0.45 sec
# > epoch=1, batch=229/300, d1=0.319, d2=0.508, g=1.819, time=0.45 sec
# > epoch=1, batch=230/300, d1=0.204, d2=0.468, g=1.799, time=0.45 sec
# > epoch=1, batch=231/300, d1=0.097, d2=0.441, g=2.272, time=0.45 sec
# > epoch=1, batch=232/300, d1=0.240, d2=0.460, g=2.025, time=0.45 sec
# > epoch=1, batch=233/300, d1=0.381, d2=0.494, g=2.257, time=0.45 sec
# > epoch=1, batch=234/300, d1=0.359, d2=0.680, g=2.447, time=0.45 sec
# > epoch=1, batch=235/300, d1=0.335, d2=0.554, g=2.674, time=0.45 sec
# > epoch=1, batch=236/300, d1=0.324, d2=0.782, g=3.800, time=0.45 sec
# > epoch=1, batch=237/300, d1=0.420, d2=0.523, g=1.744, time=0.45 sec
# > epoch=1, batch=238/300, d1=0.270, d2=0.583, g=1.819, time=0.45 sec
# > epoch=1, batch=239/300, d1=0.187, d2=0.497, g=1.720, time=0.45 sec
# > epoch=1, batch=240/300, d1=0.540, d2=0.543, g=1.495, time=0.45 sec
# > epoch=1, batch=241/300, d1=0.319, d2=0.453, g=1.954, time=0.45 sec
# > epoch=1, batch=242/300, d1=0.338, d2=0.454, g=1.809, time=0.45 sec
# > epoch=1, batch=243/300, d1=0.407, d2=0.664, g=1.915, time=0.45 sec
# > epoch=1, batch=244/300, d1=0.460, d2=0.594, g=2.024, time=0.45 sec
# > epoch=1, batch=245/300, d1=0.434, d2=0.632, g=2.195, time=0.45 sec
# > epoch=1, batch=246/300, d1=0.412, d2=0.611, g=2.137, time=0.45 sec
# > epoch=1, batch=247/300, d1=0.439, d2=0.643, g=2.093, time=0.45 sec
# > epoch=1, batch=248/300, d1=0.323, d2=0.558, g=2.253, time=0.45 sec
# > epoch=1, batch=249/300, d1=0.322, d2=0.511, g=2.137, time=0.45 sec
# > epoch=1, batch=250/300, d1=0.518, d2=0.881, g=1.671, time=0.45 sec
# > epoch=1, batch=251/300, d1=0.251, d2=0.496, g=1.833, time=0.45 sec
# > epoch=1, batch=252/300, d1=0.323, d2=0.534, g=1.461, time=0.45 sec
# > epoch=1, batch=253/300, d1=0.478, d2=0.514, g=1.826, time=0.45 sec
# > epoch=1, batch=254/300, d1=0.467, d2=0.642, g=3.271, time=0.45 sec
# > epoch=1, batch=255/300, d1=0.476, d2=0.504, g=1.842, time=0.45 sec
# > epoch=1, batch=256/300, d1=0.321, d2=0.552, g=3.867, time=0.45 sec
# > epoch=1, batch=257/300, d1=0.458, d2=0.438, g=2.294, time=0.45 sec
# > epoch=1, batch=258/300, d1=0.369, d2=0.691, g=2.422, time=0.45 sec
# > epoch=1, batch=259/300, d1=0.502, d2=0.536, g=1.739, time=0.45 sec
# > epoch=1, batch=260/300, d1=0.412, d2=0.657, g=1.360, time=0.45 sec
# > epoch=1, batch=261/300, d1=0.403, d2=0.562, g=2.064, time=0.45 sec
# > epoch=1, batch=262/300, d1=0.521, d2=0.554, g=1.224, time=0.45 sec
# > epoch=1, batch=263/300, d1=0.389, d2=0.549, g=1.711, time=0.45 sec
# > epoch=1, batch=264/300, d1=0.354, d2=0.529, g=1.601, time=0.45 sec
# > epoch=1, batch=265/300, d1=0.317, d2=0.533, g=1.722, time=0.45 sec
# > epoch=1, batch=266/300, d1=0.360, d2=0.545, g=1.501, time=0.45 sec
# > epoch=1, batch=267/300, d1=0.432, d2=0.555, g=2.043, time=0.45 sec
# > epoch=1, batch=268/300, d1=0.478, d2=0.542, g=1.477, time=0.45 sec
# > epoch=1, batch=269/300, d1=0.188, d2=0.561, g=1.616, time=0.45 sec
# > epoch=1, batch=270/300, d1=0.320, d2=0.560, g=2.195, time=0.45 sec
# > epoch=1, batch=271/300, d1=0.348, d2=0.584, g=1.695, time=0.45 sec
# > epoch=1, batch=272/300, d1=0.368, d2=0.525, g=1.660, time=0.45 sec
# > epoch=1, batch=273/300, d1=0.395, d2=0.533, g=2.027, time=0.45 sec
# > epoch=1, batch=274/300, d1=0.370, d2=0.561, g=2.130, time=0.45 sec
# > epoch=1, batch=275/300, d1=0.388, d2=0.477, g=1.769, time=0.45 sec
# > epoch=1, batch=276/300, d1=0.344, d2=0.577, g=2.324, time=0.45 sec
# > epoch=1, batch=277/300, d1=0.481, d2=0.494, g=1.654, time=0.45 sec
# > epoch=1, batch=278/300, d1=0.445, d2=0.506, g=2.133, time=0.45 sec
# > epoch=1, batch=279/300, d1=0.473, d2=0.486, g=1.999, time=0.45 sec
# > epoch=1, batch=280/300, d1=0.370, d2=0.497, g=1.829, time=0.45 sec
# > epoch=1, batch=281/300, d1=0.447, d2=0.484, g=2.126, time=0.45 sec
# > epoch=1, batch=282/300, d1=0.319, d2=0.562, g=2.108, time=0.45 sec
# > epoch=1, batch=283/300, d1=0.450, d2=0.502, g=1.663, time=0.45 sec
# > epoch=1, batch=284/300, d1=0.439, d2=0.606, g=2.802, time=0.45 sec
# > epoch=1, batch=285/300, d1=0.590, d2=0.676, g=1.768, time=0.45 sec
# > epoch=1, batch=286/300, d1=0.159, d2=0.598, g=2.083, time=0.45 sec
# > epoch=1, batch=287/300, d1=0.400, d2=0.639, g=1.685, time=0.45 sec
# > epoch=1, batch=288/300, d1=0.465, d2=0.504, g=1.923, time=0.45 sec
# > epoch=1, batch=289/300, d1=0.462, d2=0.529, g=2.191, time=0.45 sec
# > epoch=1, batch=290/300, d1=0.363, d2=0.459, g=2.005, time=0.45 sec
# > epoch=1, batch=291/300, d1=0.360, d2=0.508, g=2.147, time=0.45 sec
# > epoch=1, batch=292/300, d1=0.357, d2=0.511, g=1.910, time=0.45 sec
# > epoch=1, batch=293/300, d1=0.325, d2=0.475, g=2.185, time=0.45 sec
# > epoch=1, batch=294/300, d1=0.367, d2=0.585, g=2.239, time=0.45 sec
# > epoch=1, batch=295/300, d1=0.279, d2=0.487, g=2.515, time=0.45 sec
# > epoch=1, batch=296/300, d1=0.433, d2=0.578, g=1.662, time=0.45 sec
# > epoch=1, batch=297/300, d1=0.231, d2=0.642, g=1.666, time=0.45 sec
# > epoch=1, batch=298/300, d1=0.414, d2=0.485, g=1.997, time=0.45 sec
# > epoch=1, batch=299/300, d1=0.426, d2=0.510, g=2.056, time=0.45 sec
# > epoch=1, batch=300/300, d1=0.329, d2=0.651, g=2.452, time=0.45 sec
#
# > epoch=2, batch=1/300, d1=0.488, d2=0.422, g=2.581, time=4.02 sec
# > epoch=2, batch=2/300, d1=0.401, d2=0.555, g=2.089, time=0.47 sec
# > epoch=2, batch=3/300, d1=0.434, d2=0.551, g=2.668, time=0.45 sec
# > epoch=2, batch=4/300, d1=0.525, d2=0.847, g=1.985, time=0.45 sec
# > epoch=2, batch=5/300, d1=0.456, d2=0.639, g=1.735, time=0.45 sec
# > epoch=2, batch=6/300, d1=0.550, d2=0.553, g=1.490, time=0.45 sec
# > epoch=2, batch=7/300, d1=0.365, d2=0.600, g=1.872, time=0.45 sec
# > epoch=2, batch=8/300, d1=0.433, d2=0.462, g=2.007, time=0.45 sec
# > epoch=2, batch=9/300, d1=0.518, d2=0.593, g=1.588, time=0.45 sec
# > epoch=2, batch=10/300, d1=0.430, d2=0.525, g=2.279, time=0.45 sec
# > epoch=2, batch=11/300, d1=0.393, d2=0.715, g=1.665, time=0.45 sec
# > epoch=2, batch=12/300, d1=0.445, d2=0.534, g=1.785, time=0.46 sec
# > epoch=2, batch=13/300, d1=0.592, d2=0.797, g=1.485, time=0.45 sec
# > epoch=2, batch=14/300, d1=0.411, d2=0.555, g=1.524, time=0.45 sec
# > epoch=2, batch=15/300, d1=0.435, d2=0.581, g=1.579, time=0.45 sec
# > epoch=2, batch=16/300, d1=0.312, d2=0.538, g=1.750, time=0.45 sec
# > epoch=2, batch=17/300, d1=0.393, d2=0.527, g=2.211, time=0.45 sec
# > epoch=2, batch=18/300, d1=0.389, d2=0.471, g=2.090, time=0.45 sec
# > epoch=2, batch=19/300, d1=0.341, d2=0.545, g=1.897, time=0.45 sec
# > epoch=2, batch=20/300, d1=0.144, d2=0.622, g=2.567, time=0.45 sec
# > epoch=2, batch=21/300, d1=0.359, d2=0.519, g=1.544, time=0.45 sec
# > epoch=2, batch=22/300, d1=0.330, d2=0.837, g=2.927, time=0.45 sec
# > epoch=2, batch=23/300, d1=0.612, d2=0.527, g=1.626, time=0.45 sec
# > epoch=2, batch=24/300, d1=0.435, d2=0.579, g=1.813, time=0.45 sec
# > epoch=2, batch=25/300, d1=0.370, d2=0.548, g=2.322, time=0.45 sec
# > epoch=2, batch=26/300, d1=0.304, d2=0.523, g=1.550, time=0.45 sec
# > epoch=2, batch=27/300, d1=0.465, d2=0.681, g=2.061, time=0.45 sec
# > epoch=2, batch=28/300, d1=0.423, d2=0.520, g=1.679, time=0.45 sec
# > epoch=2, batch=29/300, d1=0.413, d2=0.528, g=1.767, time=0.45 sec
# > epoch=2, batch=30/300, d1=0.533, d2=0.506, g=2.138, time=0.45 sec
# > epoch=2, batch=31/300, d1=0.423, d2=0.531, g=1.376, time=0.45 sec
# > epoch=2, batch=32/300, d1=0.290, d2=0.668, g=2.687, time=0.45 sec
# > epoch=2, batch=33/300, d1=0.456, d2=0.531, g=1.845, time=0.45 sec
# > epoch=2, batch=34/300, d1=0.344, d2=0.749, g=2.271, time=0.45 sec
# > epoch=2, batch=35/300, d1=0.453, d2=0.572, g=1.784, time=0.45 sec
# > epoch=2, batch=36/300, d1=0.381, d2=0.597, g=2.074, time=0.45 sec
# > epoch=2, batch=37/300, d1=0.497, d2=0.480, g=1.835, time=0.45 sec
# > epoch=2, batch=38/300, d1=0.419, d2=0.489, g=2.052, time=0.45 sec
# > epoch=2, batch=39/300, d1=0.575, d2=0.574, g=1.287, time=0.45 sec
# > epoch=2, batch=40/300, d1=0.263, d2=0.585, g=1.825, time=0.45 sec
# > epoch=2, batch=41/300, d1=0.634, d2=0.520, g=2.033, time=0.45 sec
# > epoch=2, batch=42/300, d1=0.362, d2=0.618, g=1.604, time=0.45 sec
# > epoch=2, batch=43/300, d1=0.459, d2=0.578, g=1.705, time=0.45 sec
# > epoch=2, batch=44/300, d1=0.354, d2=0.503, g=1.750, time=0.45 sec
# > epoch=2, batch=45/300, d1=0.445, d2=0.536, g=1.649, time=0.45 sec
# > epoch=2, batch=46/300, d1=0.361, d2=0.566, g=2.006, time=0.45 sec
# > epoch=2, batch=47/300, d1=0.343, d2=0.535, g=2.024, time=0.45 sec
# > epoch=2, batch=48/300, d1=0.444, d2=0.571, g=2.038, time=0.45 sec
# > epoch=2, batch=49/300, d1=0.428, d2=0.550, g=1.752, time=0.45 sec
# > epoch=2, batch=50/300, d1=0.439, d2=0.496, g=2.056, time=0.45 sec
# > epoch=2, batch=51/300, d1=0.342, d2=0.541, g=1.795, time=0.45 sec
# > epoch=2, batch=52/300, d1=0.333, d2=0.519, g=1.970, time=0.45 sec
# > epoch=2, batch=53/300, d1=0.402, d2=0.472, g=1.848, time=0.45 sec
# > epoch=2, batch=54/300, d1=0.489, d2=0.576, g=2.315, time=0.45 sec
# > epoch=2, batch=55/300, d1=0.436, d2=0.556, g=1.576, time=0.45 sec
# > epoch=2, batch=56/300, d1=0.415, d2=0.600, g=1.922, time=0.45 sec
# > epoch=2, batch=57/300, d1=0.453, d2=0.629, g=2.050, time=0.45 sec
# > epoch=2, batch=58/300, d1=0.434, d2=0.828, g=2.768, time=0.45 sec
# > epoch=2, batch=59/300, d1=0.509, d2=0.634, g=1.834, time=0.45 sec
# > epoch=2, batch=60/300, d1=0.337, d2=0.639, g=1.738, time=0.45 sec
# > epoch=2, batch=61/300, d1=0.448, d2=0.551, g=2.205, time=0.45 sec
# > epoch=2, batch=62/300, d1=0.381, d2=0.738, g=2.693, time=0.45 sec
# > epoch=2, batch=63/300, d1=0.530, d2=0.702, g=2.826, time=0.45 sec
# > epoch=2, batch=64/300, d1=0.432, d2=0.544, g=1.922, time=0.45 sec
# > epoch=2, batch=65/300, d1=0.358, d2=0.817, g=2.079, time=0.45 sec
# > epoch=2, batch=66/300, d1=0.481, d2=0.544, g=1.848, time=0.45 sec
# > epoch=2, batch=67/300, d1=0.302, d2=0.594, g=1.508, time=0.45 sec
# > epoch=2, batch=68/300, d1=0.337, d2=0.639, g=1.698, time=0.45 sec
# > epoch=2, batch=69/300, d1=0.446, d2=0.528, g=1.738, time=0.45 sec
# > epoch=2, batch=70/300, d1=0.531, d2=0.599, g=1.726, time=0.45 sec
# > epoch=2, batch=71/300, d1=0.338, d2=0.617, g=1.638, time=0.45 sec
# > epoch=2, batch=72/300, d1=0.351, d2=0.585, g=2.271, time=0.45 sec
# > epoch=2, batch=73/300, d1=0.548, d2=0.536, g=2.079, time=0.45 sec
# > epoch=2, batch=74/300, d1=0.644, d2=0.559, g=1.795, time=0.45 sec
# > epoch=2, batch=75/300, d1=0.330, d2=0.533, g=1.831, time=0.45 sec
# > epoch=2, batch=76/300, d1=0.350, d2=0.580, g=2.276, time=0.45 sec
# > epoch=2, batch=77/300, d1=0.409, d2=0.525, g=1.743, time=0.45 sec
# > epoch=2, batch=78/300, d1=0.400, d2=0.576, g=2.255, time=0.45 sec
# > epoch=2, batch=79/300, d1=0.452, d2=0.519, g=1.707, time=0.45 sec
# > epoch=2, batch=80/300, d1=0.400, d2=0.636, g=2.746, time=0.45 sec
# > epoch=2, batch=81/300, d1=0.494, d2=0.538, g=1.631, time=0.45 sec
# > epoch=2, batch=82/300, d1=0.470, d2=0.751, g=1.796, time=0.45 sec
# > epoch=2, batch=83/300, d1=0.406, d2=0.521, g=2.125, time=0.45 sec
# > epoch=2, batch=84/300, d1=0.448, d2=0.509, g=1.718, time=0.45 sec
# > epoch=2, batch=85/300, d1=0.217, d2=0.583, g=2.075, time=0.45 sec
# > epoch=2, batch=86/300, d1=0.346, d2=0.513, g=2.061, time=0.45 sec
# > epoch=2, batch=87/300, d1=0.519, d2=0.579, g=2.019, time=0.45 sec
# > epoch=2, batch=88/300, d1=0.488, d2=0.521, g=1.979, time=0.45 sec
# > epoch=2, batch=89/300, d1=0.510, d2=0.689, g=1.745, time=0.45 sec
# > epoch=2, batch=90/300, d1=0.489, d2=0.521, g=1.909, time=0.45 sec
# > epoch=2, batch=91/300, d1=0.415, d2=0.570, g=1.656, time=0.45 sec
# > epoch=2, batch=92/300, d1=0.369, d2=0.579, g=1.872, time=0.45 sec
# > epoch=2, batch=93/300, d1=0.387, d2=0.664, g=1.754, time=0.45 sec
# > epoch=2, batch=94/300, d1=0.328, d2=0.609, g=1.707, time=0.45 sec
# > epoch=2, batch=95/300, d1=0.410, d2=0.498, g=1.974, time=0.45 sec
# > epoch=2, batch=96/300, d1=0.411, d2=0.534, g=1.683, time=0.45 sec
# > epoch=2, batch=97/300, d1=0.359, d2=0.615, g=1.698, time=0.45 sec
# > epoch=2, batch=98/300, d1=0.316, d2=0.531, g=1.930, time=0.45 sec
# > epoch=2, batch=99/300, d1=0.367, d2=0.509, g=1.902, time=0.45 sec
# > epoch=2, batch=100/300, d1=0.282, d2=0.530, g=2.080, time=0.45 sec
# > epoch=2, batch=101/300, d1=0.395, d2=0.552, g=2.118, time=0.45 sec
# > epoch=2, batch=102/300, d1=0.312, d2=0.568, g=2.283, time=0.45 sec
# > epoch=2, batch=103/300, d1=0.459, d2=0.528, g=2.668, time=0.45 sec
# > epoch=2, batch=104/300, d1=0.404, d2=0.532, g=1.993, time=0.45 sec
# > epoch=2, batch=105/300, d1=0.339, d2=0.511, g=2.380, time=0.45 sec
# > epoch=2, batch=106/300, d1=0.412, d2=0.511, g=1.707, time=0.45 sec
# > epoch=2, batch=107/300, d1=0.543, d2=0.643, g=2.100, time=0.45 sec
# > epoch=2, batch=108/300, d1=0.512, d2=0.536, g=1.839, time=0.45 sec
# > epoch=2, batch=109/300, d1=0.431, d2=0.800, g=2.068, time=0.45 sec
# > epoch=2, batch=110/300, d1=0.441, d2=0.505, g=1.709, time=0.45 sec
# > epoch=2, batch=111/300, d1=0.434, d2=0.605, g=1.911, time=0.45 sec
# > epoch=2, batch=112/300, d1=0.420, d2=0.490, g=1.737, time=0.45 sec
# > epoch=2, batch=113/300, d1=0.404, d2=0.599, g=2.102, time=0.45 sec
# > epoch=2, batch=114/300, d1=0.362, d2=0.493, g=1.983, time=0.45 sec
# > epoch=2, batch=115/300, d1=0.388, d2=0.580, g=1.812, time=0.45 sec
# > epoch=2, batch=116/300, d1=0.348, d2=0.472, g=1.607, time=0.45 sec
# > epoch=2, batch=117/300, d1=0.282, d2=0.564, g=1.911, time=0.45 sec
# > epoch=2, batch=118/300, d1=0.447, d2=0.637, g=2.436, time=0.45 sec
# > epoch=2, batch=119/300, d1=0.531, d2=0.682, g=2.291, time=0.45 sec
# > epoch=2, batch=120/300, d1=0.410, d2=0.541, g=1.327, time=0.45 sec
# > epoch=2, batch=121/300, d1=0.369, d2=0.632, g=1.805, time=0.45 sec
# > epoch=2, batch=122/300, d1=0.523, d2=0.496, g=2.001, time=0.45 sec
# > epoch=2, batch=123/300, d1=0.331, d2=0.580, g=1.752, time=0.45 sec
# > epoch=2, batch=124/300, d1=0.589, d2=0.451, g=2.122, time=0.45 sec
# > epoch=2, batch=125/300, d1=0.574, d2=0.528, g=1.535, time=0.45 sec
# > epoch=2, batch=126/300, d1=0.519, d2=0.545, g=1.612, time=0.45 sec
# > epoch=2, batch=127/300, d1=0.327, d2=0.484, g=1.485, time=0.45 sec
# > epoch=2, batch=128/300, d1=0.412, d2=0.649, g=1.668, time=0.45 sec
# > epoch=2, batch=129/300, d1=0.246, d2=0.511, g=2.456, time=0.45 sec
# > epoch=2, batch=130/300, d1=0.372, d2=0.496, g=1.689, time=0.45 sec
# > epoch=2, batch=131/300, d1=0.484, d2=0.573, g=1.672, time=0.45 sec
# > epoch=2, batch=132/300, d1=0.470, d2=0.512, g=1.934, time=0.45 sec
# > epoch=2, batch=133/300, d1=0.382, d2=0.564, g=1.953, time=0.45 sec
# > epoch=2, batch=134/300, d1=0.301, d2=0.536, g=2.138, time=0.45 sec
# > epoch=2, batch=135/300, d1=0.451, d2=0.490, g=2.344, time=0.45 sec
# > epoch=2, batch=136/300, d1=0.441, d2=0.533, g=1.595, time=0.45 sec
# > epoch=2, batch=137/300, d1=0.271, d2=0.556, g=1.864, time=0.45 sec
# > epoch=2, batch=138/300, d1=0.365, d2=0.552, g=2.443, time=0.45 sec
# > epoch=2, batch=139/300, d1=0.562, d2=0.786, g=2.316, time=0.45 sec
# > epoch=2, batch=140/300, d1=0.393, d2=0.509, g=1.901, time=0.45 sec
# > epoch=2, batch=141/300, d1=0.480, d2=0.609, g=1.585, time=0.45 sec
# > epoch=2, batch=142/300, d1=0.253, d2=0.586, g=1.651, time=0.45 sec
# > epoch=2, batch=143/300, d1=0.301, d2=0.567, g=1.796, time=0.45 sec
# > epoch=2, batch=144/300, d1=0.265, d2=0.581, g=1.830, time=0.45 sec
# > epoch=2, batch=145/300, d1=0.373, d2=0.535, g=1.957, time=0.45 sec
# > epoch=2, batch=146/300, d1=0.495, d2=0.535, g=1.939, time=0.45 sec
# > epoch=2, batch=147/300, d1=0.459, d2=0.667, g=1.809, time=0.45 sec
# > epoch=2, batch=148/300, d1=0.398, d2=0.509, g=1.815, time=0.45 sec
# > epoch=2, batch=149/300, d1=0.346, d2=0.667, g=1.864, time=0.45 sec
# > epoch=2, batch=150/300, d1=0.492, d2=0.532, g=1.985, time=0.45 sec
# > epoch=2, batch=151/300, d1=0.362, d2=0.509, g=1.548, time=0.45 sec
# > epoch=2, batch=152/300, d1=0.261, d2=0.586, g=2.239, time=0.45 sec
# > epoch=2, batch=153/300, d1=0.447, d2=0.512, g=2.066, time=0.45 sec
# > epoch=2, batch=154/300, d1=0.637, d2=0.761, g=1.824, time=0.45 sec
# > epoch=2, batch=155/300, d1=0.345, d2=0.534, g=1.565, time=0.45 sec
# > epoch=2, batch=156/300, d1=0.450, d2=0.573, g=1.426, time=0.45 sec
# > epoch=2, batch=157/300, d1=0.441, d2=0.643, g=1.884, time=0.45 sec
# > epoch=2, batch=158/300, d1=0.537, d2=0.496, g=1.704, time=0.45 sec
# > epoch=2, batch=159/300, d1=0.397, d2=0.560, g=1.973, time=0.45 sec
# > epoch=2, batch=160/300, d1=0.592, d2=0.483, g=2.000, time=0.45 sec
# > epoch=2, batch=161/300, d1=0.386, d2=0.597, g=1.610, time=0.45 sec
# > epoch=2, batch=162/300, d1=0.323, d2=0.516, g=1.737, time=0.45 sec
# > epoch=2, batch=163/300, d1=0.448, d2=0.568, g=1.888, time=0.45 sec
# > epoch=2, batch=164/300, d1=0.454, d2=0.490, g=2.308, time=0.45 sec
# > epoch=2, batch=165/300, d1=0.479, d2=0.492, g=1.801, time=0.45 sec
# > epoch=2, batch=166/300, d1=0.392, d2=0.612, g=1.676, time=0.45 sec
# > epoch=2, batch=167/300, d1=0.369, d2=0.503, g=2.353, time=0.45 sec
# > epoch=2, batch=168/300, d1=0.514, d2=0.487, g=2.000, time=0.45 sec
# > epoch=2, batch=169/300, d1=0.350, d2=0.605, g=1.535, time=0.45 sec
# > epoch=2, batch=170/300, d1=0.292, d2=0.464, g=1.849, time=0.45 sec
# > epoch=2, batch=171/300, d1=0.136, d2=0.506, g=2.311, time=0.45 sec
# > epoch=2, batch=172/300, d1=0.468, d2=0.601, g=2.035, time=0.45 sec
# > epoch=2, batch=173/300, d1=0.535, d2=0.453, g=2.022, time=0.45 sec
# > epoch=2, batch=174/300, d1=0.463, d2=0.532, g=1.893, time=0.45 sec
# > epoch=2, batch=175/300, d1=0.423, d2=0.545, g=1.566, time=0.45 sec
# > epoch=2, batch=176/300, d1=0.296, d2=0.508, g=1.975, time=0.45 sec
# > epoch=2, batch=177/300, d1=0.374, d2=0.561, g=2.429, time=0.45 sec
# > epoch=2, batch=178/300, d1=0.395, d2=0.454, g=1.982, time=0.45 sec
# > epoch=2, batch=179/300, d1=0.349, d2=0.568, g=2.258, time=0.45 sec
# > epoch=2, batch=180/300, d1=0.461, d2=0.479, g=2.408, time=0.45 sec
# > epoch=2, batch=181/300, d1=0.475, d2=0.544, g=1.363, time=0.45 sec
# > epoch=2, batch=182/300, d1=0.263, d2=0.741, g=1.980, time=0.45 sec
# > epoch=2, batch=183/300, d1=0.289, d2=0.565, g=2.115, time=0.45 sec
# > epoch=2, batch=184/300, d1=0.473, d2=0.502, g=1.590, time=0.45 sec
# > epoch=2, batch=185/300, d1=0.321, d2=0.581, g=1.719, time=0.45 sec
# > epoch=2, batch=186/300, d1=0.365, d2=0.475, g=1.748, time=0.45 sec
# > epoch=2, batch=187/300, d1=0.311, d2=0.625, g=1.798, time=0.45 sec
# > epoch=2, batch=188/300, d1=0.346, d2=0.529, g=1.938, time=0.45 sec
# > epoch=2, batch=189/300, d1=0.438, d2=0.480, g=2.133, time=0.45 sec
# > epoch=2, batch=190/300, d1=0.450, d2=0.610, g=2.075, time=0.45 sec
# > epoch=2, batch=191/300, d1=0.418, d2=0.519, g=1.610, time=0.45 sec
# > epoch=2, batch=192/300, d1=0.379, d2=0.574, g=1.761, time=0.45 sec
# > epoch=2, batch=193/300, d1=0.431, d2=0.513, g=1.981, time=0.45 sec
# > epoch=2, batch=194/300, d1=0.503, d2=0.484, g=1.549, time=0.45 sec
# > epoch=2, batch=195/300, d1=0.362, d2=0.567, g=1.898, time=0.45 sec
# > epoch=2, batch=196/300, d1=0.288, d2=0.576, g=2.399, time=0.45 sec
# > epoch=2, batch=197/300, d1=0.357, d2=0.543, g=1.969, time=0.45 sec
# > epoch=2, batch=198/300, d1=0.277, d2=0.589, g=1.678, time=0.45 sec
# > epoch=2, batch=199/300, d1=0.388, d2=0.540, g=2.068, time=0.45 sec
# > epoch=2, batch=200/300, d1=0.545, d2=0.516, g=2.068, time=0.45 sec
# > epoch=2, batch=201/300, d1=0.472, d2=0.600, g=1.913, time=0.45 sec
# > epoch=2, batch=202/300, d1=0.606, d2=0.560, g=1.667, time=0.45 sec
# > epoch=2, batch=203/300, d1=0.381, d2=0.530, g=1.632, time=0.45 sec
# > epoch=2, batch=204/300, d1=0.416, d2=0.555, g=2.266, time=0.45 sec
# > epoch=2, batch=205/300, d1=0.552, d2=0.564, g=1.692, time=0.45 sec
# > epoch=2, batch=206/300, d1=0.279, d2=0.518, g=1.541, time=0.45 sec
# > epoch=2, batch=207/300, d1=0.446, d2=0.519, g=1.986, time=0.45 sec
# > epoch=2, batch=208/300, d1=0.439, d2=0.546, g=1.946, time=0.45 sec
# > epoch=2, batch=209/300, d1=0.411, d2=0.542, g=2.260, time=0.45 sec
# > epoch=2, batch=210/300, d1=0.492, d2=0.529, g=1.767, time=0.45 sec
# > epoch=2, batch=211/300, d1=0.331, d2=0.529, g=1.918, time=0.45 sec
# > epoch=2, batch=212/300, d1=0.227, d2=0.522, g=1.809, time=0.45 sec
# > epoch=2, batch=213/300, d1=0.317, d2=0.497, g=3.127, time=0.45 sec
# > epoch=2, batch=214/300, d1=0.470, d2=0.536, g=1.417, time=0.45 sec
# > epoch=2, batch=215/300, d1=0.230, d2=0.616, g=2.228, time=0.45 sec
# > epoch=2, batch=216/300, d1=0.371, d2=0.605, g=1.619, time=0.45 sec
# > epoch=2, batch=217/300, d1=0.322, d2=0.952, g=1.641, time=0.45 sec
# > epoch=2, batch=218/300, d1=0.451, d2=0.545, g=2.955, time=0.45 sec
# > epoch=2, batch=219/300, d1=0.497, d2=0.506, g=1.682, time=0.45 sec
# > epoch=2, batch=220/300, d1=0.440, d2=0.545, g=2.131, time=0.45 sec
# > epoch=2, batch=221/300, d1=0.373, d2=0.549, g=1.661, time=0.45 sec
# > epoch=2, batch=222/300, d1=0.436, d2=0.688, g=1.724, time=0.45 sec
# > epoch=2, batch=223/300, d1=0.434, d2=0.552, g=1.687, time=0.45 sec
# > epoch=2, batch=224/300, d1=0.212, d2=0.441, g=1.906, time=0.45 sec
# > epoch=2, batch=225/300, d1=0.462, d2=0.551, g=1.885, time=0.45 sec
# > epoch=2, batch=226/300, d1=0.310, d2=0.481, g=1.622, time=0.45 sec
# > epoch=2, batch=227/300, d1=0.444, d2=0.550, g=1.860, time=0.45 sec
# > epoch=2, batch=228/300, d1=0.309, d2=0.491, g=1.680, time=0.45 sec
# > epoch=2, batch=229/300, d1=0.274, d2=0.618, g=1.990, time=0.45 sec
# > epoch=2, batch=230/300, d1=0.325, d2=0.547, g=2.207, time=0.45 sec
# > epoch=2, batch=231/300, d1=0.439, d2=0.525, g=2.209, time=0.45 sec
# > epoch=2, batch=232/300, d1=0.389, d2=0.593, g=1.411, time=0.45 sec
# > epoch=2, batch=233/300, d1=0.204, d2=0.540, g=1.631, time=0.45 sec
# > epoch=2, batch=234/300, d1=0.476, d2=0.568, g=2.444, time=0.45 sec
# > epoch=2, batch=235/300, d1=0.485, d2=0.565, g=2.168, time=0.45 sec
# > epoch=2, batch=236/300, d1=0.433, d2=0.594, g=1.632, time=0.45 sec
# > epoch=2, batch=237/300, d1=0.324, d2=1.062, g=2.786, time=0.45 sec
# > epoch=2, batch=238/300, d1=0.545, d2=0.596, g=1.800, time=0.45 sec
# > epoch=2, batch=239/300, d1=0.366, d2=0.608, g=1.771, time=0.45 sec
# > epoch=2, batch=240/300, d1=0.310, d2=0.474, g=1.626, time=0.45 sec
# > epoch=2, batch=241/300, d1=0.425, d2=0.557, g=1.737, time=0.45 sec
# > epoch=2, batch=242/300, d1=0.310, d2=0.527, g=1.782, time=0.45 sec
# > epoch=2, batch=243/300, d1=0.509, d2=0.490, g=2.149, time=0.45 sec
# > epoch=2, batch=244/300, d1=0.482, d2=0.443, g=1.988, time=0.45 sec
# > epoch=2, batch=245/300, d1=0.372, d2=0.502, g=1.540, time=0.45 sec
# > epoch=2, batch=246/300, d1=0.354, d2=0.521, g=1.825, time=0.45 sec
# > epoch=2, batch=247/300, d1=0.352, d2=0.513, g=1.626, time=0.45 sec
# > epoch=2, batch=248/300, d1=0.413, d2=0.540, g=1.837, time=0.45 sec
# > epoch=2, batch=249/300, d1=0.380, d2=0.499, g=1.954, time=0.45 sec
# > epoch=2, batch=250/300, d1=0.423, d2=0.580, g=1.746, time=0.45 sec
# > epoch=2, batch=251/300, d1=0.423, d2=0.452, g=1.956, time=0.45 sec
# > epoch=2, batch=252/300, d1=0.441, d2=0.532, g=2.280, time=0.45 sec
# > epoch=2, batch=253/300, d1=0.454, d2=0.457, g=1.931, time=0.45 sec
# > epoch=2, batch=254/300, d1=0.330, d2=0.574, g=2.135, time=0.45 sec
# > epoch=2, batch=255/300, d1=0.318, d2=0.500, g=1.923, time=0.45 sec
# > epoch=2, batch=256/300, d1=0.293, d2=0.458, g=1.926, time=0.45 sec
# > epoch=2, batch=257/300, d1=0.398, d2=0.555, g=1.604, time=0.45 sec
# > epoch=2, batch=258/300, d1=0.336, d2=0.535, g=2.292, time=0.45 sec
# > epoch=2, batch=259/300, d1=0.332, d2=0.496, g=1.516, time=0.45 sec
# > epoch=2, batch=260/300, d1=0.417, d2=0.560, g=2.009, time=0.45 sec
# > epoch=2, batch=261/300, d1=0.292, d2=0.554, g=1.640, time=0.45 sec
# > epoch=2, batch=262/300, d1=0.272, d2=0.636, g=2.296, time=0.45 sec
# > epoch=2, batch=263/300, d1=0.309, d2=0.571, g=1.635, time=0.45 sec
# > epoch=2, batch=264/300, d1=0.357, d2=0.548, g=1.981, time=0.45 sec
# > epoch=2, batch=265/300, d1=0.371, d2=0.528, g=1.845, time=0.45 sec
# > epoch=2, batch=266/300, d1=0.392, d2=0.509, g=2.076, time=0.45 sec
# > epoch=2, batch=267/300, d1=0.508, d2=0.559, g=2.002, time=0.45 sec
# > epoch=2, batch=268/300, d1=0.346, d2=0.519, g=2.072, time=0.45 sec
# > epoch=2, batch=269/300, d1=0.461, d2=0.670, g=1.811, time=0.45 sec
# > epoch=2, batch=270/300, d1=0.355, d2=0.544, g=1.832, time=0.45 sec
# > epoch=2, batch=271/300, d1=0.242, d2=0.576, g=2.290, time=0.45 sec
# > epoch=2, batch=272/300, d1=0.479, d2=0.547, g=1.831, time=0.45 sec
# > epoch=2, batch=273/300, d1=0.431, d2=0.676, g=2.244, time=0.45 sec
# > epoch=2, batch=274/300, d1=0.328, d2=0.470, g=1.721, time=0.45 sec
# > epoch=2, batch=275/300, d1=0.360, d2=0.558, g=1.662, time=0.45 sec
# > epoch=2, batch=276/300, d1=0.311, d2=0.636, g=1.838, time=0.46 sec
# > epoch=2, batch=277/300, d1=0.439, d2=0.586, g=1.799, time=0.45 sec
# > epoch=2, batch=278/300, d1=0.523, d2=0.625, g=1.441, time=0.45 sec
# > epoch=2, batch=279/300, d1=0.389, d2=0.608, g=1.875, time=0.45 sec
# > epoch=2, batch=280/300, d1=0.396, d2=0.443, g=2.057, time=0.45 sec
# > epoch=2, batch=281/300, d1=0.309, d2=0.486, g=1.771, time=0.45 sec
# > epoch=2, batch=282/300, d1=0.555, d2=0.525, g=1.749, time=0.46 sec
# > epoch=2, batch=283/300, d1=0.408, d2=0.630, g=1.545, time=0.45 sec
# > epoch=2, batch=284/300, d1=0.419, d2=0.512, g=2.075, time=0.46 sec
# > epoch=2, batch=285/300, d1=0.411, d2=0.550, g=2.277, time=0.45 sec
# > epoch=2, batch=286/300, d1=0.405, d2=0.550, g=1.725, time=0.45 sec
# > epoch=2, batch=287/300, d1=0.254, d2=0.543, g=2.230, time=0.45 sec
# > epoch=2, batch=288/300, d1=0.323, d2=0.494, g=1.557, time=0.45 sec
# > epoch=2, batch=289/300, d1=0.328, d2=0.560, g=1.992, time=0.45 sec
# > epoch=2, batch=290/300, d1=0.405, d2=0.549, g=1.513, time=0.45 sec
# > epoch=2, batch=291/300, d1=0.388, d2=0.828, g=2.028, time=0.45 sec
# > epoch=2, batch=292/300, d1=0.474, d2=0.525, g=1.574, time=0.45 sec
# > epoch=2, batch=293/300, d1=0.298, d2=0.606, g=1.870, time=0.45 sec
# > epoch=2, batch=294/300, d1=0.405, d2=0.505, g=1.901, time=0.45 sec
# > epoch=2, batch=295/300, d1=0.218, d2=0.517, g=1.772, time=0.45 sec
# > epoch=2, batch=296/300, d1=0.440, d2=0.574, g=1.815, time=0.45 sec
# > epoch=2, batch=297/300, d1=0.358, d2=0.481, g=1.705, time=0.45 sec
# > epoch=2, batch=298/300, d1=0.236, d2=0.575, g=2.115, time=0.45 sec
# > epoch=2, batch=299/300, d1=0.412, d2=0.511, g=2.465, time=0.45 sec
# > epoch=2, batch=300/300, d1=0.370, d2=0.549, g=1.678, time=0.45 sec
#
# > epoch=3, batch=1/300, d1=0.356, d2=0.608, g=2.174, time=0.89 sec
# > epoch=3, batch=2/300, d1=0.320, d2=0.532, g=2.093, time=0.45 sec
# > epoch=3, batch=3/300, d1=0.436, d2=0.529, g=1.590, time=0.45 sec
# > epoch=3, batch=4/300, d1=0.498, d2=0.553, g=1.597, time=0.45 sec
# > epoch=3, batch=5/300, d1=0.570, d2=0.818, g=1.571, time=0.45 sec
# > epoch=3, batch=6/300, d1=0.368, d2=0.491, g=1.990, time=0.45 sec
# > epoch=3, batch=7/300, d1=0.465, d2=0.491, g=1.869, time=0.45 sec
# > epoch=3, batch=8/300, d1=0.393, d2=0.540, g=1.826, time=0.45 sec
# > epoch=3, batch=9/300, d1=0.518, d2=0.497, g=1.593, time=0.45 sec
# > epoch=3, batch=10/300, d1=0.457, d2=0.540, g=1.786, time=0.45 sec
# > epoch=3, batch=11/300, d1=0.359, d2=0.564, g=2.001, time=0.45 sec
# > epoch=3, batch=12/300, d1=0.453, d2=0.498, g=1.729, time=0.45 sec
# > epoch=3, batch=13/300, d1=0.412, d2=0.658, g=2.292, time=0.45 sec
# > epoch=3, batch=14/300, d1=0.593, d2=0.554, g=1.694, time=0.45 sec
# > epoch=3, batch=15/300, d1=0.240, d2=0.563, g=1.490, time=0.45 sec
# > epoch=3, batch=16/300, d1=0.283, d2=0.544, g=1.408, time=0.45 sec
# > epoch=3, batch=17/300, d1=0.303, d2=0.517, g=2.516, time=0.45 sec
# > epoch=3, batch=18/300, d1=0.484, d2=0.490, g=1.514, time=0.45 sec
# > epoch=3, batch=19/300, d1=0.352, d2=0.542, g=1.538, time=0.45 sec
# > epoch=3, batch=20/300, d1=0.466, d2=0.437, g=1.934, time=0.45 sec
# > epoch=3, batch=21/300, d1=0.458, d2=0.593, g=1.619, time=0.45 sec
# > epoch=3, batch=22/300, d1=0.439, d2=0.507, g=1.763, time=0.45 sec
# > epoch=3, batch=23/300, d1=0.532, d2=0.561, g=1.586, time=0.45 sec
# > epoch=3, batch=24/300, d1=0.312, d2=0.603, g=1.814, time=0.45 sec
# > epoch=3, batch=25/300, d1=0.337, d2=0.511, g=1.906, time=0.45 sec
# > epoch=3, batch=26/300, d1=0.478, d2=0.553, g=1.538, time=0.45 sec
# > epoch=3, batch=27/300, d1=0.448, d2=0.522, g=1.912, time=0.45 sec
# > epoch=3, batch=28/300, d1=0.394, d2=0.553, g=1.681, time=0.45 sec
# > epoch=3, batch=29/300, d1=0.298, d2=0.538, g=1.757, time=0.45 sec
# > epoch=3, batch=30/300, d1=0.453, d2=0.597, g=2.129, time=0.45 sec
# > epoch=3, batch=31/300, d1=0.400, d2=0.561, g=1.871, time=0.45 sec
# > epoch=3, batch=32/300, d1=0.330, d2=0.554, g=2.166, time=0.45 sec
# > epoch=3, batch=33/300, d1=0.409, d2=0.531, g=2.029, time=0.45 sec
# > epoch=3, batch=34/300, d1=0.430, d2=0.595, g=2.196, time=0.45 sec
# ...
# > epoch=196, batch=82/300, d1=0.101, d2=0.487, g=1.490, time=0.45 sec
# > epoch=196, batch=83/300, d1=0.397, d2=0.562, g=2.058, time=0.45 sec
# > epoch=196, batch=84/300, d1=0.191, d2=0.536, g=1.653, time=0.45 sec
# > epoch=196, batch=85/300, d1=0.355, d2=0.522, g=1.788, time=0.45 sec
# > epoch=196, batch=86/300, d1=0.383, d2=0.477, g=1.937, time=0.45 sec
# > epoch=196, batch=87/300, d1=0.317, d2=0.494, g=1.922, time=0.45 sec
# > epoch=196, batch=88/300, d1=0.404, d2=0.637, g=2.130, time=0.46 sec
# > epoch=196, batch=89/300, d1=0.443, d2=0.492, g=1.850, time=0.45 sec
# > epoch=196, batch=90/300, d1=0.357, d2=0.513, g=1.804, time=0.45 sec
# > epoch=196, batch=91/300, d1=0.438, d2=0.632, g=1.822, time=0.46 sec
# > epoch=196, batch=92/300, d1=0.520, d2=0.497, g=1.914, time=0.45 sec
# > epoch=196, batch=93/300, d1=0.282, d2=0.481, g=1.595, time=0.46 sec
# > epoch=196, batch=94/300, d1=0.248, d2=0.533, g=1.700, time=0.45 sec
# > epoch=196, batch=95/300, d1=0.491, d2=0.528, g=2.131, time=0.45 sec
# > epoch=196, batch=96/300, d1=0.465, d2=0.492, g=1.810, time=0.46 sec
# > epoch=196, batch=97/300, d1=0.397, d2=0.520, g=1.754, time=0.45 sec
# > epoch=196, batch=98/300, d1=0.497, d2=0.527, g=1.475, time=0.45 sec
# > epoch=196, batch=99/300, d1=0.325, d2=0.580, g=1.865, time=0.46 sec
# > epoch=196, batch=100/300, d1=0.448, d2=0.471, g=2.044, time=0.45 sec
# > epoch=196, batch=101/300, d1=0.341, d2=0.507, g=1.578, time=0.46 sec
# > epoch=196, batch=102/300, d1=0.251, d2=0.614, g=1.744, time=0.45 sec
# > epoch=196, batch=103/300, d1=0.425, d2=0.531, g=1.923, time=0.45 sec
# > epoch=196, batch=104/300, d1=0.483, d2=0.498, g=1.879, time=0.45 sec
# > epoch=196, batch=105/300, d1=0.307, d2=0.559, g=1.707, time=0.45 sec
# > epoch=196, batch=106/300, d1=0.387, d2=0.499, g=1.804, time=0.45 sec
# > epoch=196, batch=107/300, d1=0.270, d2=0.493, g=1.801, time=0.45 sec
# > epoch=196, batch=108/300, d1=0.374, d2=0.586, g=1.769, time=0.45 sec
# > epoch=196, batch=109/300, d1=0.284, d2=0.523, g=1.501, time=0.46 sec
# > epoch=196, batch=110/300, d1=0.343, d2=0.501, g=1.867, time=0.45 sec
# > epoch=196, batch=111/300, d1=0.455, d2=0.526, g=1.941, time=0.45 sec
# > epoch=196, batch=112/300, d1=0.419, d2=0.479, g=1.561, time=0.45 sec
# > epoch=196, batch=113/300, d1=0.283, d2=0.568, g=1.950, time=0.45 sec
# > epoch=196, batch=114/300, d1=0.349, d2=0.440, g=1.944, time=0.45 sec
# > epoch=196, batch=115/300, d1=0.389, d2=0.507, g=1.642, time=0.45 sec
# > epoch=196, batch=116/300, d1=0.489, d2=0.574, g=1.590, time=0.45 sec
# > epoch=196, batch=117/300, d1=0.351, d2=0.526, g=1.471, time=0.45 sec
# > epoch=196, batch=118/300, d1=0.470, d2=0.579, g=1.609, time=0.45 sec
# > epoch=196, batch=119/300, d1=0.420, d2=0.570, g=1.876, time=0.45 sec
# > epoch=196, batch=120/300, d1=0.383, d2=0.490, g=1.954, time=0.45 sec
# > epoch=196, batch=121/300, d1=0.491, d2=0.557, g=1.390, time=0.45 sec
# > epoch=196, batch=122/300, d1=0.259, d2=0.618, g=1.618, time=0.45 sec
# > epoch=196, batch=123/300, d1=0.405, d2=0.515, g=1.913, time=0.45 sec
# > epoch=196, batch=124/300, d1=0.252, d2=0.508, g=1.900, time=0.45 sec
# > epoch=196, batch=125/300, d1=0.365, d2=0.488, g=1.736, time=0.45 sec
# > epoch=196, batch=126/300, d1=0.494, d2=0.548, g=1.709, time=0.45 sec
# > epoch=196, batch=127/300, d1=0.253, d2=0.472, g=1.747, time=0.45 sec
# > epoch=196, batch=128/300, d1=0.219, d2=0.473, g=1.843, time=0.45 sec
# > epoch=196, batch=129/300, d1=0.485, d2=0.481, g=1.897, time=0.45 sec
# > epoch=196, batch=130/300, d1=0.346, d2=0.510, g=1.413, time=0.45 sec
# > epoch=196, batch=131/300, d1=0.046, d2=0.576, g=2.098, time=0.45 sec
# > epoch=196, batch=132/300, d1=0.405, d2=0.485, g=1.999, time=0.45 sec
# > epoch=196, batch=133/300, d1=0.447, d2=0.551, g=1.880, time=0.45 sec
# > epoch=196, batch=134/300, d1=0.346, d2=0.594, g=1.697, time=0.45 sec
# > epoch=196, batch=135/300, d1=0.528, d2=0.449, g=1.728, time=0.45 sec
# > epoch=196, batch=136/300, d1=0.344, d2=0.482, g=1.681, time=0.45 sec
# > epoch=196, batch=137/300, d1=0.325, d2=0.594, g=2.169, time=0.45 sec
# > epoch=196, batch=138/300, d1=0.408, d2=0.565, g=1.735, time=0.45 sec
# > epoch=196, batch=139/300, d1=0.370, d2=0.534, g=2.235, time=0.45 sec
# > epoch=196, batch=140/300, d1=0.390, d2=0.439, g=2.027, time=0.45 sec
# > epoch=196, batch=141/300, d1=0.494, d2=0.499, g=1.564, time=0.45 sec
# > epoch=196, batch=142/300, d1=0.388, d2=0.552, g=1.726, time=0.45 sec
# > epoch=196, batch=143/300, d1=0.307, d2=0.562, g=1.466, time=0.46 sec
# > epoch=196, batch=144/300, d1=0.381, d2=0.552, g=1.868, time=0.45 sec
# > epoch=196, batch=145/300, d1=0.445, d2=0.451, g=1.750, time=0.46 sec
# > epoch=196, batch=146/300, d1=0.585, d2=0.459, g=1.904, time=0.45 sec
# > epoch=196, batch=147/300, d1=0.488, d2=0.582, g=1.567, time=0.45 sec
# > epoch=196, batch=148/300, d1=0.462, d2=0.523, g=1.707, time=0.46 sec
# > epoch=196, batch=149/300, d1=0.425, d2=0.566, g=1.859, time=0.45 sec
# > epoch=196, batch=150/300, d1=0.474, d2=0.474, g=1.907, time=0.45 sec
# > epoch=196, batch=151/300, d1=0.431, d2=0.549, g=1.816, time=0.46 sec
# > epoch=196, batch=152/300, d1=0.305, d2=0.507, g=2.002, time=0.45 sec
# > epoch=196, batch=153/300, d1=0.351, d2=0.532, g=1.532, time=0.46 sec
# > epoch=196, batch=154/300, d1=0.419, d2=0.540, g=2.025, time=0.45 sec
# > epoch=196, batch=155/300, d1=0.401, d2=0.506, g=1.864, time=0.45 sec
# > epoch=196, batch=156/300, d1=0.474, d2=0.714, g=1.796, time=0.49 sec
# > epoch=196, batch=157/300, d1=0.323, d2=0.559, g=2.047, time=0.45 sec
# > epoch=196, batch=158/300, d1=0.389, d2=0.529, g=1.543, time=0.46 sec
# > epoch=196, batch=159/300, d1=0.381, d2=0.482, g=1.971, time=0.45 sec
# > epoch=196, batch=160/300, d1=0.549, d2=0.501, g=1.706, time=0.46 sec
# > epoch=196, batch=161/300, d1=0.457, d2=0.536, g=1.658, time=0.45 sec
# > epoch=196, batch=162/300, d1=0.335, d2=0.638, g=1.654, time=0.45 sec
# > epoch=196, batch=163/300, d1=0.365, d2=0.485, g=1.624, time=0.47 sec
# > epoch=196, batch=164/300, d1=0.429, d2=0.497, g=1.592, time=0.47 sec
# > epoch=196, batch=165/300, d1=0.386, d2=0.521, g=1.717, time=0.47 sec
# > epoch=196, batch=166/300, d1=0.449, d2=0.522, g=1.669, time=0.45 sec
# > epoch=196, batch=167/300, d1=0.216, d2=0.588, g=1.657, time=0.46 sec
# > epoch=196, batch=168/300, d1=0.398, d2=0.518, g=1.656, time=0.48 sec
# > epoch=196, batch=169/300, d1=0.668, d2=0.518, g=1.472, time=0.46 sec
# > epoch=196, batch=170/300, d1=0.430, d2=0.527, g=1.599, time=0.45 sec
# > epoch=196, batch=171/300, d1=0.440, d2=0.602, g=1.486, time=0.45 sec
# > epoch=196, batch=172/300, d1=0.468, d2=0.526, g=1.731, time=0.46 sec
# > epoch=196, batch=173/300, d1=0.308, d2=0.536, g=1.780, time=0.47 sec
# > epoch=196, batch=174/300, d1=0.291, d2=0.524, g=1.643, time=0.45 sec
# > epoch=196, batch=175/300, d1=0.268, d2=0.539, g=1.653, time=0.46 sec
# > epoch=196, batch=176/300, d1=0.257, d2=0.455, g=1.733, time=0.46 sec
# > epoch=196, batch=177/300, d1=0.324, d2=0.640, g=2.209, time=0.45 sec
# > epoch=196, batch=178/300, d1=0.442, d2=0.472, g=2.056, time=0.45 sec
# > epoch=196, batch=179/300, d1=0.423, d2=0.544, g=1.460, time=0.45 sec
# > epoch=196, batch=180/300, d1=0.437, d2=0.534, g=1.943, time=0.45 sec
# > epoch=196, batch=181/300, d1=0.441, d2=0.594, g=1.670, time=0.45 sec
# > epoch=196, batch=182/300, d1=0.431, d2=0.545, g=1.529, time=0.45 sec
# > epoch=196, batch=183/300, d1=0.399, d2=0.467, g=1.963, time=0.45 sec
# > epoch=196, batch=184/300, d1=0.386, d2=0.501, g=1.791, time=0.45 sec
# > epoch=196, batch=185/300, d1=0.310, d2=0.522, g=1.413, time=0.45 sec
# > epoch=196, batch=186/300, d1=0.338, d2=0.558, g=1.433, time=0.45 sec
# > epoch=196, batch=187/300, d1=0.320, d2=0.544, g=1.559, time=0.45 sec
# > epoch=196, batch=188/300, d1=0.428, d2=0.503, g=1.667, time=0.45 sec
# > epoch=196, batch=189/300, d1=0.403, d2=0.552, g=1.549, time=0.45 sec
# > epoch=196, batch=190/300, d1=0.304, d2=0.508, g=1.817, time=0.45 sec
# > epoch=196, batch=191/300, d1=0.451, d2=0.445, g=1.735, time=0.45 sec
# > epoch=196, batch=192/300, d1=0.240, d2=0.563, g=1.677, time=0.45 sec
# > epoch=196, batch=193/300, d1=0.521, d2=0.534, g=2.064, time=0.45 sec
# > epoch=196, batch=194/300, d1=0.502, d2=0.477, g=1.501, time=0.45 sec
# > epoch=196, batch=195/300, d1=0.355, d2=0.568, g=1.472, time=0.45 sec
# > epoch=196, batch=196/300, d1=0.295, d2=0.569, g=2.064, time=0.45 sec
# > epoch=196, batch=197/300, d1=0.445, d2=0.471, g=1.751, time=0.45 sec
# > epoch=196, batch=198/300, d1=0.435, d2=0.594, g=1.492, time=0.45 sec
# > epoch=196, batch=199/300, d1=0.304, d2=0.539, g=1.846, time=0.46 sec
# > epoch=196, batch=200/300, d1=0.443, d2=0.458, g=1.895, time=0.45 sec
# > epoch=196, batch=201/300, d1=0.267, d2=0.434, g=1.889, time=0.45 sec
# > epoch=196, batch=202/300, d1=0.394, d2=0.450, g=1.508, time=0.45 sec
# > epoch=196, batch=203/300, d1=0.394, d2=0.495, g=1.711, time=0.45 sec
# > epoch=196, batch=204/300, d1=0.317, d2=0.477, g=1.659, time=0.45 sec
# > epoch=196, batch=205/300, d1=0.461, d2=0.467, g=1.800, time=0.45 sec
# > epoch=196, batch=206/300, d1=0.355, d2=0.525, g=1.422, time=0.45 sec
# > epoch=196, batch=207/300, d1=0.426, d2=0.562, g=2.010, time=0.45 sec
# > epoch=196, batch=208/300, d1=0.438, d2=0.573, g=1.674, time=0.45 sec
# > epoch=196, batch=209/300, d1=0.265, d2=0.545, g=1.600, time=0.46 sec
# > epoch=196, batch=210/300, d1=0.266, d2=0.519, g=1.893, time=0.45 sec
# > epoch=196, batch=211/300, d1=0.520, d2=0.498, g=1.984, time=0.45 sec
# > epoch=196, batch=212/300, d1=0.353, d2=0.555, g=1.561, time=0.46 sec
# > epoch=196, batch=213/300, d1=0.324, d2=0.514, g=1.719, time=0.45 sec
# > epoch=196, batch=214/300, d1=0.514, d2=0.458, g=1.750, time=0.45 sec
# > epoch=196, batch=215/300, d1=0.387, d2=0.520, g=1.658, time=0.45 sec
# > epoch=196, batch=216/300, d1=0.497, d2=0.492, g=1.534, time=0.45 sec
# > epoch=196, batch=217/300, d1=0.408, d2=0.552, g=1.710, time=0.45 sec
# > epoch=196, batch=218/300, d1=0.405, d2=0.535, g=1.810, time=0.45 sec
# > epoch=196, batch=219/300, d1=0.452, d2=0.468, g=1.844, time=0.45 sec
# > epoch=196, batch=220/300, d1=0.309, d2=0.461, g=1.683, time=0.45 sec
# > epoch=196, batch=221/300, d1=0.203, d2=0.517, g=1.891, time=0.45 sec
# > epoch=196, batch=222/300, d1=0.583, d2=0.491, g=1.913, time=0.45 sec
# > epoch=196, batch=223/300, d1=0.351, d2=0.484, g=1.385, time=0.45 sec
# > epoch=196, batch=224/300, d1=0.314, d2=0.557, g=1.664, time=0.45 sec
# > epoch=196, batch=225/300, d1=0.368, d2=0.477, g=1.728, time=0.46 sec
# > epoch=196, batch=226/300, d1=0.251, d2=0.431, g=1.569, time=0.45 sec
# > epoch=196, batch=227/300, d1=0.234, d2=0.509, g=1.531, time=0.45 sec
# > epoch=196, batch=228/300, d1=0.226, d2=0.530, g=1.956, time=0.45 sec
# > epoch=196, batch=229/300, d1=0.398, d2=0.486, g=1.544, time=0.45 sec
# > epoch=196, batch=230/300, d1=0.270, d2=0.509, g=1.661, time=0.45 sec
# > epoch=196, batch=231/300, d1=0.379, d2=0.503, g=2.189, time=0.45 sec
# > epoch=196, batch=232/300, d1=0.345, d2=0.475, g=2.312, time=0.45 sec
# > epoch=196, batch=233/300, d1=0.400, d2=0.543, g=1.769, time=0.45 sec
# > epoch=196, batch=234/300, d1=0.257, d2=0.435, g=1.534, time=0.45 sec
# > epoch=196, batch=235/300, d1=0.284, d2=0.681, g=2.147, time=0.46 sec
# > epoch=196, batch=236/300, d1=0.491, d2=0.438, g=2.274, time=0.45 sec
# > epoch=196, batch=237/300, d1=0.518, d2=0.568, g=1.741, time=0.45 sec
# > epoch=196, batch=238/300, d1=0.482, d2=0.508, g=1.423, time=0.45 sec
# > epoch=196, batch=239/300, d1=0.266, d2=0.481, g=1.691, time=0.45 sec
# > epoch=196, batch=240/300, d1=0.228, d2=0.444, g=1.860, time=0.45 sec
# > epoch=196, batch=241/300, d1=0.419, d2=0.482, g=1.908, time=0.46 sec
# > epoch=196, batch=242/300, d1=0.448, d2=0.585, g=1.772, time=0.45 sec
# > epoch=196, batch=243/300, d1=0.404, d2=0.553, g=1.632, time=0.45 sec
# > epoch=196, batch=244/300, d1=0.512, d2=0.523, g=1.751, time=0.45 sec
# > epoch=196, batch=245/300, d1=0.366, d2=0.534, g=1.600, time=0.45 sec
# > epoch=196, batch=246/300, d1=0.265, d2=0.558, g=1.488, time=0.45 sec
# > epoch=196, batch=247/300, d1=0.471, d2=0.549, g=1.706, time=0.45 sec
# > epoch=196, batch=248/300, d1=0.345, d2=0.505, g=1.809, time=0.45 sec
# > epoch=196, batch=249/300, d1=0.433, d2=0.440, g=1.620, time=0.45 sec
# > epoch=196, batch=250/300, d1=0.386, d2=0.441, g=1.750, time=0.45 sec
# > epoch=196, batch=251/300, d1=0.488, d2=0.503, g=1.794, time=0.45 sec
# > epoch=196, batch=252/300, d1=0.446, d2=0.507, g=1.815, time=0.45 sec
# > epoch=196, batch=253/300, d1=0.394, d2=0.520, g=1.748, time=0.45 sec
# > epoch=196, batch=254/300, d1=0.254, d2=0.524, g=1.674, time=0.45 sec
# > epoch=196, batch=255/300, d1=0.445, d2=0.438, g=2.143, time=0.45 sec
# > epoch=196, batch=256/300, d1=0.369, d2=0.572, g=1.599, time=0.45 sec
# > epoch=196, batch=257/300, d1=0.491, d2=0.500, g=1.971, time=0.45 sec
# > epoch=196, batch=258/300, d1=0.311, d2=0.476, g=1.685, time=0.45 sec
# > epoch=196, batch=259/300, d1=0.309, d2=0.521, g=1.738, time=0.45 sec
# > epoch=196, batch=260/300, d1=0.336, d2=0.488, g=1.722, time=0.45 sec
# > epoch=196, batch=261/300, d1=0.368, d2=0.529, g=1.716, time=0.45 sec
# > epoch=196, batch=262/300, d1=0.462, d2=0.434, g=2.033, time=0.45 sec
# > epoch=196, batch=263/300, d1=0.547, d2=0.479, g=1.394, time=0.45 sec
# > epoch=196, batch=264/300, d1=0.390, d2=0.655, g=1.715, time=0.45 sec
# > epoch=196, batch=265/300, d1=0.544, d2=0.461, g=2.019, time=0.45 sec
# > epoch=196, batch=266/300, d1=0.524, d2=0.553, g=1.225, time=0.45 sec
# > epoch=196, batch=267/300, d1=0.232, d2=0.546, g=1.817, time=0.45 sec
# > epoch=196, batch=268/300, d1=0.458, d2=0.469, g=2.218, time=0.45 sec
# > epoch=196, batch=269/300, d1=0.593, d2=0.568, g=1.653, time=0.46 sec
# > epoch=196, batch=270/300, d1=0.403, d2=0.486, g=1.973, time=0.45 sec
# > epoch=196, batch=271/300, d1=0.632, d2=0.488, g=1.602, time=0.45 sec
# > epoch=196, batch=272/300, d1=0.439, d2=0.621, g=2.018, time=0.45 sec
# > epoch=196, batch=273/300, d1=0.495, d2=0.537, g=1.447, time=0.45 sec
# > epoch=196, batch=274/300, d1=0.419, d2=0.528, g=1.454, time=0.45 sec
# > epoch=196, batch=275/300, d1=0.363, d2=0.544, g=1.868, time=0.46 sec
# > epoch=196, batch=276/300, d1=0.407, d2=0.493, g=1.790, time=0.45 sec
# > epoch=196, batch=277/300, d1=0.447, d2=0.555, g=1.613, time=0.45 sec
# > epoch=196, batch=278/300, d1=0.491, d2=0.484, g=1.820, time=0.45 sec
# > epoch=196, batch=279/300, d1=0.469, d2=0.476, g=1.686, time=0.45 sec
# > epoch=196, batch=280/300, d1=0.319, d2=0.465, g=1.469, time=0.46 sec
# > epoch=196, batch=281/300, d1=0.249, d2=0.515, g=1.613, time=0.45 sec
# > epoch=196, batch=282/300, d1=0.298, d2=0.556, g=1.601, time=0.46 sec
# > epoch=196, batch=283/300, d1=0.221, d2=0.508, g=1.831, time=0.45 sec
# > epoch=196, batch=284/300, d1=0.364, d2=0.521, g=1.810, time=0.45 sec
# > epoch=196, batch=285/300, d1=0.410, d2=0.529, g=1.609, time=0.46 sec
# > epoch=196, batch=286/300, d1=0.396, d2=0.504, g=1.774, time=0.45 sec
# > epoch=196, batch=287/300, d1=0.364, d2=0.554, g=1.820, time=0.45 sec
# > epoch=196, batch=288/300, d1=0.263, d2=0.455, g=1.797, time=0.45 sec
# > epoch=196, batch=289/300, d1=0.150, d2=0.617, g=1.875, time=0.45 sec
# > epoch=196, batch=290/300, d1=0.459, d2=0.477, g=1.979, time=0.45 sec
# > epoch=196, batch=291/300, d1=0.235, d2=0.515, g=1.809, time=0.45 sec
# > epoch=196, batch=292/300, d1=0.350, d2=0.538, g=1.921, time=0.45 sec
# > epoch=196, batch=293/300, d1=0.350, d2=0.539, g=1.574, time=0.46 sec
# > epoch=196, batch=294/300, d1=0.298, d2=0.493, g=1.982, time=0.45 sec
# > epoch=196, batch=295/300, d1=0.293, d2=0.500, g=1.483, time=0.45 sec
# > epoch=196, batch=296/300, d1=0.295, d2=0.624, g=1.818, time=0.45 sec
# > epoch=196, batch=297/300, d1=0.400, d2=0.513, g=1.834, time=0.45 sec
# > epoch=196, batch=298/300, d1=0.409, d2=0.546, g=1.588, time=0.45 sec
# > epoch=196, batch=299/300, d1=0.459, d2=0.525, g=1.754, time=0.45 sec
# > epoch=196, batch=300/300, d1=0.334, d2=0.531, g=1.497, time=0.45 sec
#
# > epoch=197, batch=1/300, d1=0.383, d2=0.549, g=1.655, time=3.43 sec
# > epoch=197, batch=2/300, d1=0.231, d2=0.479, g=1.736, time=0.47 sec
# > epoch=197, batch=3/300, d1=0.272, d2=0.505, g=1.790, time=0.45 sec
# > epoch=197, batch=4/300, d1=0.290, d2=0.531, g=1.704, time=0.46 sec
# > epoch=197, batch=5/300, d1=0.443, d2=0.526, g=1.924, time=0.45 sec
# > epoch=197, batch=6/300, d1=0.529, d2=0.461, g=1.476, time=0.45 sec
